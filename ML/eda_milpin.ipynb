# %% [markdown]
# # EDA MILPÍN AgTech v2.0
# **Valle del Yaqui, Sonora — Distrito de Riego DR-041**
#
# | Sección | Contenido |
# |---|---|
# | 1. Vista General | Tablas, filas, nulos, dtypes |
# | 2. Catálogo FAO-56 | Kc, Ky, duración de ciclo, rendimiento |
# | 3. Parcelas | Suelo, riego, agua disponible, salinidad |
# | 4. Recomendaciones | Urgencias, feedback del agricultor, motor FAO-56 |
# | 5. KPI Hídrico | Volumen m³/ha vs baseline 8,000 · meta 6,000 |
# | 6. Economía | Márgenes, estructura de costos, ROI hídrico |
# | 7. Hallazgos Clave | Tabla resumen ejecutivo |

# %%
import json
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import display

warnings.filterwarnings('ignore')

DATA_DIR = Path('..') / 'data' / 'synthetic'

# ── Paleta visual MILPÍN ─────────────────────────────────────────────────────
CULTIVO_COLORS = {
    'Maíz':    '#F4C430',
    'Frijol':  '#8B4513',
    'Algodón': '#5F9EA0',
    'Uva':     '#722F37',
    'Chile':   '#DC143C',
}
VERDE = '#27AE60'; NARANJA = '#E67E22'; ROJO = '#C0392B'; AZUL = '#2980B9'; GRIS = '#7F8C8D'
URGENCIA_COLORS = {'crítico': ROJO, 'moderado': NARANJA, 'preventivo': VERDE}

sns.set_theme(style='whitegrid', font_scale=1.05)
plt.rcParams.update({'figure.dpi': 130, 'savefig.bbox': 'tight',
                     'axes.titlesize': 13, 'axes.labelsize': 11})

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)
pd.set_option('display.max_colwidth', 40)

# %% [markdown]
# ---
# ## 1 · Vista General de las Tablas

# %%
# Carga de los 6 datasets
usuarios  = pd.read_csv(DATA_DIR / 'usuarios.csv',           encoding='utf-8')
cultivos  = pd.read_csv(DATA_DIR / 'cultivos_catalogo.csv',  encoding='utf-8')
parcelas  = pd.read_csv(DATA_DIR / 'parcelas.csv',           encoding='utf-8')
recomend  = pd.read_csv(DATA_DIR / 'recomendaciones.csv',    encoding='utf-8')
historial = pd.read_csv(DATA_DIR / 'historial_riego.csv',    encoding='utf-8')
costos    = pd.read_csv(DATA_DIR / 'costos_ciclo.csv',       encoding='utf-8')

# Parsear fechas
recomend['fecha_generacion']  = pd.to_datetime(recomend['fecha_generacion'],  utc=True)
historial['fecha_riego']      = pd.to_datetime(historial['fecha_riego'])

# Enriquecer parcelas: unir cultivo desde costos (más fiable que parsear nombre_parcela)
cultivo_x_parcela = (
    costos.drop_duplicates('id_parcela')[['id_parcela', 'cultivo']]
)
parcelas = parcelas.merge(cultivo_x_parcela, on='id_parcela', how='left')

# Agua Disponible Total (mm) = (CC - PMP) × profundidad_raiz_cm × 10
parcelas['agua_disponible_mm'] = (
    (parcelas['capacidad_campo'] - parcelas['punto_marchitez'])
    * parcelas['profundidad_raiz_cm'] * 10
)

# ── Tabla resumen de datasets ─────────────────────────────────────────────────
dfs = {
    'usuarios':       usuarios,
    'cultivos_catalogo': cultivos,
    'parcelas':       parcelas,
    'recomendaciones': recomend,
    'historial_riego': historial,
    'costos_ciclo':   costos,
}

resumen = pd.DataFrame([
    {
        'Dataset': name,
        'Filas': df.shape[0],
        'Columnas': df.shape[1],
        'Nulos (total)': df.isnull().sum().sum(),
        'Nulos (%)': round(df.isnull().mean().mean() * 100, 1),
        'Memoria (KB)': round(df.memory_usage(deep=True).sum() / 1024, 1),
    }
    for name, df in dfs.items()
])

display(
    resumen.style
    .set_caption('📋 Inventario de datasets — MILPÍN v2.0')
    .background_gradient(subset=['Filas'], cmap='Blues')
    .background_gradient(subset=['Nulos (%)'], cmap='YlOrRd')
    .format({'Nulos (%)': '{:.1f}%', 'Memoria (KB)': '{:.1f} KB'})
    .set_properties(**{'text-align': 'center'})
    .set_table_styles([{
        'selector': 'caption',
        'props': [('font-size', '14px'), ('font-weight', 'bold'), ('color', '#2C3E50')]
    }])
    .hide(axis='index')
)
# Out:
# <style type="text/css">
# #T_58305 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2C3E50;
# }
# #T_58305_row0_col0, #T_58305_row0_col2, #T_58305_row0_col3, #T_58305_row0_col5, #T_58305_row1_col0, #T_58305_row1_col2, #T_58305_row1_col3, #T_58305_row1_col5, #T_58305_row2_col0, #T_58305_row2_col2, #T_58305_row2_col3, #T_58305_row2_col5, #T_58305_row3_col0, #T_58305_row3_col2, #T_58305_row3_col3, #T_58305_row3_col5, #T_58305_row4_col0, #T_58305_row4_col2, #T_58305_row4_col3, #T_58305_row4_col5, #T_58305_row5_col0, #T_58305_row5_col2, #T_58305_row5_col3, #T_58305_row5_col5 {
#   text-align: center;
# }
# #T_58305_row0_col1, #T_58305_row1_col1, #T_58305_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
# }
# #T_58305_row0_col4, #T_58305_row1_col4, #T_58305_row2_col4, #T_58305_row5_col4 {
#   background-color: #ffffcc;
#   color: #000000;
#   text-align: center;
# }
# #T_58305_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_58305_row3_col4 {
#   background-color: #fee187;
#   color: #000000;
#   text-align: center;
# }
# #T_58305_row4_col1 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_58305_row4_col4 {
#   background-color: #800026;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_58305_row5_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_58305">
#   <caption>📋 Inventario de datasets — MILPÍN v2.0</caption>
#   <thead>
#     <tr>
#       <th id="T_58305_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_58305_level0_col1" class="col_heading level0 col1" >Filas</th>
#       <th id="T_58305_level0_col2" class="col_heading level0 col2" >Columnas</th>
#       <th id="T_58305_level0_col3" class="col_heading level0 col3" >Nulos (total)</th>
#       <th id="T_58305_level0_col4" class="col_heading level0 col4" >Nulos (%)</th>
#       <th id="T_58305_level0_col5" class="col_heading level0 col5" >Memoria (KB)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_58305_row0_col0" class="data row0 col0" >usuarios</td>
#       <td id="T_58305_row0_col1" class="data row0 col1" >20</td>
#       <td id="T_58305_row0_col2" class="data row0 col2" >7</td>
#       <td id="T_58305_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_58305_row0_col4" class="data row0 col4" >0.0%</td>
#       <td id="T_58305_row0_col5" class="data row0 col5" >7.7 KB</td>
#     </tr>
#     <tr>
#       <td id="T_58305_row1_col0" class="data row1 col0" >cultivos_catalogo</td>
#       <td id="T_58305_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_58305_row1_col2" class="data row1 col2" >12</td>
#       <td id="T_58305_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_58305_row1_col4" class="data row1 col4" >0.0%</td>
#       <td id="T_58305_row1_col5" class="data row1 col5" >1.5 KB</td>
#     </tr>
#     <tr>
#       <td id="T_58305_row2_col0" class="data row2 col0" >parcelas</td>
#       <td id="T_58305_row2_col1" class="data row2 col1" >80</td>
#       <td id="T_58305_row2_col2" class="data row2 col2" >16</td>
#       <td id="T_58305_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_58305_row2_col4" class="data row2 col4" >0.0%</td>
#       <td id="T_58305_row2_col5" class="data row2 col5" >65.4 KB</td>
#     </tr>
#     <tr>
#       <td id="T_58305_row3_col0" class="data row3 col0" >recomendaciones</td>
#       <td id="T_58305_row3_col1" class="data row3 col1" >20800</td>
#       <td id="T_58305_row3_col2" class="data row3 col2" >15</td>
#       <td id="T_58305_row3_col3" class="data row3 col3" >6362</td>
#       <td id="T_58305_row3_col4" class="data row3 col4" >2.0%</td>
#       <td id="T_58305_row3_col5" class="data row3 col5" >14312.1 KB</td>
#     </tr>
#     <tr>
#       <td id="T_58305_row4_col0" class="data row4 col0" >historial_riego</td>
#       <td id="T_58305_row4_col1" class="data row4 col1" >11329</td>
#       <td id="T_58305_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_58305_row4_col3" class="data row4 col3" >15897</td>
#       <td id="T_58305_row4_col4" class="data row4 col4" >10.0%</td>
#       <td id="T_58305_row4_col5" class="data row4 col5" >5891.8 KB</td>
#     </tr>
#     <tr>
#       <td id="T_58305_row5_col0" class="data row5 col0" >costos_ciclo</td>
#       <td id="T_58305_row5_col1" class="data row5 col1" >800</td>
#       <td id="T_58305_row5_col2" class="data row5 col2" >13</td>
#       <td id="T_58305_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_58305_row5_col4" class="data row5 col4" >0.0%</td>
#       <td id="T_58305_row5_col5" class="data row5 col5" >280.0 KB</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Nulos detallados por columna (solo columnas con nulos)
nulos_por_df = {}
for name, df in dfs.items():
    s = df.isnull().sum()
    s = s[s > 0].rename(name)
    if not s.empty:
        nulos_por_df[name] = s

if nulos_por_df:
    nulos_df = pd.DataFrame(nulos_por_df).fillna(0).astype(int)
    display(
        nulos_df.style
        .set_caption(' Valores nulos por columna y dataset')
        .background_gradient(cmap='Oranges', axis=None)
        .format('{:,d}')
        .set_table_styles([{'selector': 'caption',
                            'props': [('font-size', '13px'), ('font-weight', 'bold')]}])
    )
else:
    print('✓ No hay valores nulos en ningún dataset.')
# Out:
# <style type="text/css">
# #T_6a865 caption {
#   font-size: 13px;
#   font-weight: bold;
# }
# #T_6a865_row0_col0, #T_6a865_row1_col1, #T_6a865_row2_col0 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_6a865_row0_col1 {
#   background-color: #fda660;
#   color: #000000;
# }
# #T_6a865_row1_col0 {
#   background-color: #f77b28;
#   color: #f1f1f1;
# }
# #T_6a865_row2_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6a865">
#   <caption>❓ Valores nulos por columna y dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a865_level0_col0" class="col_heading level0 col0" >recomendaciones</th>
#       <th id="T_6a865_level0_col1" class="col_heading level0 col1" >historial_riego</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a865_level0_row0" class="row_heading level0 row0" >id_recomendacion</th>
#       <td id="T_6a865_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6a865_row0_col1" class="data row0 col1" >4,568</td>
#     </tr>
#     <tr>
#       <th id="T_6a865_level0_row1" class="row_heading level0 row1" >lamina_ejecutada_mm</th>
#       <td id="T_6a865_row1_col0" class="data row1 col0" >6,362</td>
#       <td id="T_6a865_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a865_level0_row2" class="row_heading level0 row2" >observaciones</th>
#       <td id="T_6a865_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_6a865_row2_col1" class="data row2 col1" >11,329</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# ## 2 · Catálogo de Cultivos — Parámetros FAO-56

# %%
# Calcular métricas derivadas del catálogo
cult = cultivos.copy()
cult['ciclo_total_dias'] = (
    cult['dias_etapa_inicial'] + cult['dias_etapa_desarrollo']
    + cult['dias_etapa_media'] + cult['dias_etapa_final']
)
# Kc ponderado = 20% inicial + 60% medio + 20% final (pesos de duración aprox)
cult['kc_ponderado'] = (
    cult['kc_inicial'] * 0.20
    + cult['kc_medio']  * 0.60
    + cult['kc_final']  * 0.20
).round(3)
# Índice de riesgo hídrico = Ky × Kc_ponderado (cultivos con alta demanda Y alta sensibilidad)
cult['riesgo_hidrico'] = (cult['ky_total'] * cult['kc_ponderado']).round(3)

tabla_cult = cult[[
    'nombre_comun', 'nombre_cientifico',
    'kc_inicial', 'kc_medio', 'kc_final', 'kc_ponderado',
    'ky_total', 'ciclo_total_dias',
    'rendimiento_potencial_ton', 'riesgo_hidrico'
]].sort_values('riesgo_hidrico', ascending=False).reset_index(drop=True)

tabla_cult.columns = [
    'Cultivo', 'Nombre científico',
    'Kc ini', 'Kc med', 'Kc fin', 'Kc pond.',
    'Ky total', 'Ciclo (días)',
    'Rend. pot. (ton/ha)', 'Índice riesgo hídrico'
]

display(
    tabla_cult.style
    .set_caption('Catálogo FAO-56 — Parámetros agronómicos (ordenado por riesgo hídrico)')
    .background_gradient(subset=['Kc med'], cmap='YlGn')
    .background_gradient(subset=['Ky total'], cmap='YlOrRd')
    .background_gradient(subset=['Índice riesgo hídrico'], cmap='RdYlGn_r')
    .bar(subset=['Ciclo (días)'], color='#AED6F1', align='zero')
    .bar(subset=['Rend. pot. (ton/ha)'], color='#A9DFBF', align='zero')
    .format({'Kc ini': '{:.2f}', 'Kc med': '{:.2f}', 'Kc fin': '{:.2f}',
             'Kc pond.': '{:.3f}', 'Ky total': '{:.2f}',
             'Rend. pot. (ton/ha)': '{:.1f}', 'Índice riesgo hídrico': '{:.3f}'})
    .set_properties(**{'text-align': 'center'})
    .set_table_styles([{'selector': 'caption',
                        'props': [('font-size', '14px'), ('font-weight', 'bold')]}])
    .hide(axis='index')
)
# Out:
# <style type="text/css">
# #T_1e215 caption {
#   font-size: 14px;
#   font-weight: bold;
# }
# #T_1e215_row0_col0, #T_1e215_row0_col1, #T_1e215_row0_col2, #T_1e215_row0_col4, #T_1e215_row0_col5, #T_1e215_row1_col0, #T_1e215_row1_col1, #T_1e215_row1_col2, #T_1e215_row1_col4, #T_1e215_row1_col5, #T_1e215_row2_col0, #T_1e215_row2_col1, #T_1e215_row2_col2, #T_1e215_row2_col4, #T_1e215_row2_col5, #T_1e215_row3_col0, #T_1e215_row3_col1, #T_1e215_row3_col2, #T_1e215_row3_col4, #T_1e215_row3_col5, #T_1e215_row4_col0, #T_1e215_row4_col1, #T_1e215_row4_col2, #T_1e215_row4_col4, #T_1e215_row4_col5 {
#   text-align: center;
# }
# #T_1e215_row0_col3, #T_1e215_row3_col3 {
#   background-color: #004529;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1e215_row0_col6 {
#   background-color: #800026;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1e215_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #AED6F1 50.0%, #AED6F1 82.6%, transparent 82.6%);
#   text-align: center;
# }
# #T_1e215_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #A9DFBF 50.0%, #A9DFBF 66.7%, transparent 66.7%);
#   text-align: center;
# }
# #T_1e215_row0_col9 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1e215_row1_col3 {
#   background-color: #58b669;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1e215_row1_col6 {
#   background-color: #fc4d2a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1e215_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #AED6F1 50.0%, #AED6F1 79.1%, transparent 79.1%);
#   text-align: center;
# }
# #T_1e215_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #A9DFBF 50.0%, #A9DFBF 100.0%, transparent 100.0%);
#   text-align: center;
# }
# #T_1e215_row1_col9 {
#   background-color: #ee613e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1e215_row2_col3 {
#   background-color: #056c39;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1e215_row2_col6 {
#   background-color: #e31a1c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1e215_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #AED6F1 50.0%, #AED6F1 75.6%, transparent 75.6%);
#   text-align: center;
# }
# #T_1e215_row2_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #A9DFBF 50.0%, #A9DFBF 53.3%, transparent 53.3%);
#   text-align: center;
# }
# #T_1e215_row2_col9 {
#   background-color: #fba35c;
#   color: #000000;
#   text-align: center;
# }
# #T_1e215_row3_col6, #T_1e215_row4_col6 {
#   background-color: #ffffcc;
#   color: #000000;
#   text-align: center;
# }
# #T_1e215_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #AED6F1 50.0%, #AED6F1 91.9%, transparent 91.9%);
#   text-align: center;
# }
# #T_1e215_row3_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #A9DFBF 50.0%, #A9DFBF 55.8%, transparent 55.8%);
#   text-align: center;
# }
# #T_1e215_row3_col9 {
#   background-color: #daf08d;
#   color: #000000;
#   text-align: center;
# }
# #T_1e215_row4_col3 {
#   background-color: #ffffe5;
#   color: #000000;
#   text-align: center;
# }
# #T_1e215_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #AED6F1 50.0%, #AED6F1 100.0%, transparent 100.0%);
#   text-align: center;
# }
# #T_1e215_row4_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #A9DFBF 50.0%, #A9DFBF 87.5%, transparent 87.5%);
#   text-align: center;
# }
# #T_1e215_row4_col9 {
#   background-color: #006837;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_1e215">
#   <caption>🌾 Catálogo FAO-56 — Parámetros agronómicos (ordenado por riesgo hídrico)</caption>
#   <thead>
#     <tr>
#       <th id="T_1e215_level0_col0" class="col_heading level0 col0" >Cultivo</th>
#       <th id="T_1e215_level0_col1" class="col_heading level0 col1" >Nombre científico</th>
#       <th id="T_1e215_level0_col2" class="col_heading level0 col2" >Kc ini</th>
#       <th id="T_1e215_level0_col3" class="col_heading level0 col3" >Kc med</th>
#       <th id="T_1e215_level0_col4" class="col_heading level0 col4" >Kc fin</th>
#       <th id="T_1e215_level0_col5" class="col_heading level0 col5" >Kc pond.</th>
#       <th id="T_1e215_level0_col6" class="col_heading level0 col6" >Ky total</th>
#       <th id="T_1e215_level0_col7" class="col_heading level0 col7" >Ciclo (días)</th>
#       <th id="T_1e215_level0_col8" class="col_heading level0 col8" >Rend. pot. (ton/ha)</th>
#       <th id="T_1e215_level0_col9" class="col_heading level0 col9" >Índice riesgo hídrico</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1e215_row0_col0" class="data row0 col0" >Maíz</td>
#       <td id="T_1e215_row0_col1" class="data row0 col1" >Zea mays</td>
#       <td id="T_1e215_row0_col2" class="data row0 col2" >0.30</td>
#       <td id="T_1e215_row0_col3" class="data row0 col3" >1.20</td>
#       <td id="T_1e215_row0_col4" class="data row0 col4" >0.60</td>
#       <td id="T_1e215_row0_col5" class="data row0 col5" >0.900</td>
#       <td id="T_1e215_row0_col6" class="data row0 col6" >1.25</td>
#       <td id="T_1e215_row0_col7" class="data row0 col7" >140</td>
#       <td id="T_1e215_row0_col8" class="data row0 col8" >10.0</td>
#       <td id="T_1e215_row0_col9" class="data row0 col9" >1.125</td>
#     </tr>
#     <tr>
#       <td id="T_1e215_row1_col0" class="data row1 col0" >Chile</td>
#       <td id="T_1e215_row1_col1" class="data row1 col1" >Capsicum annuum</td>
#       <td id="T_1e215_row1_col2" class="data row1 col2" >0.60</td>
#       <td id="T_1e215_row1_col3" class="data row1 col3" >1.05</td>
#       <td id="T_1e215_row1_col4" class="data row1 col4" >0.90</td>
#       <td id="T_1e215_row1_col5" class="data row1 col5" >0.930</td>
#       <td id="T_1e215_row1_col6" class="data row1 col6" >1.10</td>
#       <td id="T_1e215_row1_col7" class="data row1 col7" >125</td>
#       <td id="T_1e215_row1_col8" class="data row1 col8" >30.0</td>
#       <td id="T_1e215_row1_col9" class="data row1 col9" >1.023</td>
#     </tr>
#     <tr>
#       <td id="T_1e215_row2_col0" class="data row2 col0" >Frijol</td>
#       <td id="T_1e215_row2_col1" class="data row2 col1" >Phaseolus vulgaris</td>
#       <td id="T_1e215_row2_col2" class="data row2 col2" >0.40</td>
#       <td id="T_1e215_row2_col3" class="data row2 col3" >1.15</td>
#       <td id="T_1e215_row2_col4" class="data row2 col4" >0.35</td>
#       <td id="T_1e215_row2_col5" class="data row2 col5" >0.840</td>
#       <td id="T_1e215_row2_col6" class="data row2 col6" >1.15</td>
#       <td id="T_1e215_row2_col7" class="data row2 col7" >110</td>
#       <td id="T_1e215_row2_col8" class="data row2 col8" >2.0</td>
#       <td id="T_1e215_row2_col9" class="data row2 col9" >0.966</td>
#     </tr>
#     <tr>
#       <td id="T_1e215_row3_col0" class="data row3 col0" >Algodón</td>
#       <td id="T_1e215_row3_col1" class="data row3 col1" >Gossypium hirsutum</td>
#       <td id="T_1e215_row3_col2" class="data row3 col2" >0.35</td>
#       <td id="T_1e215_row3_col3" class="data row3 col3" >1.20</td>
#       <td id="T_1e215_row3_col4" class="data row3 col4" >0.70</td>
#       <td id="T_1e215_row3_col5" class="data row3 col5" >0.930</td>
#       <td id="T_1e215_row3_col6" class="data row3 col6" >0.85</td>
#       <td id="T_1e215_row3_col7" class="data row3 col7" >180</td>
#       <td id="T_1e215_row3_col8" class="data row3 col8" >3.5</td>
#       <td id="T_1e215_row3_col9" class="data row3 col9" >0.790</td>
#     </tr>
#     <tr>
#       <td id="T_1e215_row4_col0" class="data row4 col0" >Uva</td>
#       <td id="T_1e215_row4_col1" class="data row4 col1" >Vitis vinifera</td>
#       <td id="T_1e215_row4_col2" class="data row4 col2" >0.30</td>
#       <td id="T_1e215_row4_col3" class="data row4 col3" >0.85</td>
#       <td id="T_1e215_row4_col4" class="data row4 col4" >0.45</td>
#       <td id="T_1e215_row4_col5" class="data row4 col5" >0.660</td>
#       <td id="T_1e215_row4_col6" class="data row4 col6" >0.85</td>
#       <td id="T_1e215_row4_col7" class="data row4 col7" >215</td>
#       <td id="T_1e215_row4_col8" class="data row4 col8" >22.5</td>
#       <td id="T_1e215_row4_col9" class

# %%
# Gráfico: Kc por etapa + Ky + duración de ciclo
fig, axes = plt.subplots(1, 3, figsize=(15, 4.5))
fig.suptitle('Catálogo FAO-56 — Coeficientes de cultivo por etapa', fontsize=14, fontweight='bold')

crop_names = cult['nombre_comun'].tolist()
x = np.arange(len(crop_names))
w = 0.25
c_colors = [CULTIVO_COLORS.get(c, GRIS) for c in crop_names]

# Panel 1: Kc por etapa
ax = axes[0]
ax.bar(x - w, cult['kc_inicial'], w, label='Kc inicial',  color='#A8D5A2', edgecolor='white')
ax.bar(x,      cult['kc_medio'],   w, label='Kc medio',    color='#2ECC71', edgecolor='white')
ax.bar(x + w, cult['kc_final'],   w, label='Kc final',    color='#1A5276', edgecolor='white')
ax.set_xticks(x); ax.set_xticklabels(crop_names, rotation=20, ha='right')
ax.set_ylabel('Coeficiente Kc'); ax.set_title('Fases del Kc')
ax.legend(fontsize=8); ax.set_ylim(0, 1.5)

# Panel 2: Sensibilidad hídrica Ky
ax2 = axes[1]
ky_sorted = cult.sort_values('ky_total', ascending=True)
ky_colors = [CULTIVO_COLORS.get(c, GRIS) for c in ky_sorted['nombre_comun']]
bars = ax2.barh(ky_sorted['nombre_comun'], ky_sorted['ky_total'],
                color=ky_colors, height=0.5, edgecolor='white')
ax2.bar_label(bars, fmt='%.2f', fontsize=9, padding=3)
ax2.axvline(1.0, color=ROJO, linestyle='--', lw=1.5, label='Ky=1 (proporcional)')
ax2.set_xlabel('Ky total'); ax2.set_title('Sensibilidad al déficit hídrico')
ax2.legend(fontsize=8); ax2.set_xlim(0, 1.5)

# Panel 3: Duración de etapas (barras apiladas)
ax3 = axes[2]
etapa_cols = ['dias_etapa_inicial', 'dias_etapa_desarrollo', 'dias_etapa_media', 'dias_etapa_final']
etapa_labels = ['Inicial', 'Desarrollo', 'Media', 'Final']
etapa_colors = ['#D5E8D4', '#82B366', '#23445D', '#ADB3BC']
bottom = np.zeros(len(cult))
for col, lbl, col_c in zip(etapa_cols, etapa_labels, etapa_colors):
    vals = cult[col].values
    ax3.bar(crop_names, vals, bottom=bottom, label=lbl, color=col_c, edgecolor='white')
    for i, (b, v) in enumerate(zip(bottom, vals)):
        if v > 0:
            ax3.text(i, b + v/2, str(v), ha='center', va='center', fontsize=8, color='white', fontweight='bold')
    bottom += vals
ax3.set_ylabel('Días'); ax3.set_title('Duración del ciclo por etapa')
ax3.tick_params(axis='x', rotation=20)
ax3.legend(fontsize=8, loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 3 · Parcelas — Perfil Edáfico y Uso de Suelo

# %%
# ── Estadísticas descriptivas de parcelas ────────────────────────────────────
desc_parc = parcelas[[
    'area_ha', 'conductividad_electrica',
    'profundidad_raiz_cm', 'capacidad_campo',
    'punto_marchitez', 'agua_disponible_mm'
]].describe().T.rename(columns={
    'count':'n', 'mean':'Media', 'std':'Desv.Est.',
    'min':'Mín', '25%':'P25', '50%':'Mediana',
    '75%':'P75', 'max':'Máx'
})
desc_parc.index = [
    'Superficie (ha)', 'CE (dS/m)',
    'Prof. raíz (cm)', 'Cap. campo (m³/m³)',
    'Punto marchitez (m³/m³)', 'Agua disponible (mm)'
]

display(
    desc_parc.style
    .set_caption('Estadísticas descriptivas de parcelas (n=80)')
    .background_gradient(subset=['Media'], cmap='Blues')
    .background_gradient(subset=['Desv.Est.'], cmap='Oranges')
    .format('{:.3f}', subset=['Media', 'Desv.Est.', 'Mín', 'P25', 'Mediana', 'P75', 'Máx'])
    .format('{:.0f}', subset=['n'])
    .set_table_styles([{'selector': 'caption',
                        'props': [('font-size', '14px'), ('font-weight', 'bold')]}])
)
# Out:
# <style type="text/css">
# #T_b66a8 caption {
#   font-size: 14px;
#   font-weight: bold;
# }
# #T_b66a8_row0_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_b66a8_row0_col2 {
#   background-color: #feecda;
#   color: #000000;
# }
# #T_b66a8_row1_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_b66a8_row1_col2 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_b66a8_row2_col1 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_b66a8_row2_col2 {
#   background-color: #fda762;
#   color: #000000;
# }
# #T_b66a8_row3_col1, #T_b66a8_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b66a8_row3_col2, #T_b66a8_row4_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_b66a8_row5_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b66a8_row5_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b66a8">
#   <caption>📊 Estadísticas descriptivas de parcelas (n=80)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b66a8_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_b66a8_level0_col1" class="col_heading level0 col1" >Media</th>
#       <th id="T_b66a8_level0_col2" class="col_heading level0 col2" >Desv.Est.</th>
#       <th id="T_b66a8_level0_col3" class="col_heading level0 col3" >Mín</th>
#       <th id="T_b66a8_level0_col4" class="col_heading level0 col4" >P25</th>
#       <th id="T_b66a8_level0_col5" class="col_heading level0 col5" >Mediana</th>
#       <th id="T_b66a8_level0_col6" class="col_heading level0 col6" >P75</th>
#       <th id="T_b66a8_level0_col7" class="col_heading level0 col7" >Máx</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b66a8_level0_row0" class="row_heading level0 row0" >Superficie (ha)</th>
#       <td id="T_b66a8_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_b66a8_row0_col1" class="data row0 col1" >13.354</td>
#       <td id="T_b66a8_row0_col2" class="data row0 col2" >6.635</td>
#       <td id="T_b66a8_row0_col3" class="data row0 col3" >5.118</td>
#       <td id="T_b66a8_row0_col4" class="data row0 col4" >8.801</td>
#       <td id="T_b66a8_row0_col5" class="data row0 col5" >11.739</td>
#       <td id="T_b66a8_row0_col6" class="data row0 col6" >16.642</td>
#       <td id="T_b66a8_row0_col7" class="data row0 col7" >34.987</td>
#     </tr>
#     <tr>
#       <th id="T_b66a8_level0_row1" class="row_heading level0 row1" >CE (dS/m)</th>
#       <td id="T_b66a8_row1_col0" class="data row1 col0" >80</td>
#       <td id="T_b66a8_row1_col1" class="data row1 col1" >2.549</td>
#       <td id="T_b66a8_row1_col2" class="data row1 col2" >1.564</td>
#       <td id="T_b66a8_row1_col3" class="data row1 col3" >1.010</td>
#       <td id="T_b66a8_row1_col4" class="data row1 col4" >1.620</td>
#       <td id="T_b66a8_row1_col5" class="data row1 col5" >2.105</td>
#       <td id="T_b66a8_row1_col6" class="data row1 col6" >2.708</td>
#       <td id="T_b66a8_row1_col7" class="data row1 col7" >7.860</td>
#     </tr>
#     <tr>
#       <th id="T_b66a8_level0_row2" class="row_heading level0 row2" >Prof. raíz (cm)</th>
#       <td id="T_b66a8_row2_col0" class="data row2 col0" >80</td>
#       <td id="T_b66a8_row2_col1" class="data row2 col1" >100.325</td>
#       <td id="T_b66a8_row2_col2" class="data row2 col2" >34.279</td>
#       <td id="T_b66a8_row2_col3" class="data row2 col3" >31.000</td>
#       <td id="T_b66a8_row2_col4" class="data row2 col4" >75.750</td>
#       <td id="T_b66a8_row2_col5" class="data row2 col5" >99.500</td>
#       <td id="T_b66a8_row2_col6" class="data row2 col6" >124.250</td>
#       <td id="T_b66a8_row2_col7" class="data row2 col7" >189.000</td>
#     </tr>
#     <tr>
#       <th id="T_b66a8_level0_row3" class="row_heading level0 row3" >Cap. campo (m³/m³)</th>
#       <td id="T_b66a8_row3_col0" class="data row3 col0" >80</td>
#       <td id="T_b66a8_row3_col1" class="data row3 col1" >0.291</td>
#       <td id="T_b66a8_row3_col2" class="data row3 col2" >0.061</td>
#       <td id="T_b66a8_row3_col3" class="data row3 col3" >0.177</td>
#       <td id="T_b66a8_row3_col4" class="data row3 col4" >0.250</td>
#       <td id="T_b66a8_row3_col5" class="data row3 col5" >0.298</td>
#       <td id="T_b66a8_row3_col6" class="data row3 col6" >0.331</td>
#       <td id="T_b66a8_row3_col7" class="data row3 col7" >0.444</td>
#     </tr>
#     <tr>
#       <th id="T_b66a8_level0_row4" class="row_heading level0 row4" >Punto marchitez (m³/m³)</th>
#       <td id="T_b66a8_row4_col0" class="data row4 col0" >80</td>
#       <td id="T_b66a8_row4_col1" class="data row4 col1" >0.131</td>
#       <td id="T_b66a8_row4_col2" class="data row4 col2" >0.044</td>
#       <td id="T_b66a8_row4_col3" class="data row4 col3" >0.043</td>
#       <td id="T_b66a8_row4_col4" class="data row4 col4" >0.097</td>
#       <td id="T_b66a8_row4_col5" class="data row4 col5" >0.130</td>
#       <td id="T_b66a8_row4_col6" class="data row4 col6" >0.159</td>
#       <td id="T_b66a8_row4_col7" class="data row4 col7" >0.242</td>
#     </tr>
#     <tr>
#       <th id="T_b66a8_level0_row5" class="row_heading level0 row5" >Agua disponible (mm)</th>
#       <td id="T_b66a8_row5_col0" class="data row5 col0" >80</td>
#       <td id="T_b66a8_row5_col1" class="data row5 col1" >159.888</td>
#       <td id="T_b66a8_row5_col2" class="data row5 col2" >85.378</td>
#       <td id="T_b66a8_row5_col3" class="data row5 col3" >26.319</td>
#       <td id="T_b66a8_row5_col4" class="data row5 col4" >91.675</td>
#       <td id="T_b66a8_row5_col5" class="data row5 col5" >156.786</td>
#       <td id="T_b66a8_row5_col6" class="data row5 col6" >212.859</td>
#       <td id="T_b66a8_row5_col7" class="data row5 col7" >416.179</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ── Distribuciones categóricas + métricas edáficas ───────────────────────────
fig, axes = plt.subplots(2, 3, figsize=(16, 9))
fig.suptitle('Análisis de Parcelas — DR-041', fontsize=15, fontweight='bold')

# (0,0) Superficie por cultivo
ax = axes[0, 0]
ha_cult = parcelas.groupby('cultivo')['area_ha'].sum().sort_values(ascending=False)
colors_c = [CULTIVO_COLORS.get(c, GRIS) for c in ha_cult.index]
bars = ax.bar(ha_cult.index, ha_cult.values, color=colors_c, edgecolor='white', width=0.6)
ax.bar_label(bars, fmt='%.0f ha', fontsize=9, padding=2)
ax.set_title('Superficie total por cultivo'); ax.set_ylabel('Hectáreas')
ax.tick_params(axis='x', rotation=15)

# (0,1) Sistema de riego
ax2 = axes[0, 1]
sys_cnt = parcelas['sistema_riego'].value_counts()
sys_pal = sns.color_palette('Set2', len(sys_cnt))
wedges, texts, autotexts = ax2.pie(
    sys_cnt.values, labels=sys_cnt.index, colors=sys_pal,
    autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.65))
for at in autotexts: at.set_fontsize(9)
ax2.set_title('Sistema de riego')

# (0,2) Tipo de suelo
ax3 = axes[0, 2]
suelo_cnt = parcelas['tipo_suelo'].value_counts()
suelo_pal = sns.color_palette('Set3', len(suelo_cnt))
wedges2, texts2, autotexts2 = ax3.pie(
    suelo_cnt.values, labels=suelo_cnt.index, colors=suelo_pal,
    autopct='%1.0f%%', startangle=140, wedgeprops=dict(width=0.65))
for at in autotexts2: at.set_fontsize(9)
ax3.set_title('Tipo de suelo')

# (1,0) CE por cultivo — boxplot
ax4 = axes[1, 0]
cult_order = parcelas['cultivo'].value_counts().index.tolist()
bp_data = [parcelas.loc[parcelas['cultivo']==c, 'conductividad_electrica'].dropna().values
           for c in cult_order]
bp = ax4.boxplot(bp_data, labels=cult_order, patch_artist=True,
                 medianprops=dict(color='white', lw=2.5), widths=0.5)
for patch, c in zip(bp['boxes'], cult_order):
    patch.set_facecolor(CULTIVO_COLORS.get(c, GRIS))
    patch.set_alpha(0.85)
ax4.axhline(4, color=ROJO, linestyle='--', lw=1.8, label='Límite estrés (4 dS/m)')
ax4.set_title('Conductividad Eléctrica por cultivo')
ax4.set_ylabel('CE (dS/m)'); ax4.legend(fontsize=8)
ax4.tick_params(axis='x', rotation=15)

# (1,1) Agua disponible (ADT)
ax5 = axes[1, 1]
adt = parcelas['agua_disponible_mm'].dropna()
ax5.hist(adt, bins=20, color=AZUL, edgecolor='white', alpha=0.85)
ax5.axvline(adt.mean(),   color=VERDE,   linestyle='--', lw=1.8, label=f'Media: {adt.mean():.0f} mm')
ax5.axvline(adt.quantile(0.25), color=NARANJA, linestyle=':', lw=1.5, label=f'P25: {adt.quantile(0.25):.0f} mm')
ax5.set_title('Agua Disponible Total (ADT) en suelo')
ax5.set_xlabel('mm'); ax5.set_ylabel('Parcelas'); ax5.legend(fontsize=8)

# (1,2) ADT vs CE scatter — detecta parcelas con doble estrés
ax6 = axes[1, 2]
colors_scatter = [CULTIVO_COLORS.get(c, GRIS) for c in parcelas['cultivo'].fillna('N/A')]
ax6.scatter(parcelas['conductividad_electrica'], parcelas['agua_disponible_mm'],
            c=colors_scatter, alpha=0.7, s=45, edgecolors='white', linewidths=0.5)
ax6.axvline(4, color=ROJO, linestyle='--', lw=1.5, alpha=0.7)
ax6.axhline(adt.quantile(0.25), color=NARANJA, linestyle=':', lw=1.5, alpha=0.7)
from matplotlib.patches import Patch
legend_handles = [Patch(color=v, label=k) for k, v in CULTIVO_COLORS.items()]
legend_handles += [
    plt.Line2D([0],[0], color=ROJO, linestyle='--', lw=1.5, label='CE > 4'),
    plt.Line2D([0],[0], color=NARANJA, linestyle=':', lw=1.5, label='ADT P25'),
]
ax6.legend(handles=legend_handles, fontsize=7, ncol=2)
ax6.set_xlabel('CE (dS/m)'); ax6.set_ylabel('Agua disponible (mm)')
ax6.set_title('Doble estrés: salinidad vs retención de agua')

plt.tight_layout()
plt.show()

# %%
# ── Parcelas con estrés salino activo (CE > 4 dS/m) ─────────────────────────
parcelas_salinas = (
    parcelas[parcelas['conductividad_electrica'] > 4]
    [['nombre_parcela', 'cultivo', 'area_ha',
      'conductividad_electrica', 'tipo_suelo',
      'sistema_riego', 'agua_disponible_mm']]
    .sort_values('conductividad_electrica', ascending=False)
    .reset_index(drop=True)
)
parcelas_salinas.columns = [
    'Parcela', 'Cultivo', 'Área (ha)',
    'CE (dS/m)', 'Tipo suelo', 'Sistema riego', 'ADT (mm)'
]

print(f'⚠  Parcelas con estrés salino activo: {len(parcelas_salinas)} de {len(parcelas)} ({len(parcelas_salinas)/len(parcelas)*100:.0f}%)')

display(
    parcelas_salinas.style
    .set_caption('Parcelas con CE > 4 dS/m — Estrés salino activo')
    .background_gradient(subset=['CE (dS/m)'], cmap='YlOrRd')
    .background_gradient(subset=['ADT (mm)'], cmap='Blues')
    .format({'CE (dS/m)': '{:.2f}', 'Área (ha)': '{:.1f}', 'ADT (mm)': '{:.1f}'})
    .set_properties(**{'text-align': 'center'})
    .set_table_styles([{'selector': 'caption',
                        'props': [('font-size', '14px'), ('font-weight', 'bold'), ('color', '#C0392B')]}])
    .hide(axis='index')
)
# Out:
# ⚠  Parcelas con estrés salino activo: 11 de 80 (14%)
# <style type="text/css">
# #T_fc6fb caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #C0392B;
# }
# #T_fc6fb_row0_col0, #T_fc6fb_row0_col1, #T_fc6fb_row0_col2, #T_fc6fb_row0_col4, #T_fc6fb_row0_col5, #T_fc6fb_row1_col0, #T_fc6fb_row1_col1, #T_fc6fb_row1_col2, #T_fc6fb_row1_col4, #T_fc6fb_row1_col5, #T_fc6fb_row2_col0, #T_fc6fb_row2_col1, #T_fc6fb_row2_col2, #T_fc6fb_row2_col4, #T_fc6fb_row2_col5, #T_fc6fb_row3_col0, #T_fc6fb_row3_col1, #T_fc6fb_row3_col2, #T_fc6fb_row3_col4, #T_fc6fb_row3_col5, #T_fc6fb_row4_col0, #T_fc6fb_row4_col1, #T_fc6fb_row4_col2, #T_fc6fb_row4_col4, #T_fc6fb_row4_col5, #T_fc6fb_row5_col0, #T_fc6fb_row5_col1, #T_fc6fb_row5_col2, #T_fc6fb_row5_col4, #T_fc6fb_row5_col5, #T_fc6fb_row6_col0, #T_fc6fb_row6_col1, #T_fc6fb_row6_col2, #T_fc6fb_row6_col4, #T_fc6fb_row6_col5, #T_fc6fb_row7_col0, #T_fc6fb_row7_col1, #T_fc6fb_row7_col2, #T_fc6fb_row7_col4, #T_fc6fb_row7_col5, #T_fc6fb_row8_col0, #T_fc6fb_row8_col1, #T_fc6fb_row8_col2, #T_fc6fb_row8_col4, #T_fc6fb_row8_col5, #T_fc6fb_row9_col0, #T_fc6fb_row9_col1, #T_fc6fb_row9_col2, #T_fc6fb_row9_col4, #T_fc6fb_row9_col5, #T_fc6fb_row10_col0, #T_fc6fb_row10_col1, #T_fc6fb_row10_col2, #T_fc6fb_row10_col4, #T_fc6fb_row10_col5 {
#   text-align: center;
# }
# #T_fc6fb_row0_col3 {
#   background-color: #800026;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_fc6fb_row0_col6 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_fc6fb_row1_col3 {
#   background-color: #990026;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_fc6fb_row1_col6 {
#   background-color: #4090c5;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_fc6fb_row2_col3 {
#   background-color: #f33b25;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_fc6fb_row2_col6 {
#   background-color: #084c95;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_fc6fb_row3_col3 {
#   background-color: #fc512b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_fc6fb_row3_col6 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_fc6fb_row4_col3, #T_fc6fb_row5_col3 {
#   background-color: #fd8e3c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_fc6fb_row4_col6 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
# }
# #T_fc6fb_row5_col6 {
#   background-color: #3484bf;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_fc6fb_row6_col3 {
#   background-color: #febe59;
#   color: #000000;
#   text-align: center;
# }
# #T_fc6fb_row6_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_fc6fb_row7_col3 {
#   background-color: #fedb7a;
#   color: #000000;
#   text-align: center;
# }
# #T_fc6fb_row7_col6 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_fc6fb_row8_col3 {
#   background-color: #ffeea3;
#   color: #000000;
#   text-align: center;
# }
# #T_fc6fb_row8_col6 {
#   background-color: #e9f2fa;
#   color: #000000;
#   text-align: center;
# }
# #T_fc6fb_row9_col3 {
#   background-color: #fffec9;
#   color: #000000;
#   text-align: center;
# }
# #T_fc6fb_row9_col6 {
#   background-color: #b8d5ea;
#   color: #000000;
#   text-align: center;
# }
# #T_fc6fb_row10_col3 {
#   background-color: #ffffcc;
#   color: #000000;
#   text-align: center;
# }
# #T_fc6fb_row10_col6 {
#   background-color: #cbdef1;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_fc6fb">
#   <caption>⚠️ Parcelas con CE > 4 dS/m — Estrés salino activo</caption>
#   <thead>
#     <tr>
#       <th id="T_fc6fb_level0_col0" class="col_heading level0 col0" >Parcela</th>
#       <th id="T_fc6fb_level0_col1" class="col_heading level0 col1" >Cultivo</th>
#       <th id="T_fc6fb_level0_col2" class="col_heading level0 col2" >Área (ha)</th>
#       <th id="T_fc6fb_level0_col3" class="col_heading level0 col3" >CE (dS/m)</th>
#       <th id="T_fc6fb_level0_col4" class="col_heading level0 col4" >Tipo suelo</th>
#       <th id="T_fc6fb_level0_col5" class="col_heading level0 col5" >Sistema riego</th>
#       <th id="T_fc6fb_level0_col6" class="col_heading level0 col6" >ADT (mm)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fc6fb_row0_col0" class="data row0 col0" >Lote Chi-031</td>
#       <td id="T_fc6fb_row0_col1" class="data row0 col1" >Uva</td>
#       <td id="T_fc6fb_row0_col2" class="data row0 col2" >16.3</td>
#       <td id="T_fc6fb_row0_col3" class="data row0 col3" >7.86</td>
#       <td id="T_fc6fb_row0_col4" class="data row0 col4" >franco-arenoso</td>
#       <td id="T_fc6fb_row0_col5" class="data row0 col5" >gravedad</td>
#       <td id="T_fc6fb_row0_col6" class="data row0 col6" >199.6</td>
#     </tr>
#     <tr>
#       <td id="T_fc6fb_row1_col0" class="data row1 col0" >Lote Chi-056</td>
#       <td id="T_fc6fb_row1_col1" class="data row1 col1" >Algodón</td>
#       <td id="T_fc6fb_row1_col2" class="data row1 col2" >21.0</td>
#       <td id="T_fc6fb_row1_col3" class="data row1 col3" >7.68</td>
#       <td id="T_fc6fb_row1_col4" class="data row1 col4" >arcilloso</td>
#       <td id="T_fc6fb_row1_col5" class="data row1 col5" >aspersion</td>
#       <td id="T_fc6fb_row1_col6" class="data row1 col6" >159.1</td>
#     </tr>
#     <tr>
#       <td id="T_fc6fb_row2_col0" class="data row2 col0" >Lote Uva-018</td>
#       <td id="T_fc6fb_row2_col1" class="data row2 col1" >Maíz</td>
#       <td id="T_fc6fb_row2_col2" class="data row2 col2" >8.8</td>
#       <td id="T_fc6fb_row2_col3" class="data row2 col3" >6.70</td>
#       <td id="T_fc6fb_row2_col4" class="data row2 col4" >arenoso</td>
#       <td id="T_fc6fb_row2_col5" class="data row2 col5" >goteo</td>
#       <td id="T_fc6fb_row2_col6" class="data row2 col6" >210.1</td>
#     </tr>
#     <tr>
#       <td id="T_fc6fb_row3_col0" class="data row3 col0" >Lote Alg-033</td>
#       <td id="T_fc6fb_row3_col1" class="data row3 col1" >Chile</td>
#       <td id="T_fc6fb_row3_col2" class="data row3 col2" >9.4</td>
#       <td id="T_fc6fb_row3_col3" class="data row3 col3" >6.53</td>
#       <td id="T_fc6fb_row3_col4" class="data row3 col4" >franco</td>
#       <td id="T_fc6fb_row3_col5" class="data row3 col5" >microaspersion</td>
#       <td id="T_fc6fb_row3_col6" class="data row3 col6" >141.1</td>
#     </tr>
#     <tr>
#       <td id="T_fc6fb_row4_col0" class="data row4 col0" >Lote Alg-036</td>
#       <td id="T_fc6fb_row4_col1" class="data row4 col1" >Chile</td>
#       <td id="T_fc6fb_row4_col2" class="data row4 col2" >16.6</td>
#       <td id="T_fc6fb_row4_col3" class="data row4 col3" >6.10</td>
#       <td id="T_fc6fb_row4_col4" class="data row4 col4" >arcilloso</td>
#       <td id="T_fc6fb_row4_col5" class="data row4 col5" >aspersion</td>
#       <td id="T_fc6fb_row4_col6" class="data row4 col6" >36.1</td>
#     </tr>
#     <tr>
#       <td id="T_fc6fb_row5_col0" class="data row5 col0" >Lote Fri-080</td>
#       <td id="T_fc6fb_row5_col1" class="data row5 col1" >Chile</td>
#       <td id="T_fc6fb_row5_col2" class="data row5 col2" >14.8</td>
#       <td id="T_fc6fb_row5_col3" class="data row5 col3" >6.10</td>
#       <td id="T_fc6fb_row5_col4" class="data row5 col4" >franco</td>
#       <td id="T_fc6fb_row5_col5" class="data row5 col5" >gravedad</td>
#       <td id="T_fc6fb_row5_col6" class="data row5 col6" >168.3</td>
#     </tr>
#     <tr>
#       <td id="T_fc6fb_row6_col0" class="data row6 col0" >Lote Maí-057</td>
#       <td id="T_fc6fb_row6_col1" class="data row6 col1" >Uva</td>
#       <td id="T_fc6fb_row6_col2" class="data row6 col2" >16.0</td>
#       <td id="T_fc6fb_row6_col3" class="data row6 col3" >5.53</td>
#       <td id="T_fc6fb_row6_col4" class="data row6 col4" >arcilloso</td>
#       <td id="T_fc6fb_row6_col5" class="data row6 col5" >microaspersion</td>
#       <td id="T_fc6fb_row6_col6" class="data row6 col6" >231.3</td>
#     </tr>
#     <tr>
#       <td id="T_fc6fb_row7_col0" class="data row7 col0" >Lote Uva-074</td>
#       <td id="T_fc6fb_row7_col1" class="data row7 col1" >Chile</td>
#       <td id="T_fc6fb_row7_col2" class="data row7 col2" >7.8</td>
#       <td id="T_fc6fb_row7_col3" class="data row7 col3" >5.19</td>
#       <td id="T_fc6fb_row7_col4" class="data row7 col4" >franco-arcilloso</td>
#       <td id="T_fc6fb_row7_col5" class="data row7 col5" >aspersion</td>
#       <td id="T_fc6fb_row7_col6" class="data row7 col6" >131.3</td>
#     </tr>
#     <tr>

# %% [markdown]
# ---
# ## 4 · Recomendaciones — Motor FAO-56 y Feedback del Agricultor

# %%
# Extraer cultivo de parametros_json
def _cultivo_json(s):
    try:
        return json.loads(s).get('cultivo')
    except Exception:
        return None

recomend['cultivo'] = recomend['parametros_json'].apply(_cultivo_json)
recomend['mes']     = recomend['fecha_generacion'].dt.to_period('M')

# ── Resumen por nivel de urgencia ────────────────────────────────────────────
urg_resumen = (
    recomend.groupby('nivel_urgencia').agg(
        n_recomendaciones=('id_recomendacion', 'count'),
        pct_aceptadas=('aceptada', lambda x: (x == 'aceptada').mean() * 100),
        pct_ignoradas=('aceptada', lambda x: (x == 'ignorada').mean() * 100),
        pct_modificadas=('aceptada', lambda x: (x == 'modificada').mean() * 100),
        lamina_media_mm=('lamina_recomendada_mm', 'mean'),
        eto_media=('eto_referencia', 'mean'),
        etc_media=('etc_calculada', 'mean'),
        deficit_medio_mm=('deficit_acumulado_mm', 'mean'),
    ).reset_index()
)
urg_resumen.columns = [
    'Urgencia', 'N° recomend.',
    'Aceptadas (%)', 'Ignoradas (%)', 'Modificadas (%)',
    'Lámina media (mm)', 'ETo media', 'ETc media', 'Déficit medio (mm)'
]
urg_orden = {'crítico': 0, 'moderado': 1, 'preventivo': 2}
urg_resumen['_ord'] = urg_resumen['Urgencia'].map(urg_orden)
urg_resumen = urg_resumen.sort_values('_ord').drop('_ord', axis=1).reset_index(drop=True)

def colorear_urgencia(val):
    colors = {'crítico': '#FADBD8', 'moderado': '#FDEBD0', 'preventivo': '#D5F5E3'}
    return f'background-color: {colors.get(val, "")}; font-weight: bold'

display(
    urg_resumen.style
    .set_caption('Recomendaciones por nivel de urgencia — feedback del agricultor')
    .applymap(colorear_urgencia, subset=['Urgencia'])
    .background_gradient(subset=['Aceptadas (%)'], cmap='Greens')
    .background_gradient(subset=['Ignoradas (%)'], cmap='Reds')
    .background_gradient(subset=['Déficit medio (mm)'], cmap='YlOrRd')
    .format({
        'N° recomend.': '{:,d}',
        'Aceptadas (%)': '{:.1f}%',
        'Ignoradas (%)': '{:.1f}%',
        'Modificadas (%)': '{:.1f}%',
        'Lámina media (mm)': '{:.1f}',
        'ETo media': '{:.3f}',
        'ETc media': '{:.3f}',
        'Déficit medio (mm)': '{:.1f}',
    })
    .set_properties(**{'text-align': 'center'})
    .set_table_styles([{'selector': 'caption',
                        'props': [('font-size', '14px'), ('font-weight', 'bold')]}])
    .hide(axis='index')
)
# Out:
# <style type="text/css">
# #T_bd966 caption {
#   font-size: 14px;
#   font-weight: bold;
# }
# #T_bd966_row0_col0 {
#   background-color: #FDEBD0;
#   font-weight: bold;
#   text-align: center;
# }
# #T_bd966_row0_col1, #T_bd966_row0_col4, #T_bd966_row0_col5, #T_bd966_row0_col6, #T_bd966_row0_col7, #T_bd966_row1_col1, #T_bd966_row1_col4, #T_bd966_row1_col5, #T_bd966_row1_col6, #T_bd966_row1_col7, #T_bd966_row2_col1, #T_bd966_row2_col4, #T_bd966_row2_col5, #T_bd966_row2_col6, #T_bd966_row2_col7 {
#   text-align: center;
# }
# #T_bd966_row0_col2 {
#   background-color: #006b2b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd966_row0_col3 {
#   background-color: #880811;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd966_row0_col8 {
#   background-color: #fd9d43;
#   color: #000000;
#   text-align: center;
# }
# #T_bd966_row1_col0 {
#   background-color: #D5F5E3;
#   font-weight: bold;
#   text-align: center;
# }
# #T_bd966_row1_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd966_row1_col3 {
#   background-color: #fff5f0;
#   color: #000000;
#   text-align: center;
# }
# #T_bd966_row1_col8 {
#   background-color: #ffffcc;
#   color: #000000;
#   text-align: center;
# }
# #T_bd966_row2_col0 {
#   background-color: ;
#   font-weight: bold;
#   text-align: center;
# }
# #T_bd966_row2_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
#   text-align: center;
# }
# #T_bd966_row2_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_bd966_row2_col8 {
#   background-color: #800026;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_bd966">
#   <caption>🚨 Recomendaciones por nivel de urgencia — feedback del agricultor</caption>
#   <thead>
#     <tr>
#       <th id="T_bd966_level0_col0" class="col_heading level0 col0" >Urgencia</th>
#       <th id="T_bd966_level0_col1" class="col_heading level0 col1" >N° recomend.</th>
#       <th id="T_bd966_level0_col2" class="col_heading level0 col2" >Aceptadas (%)</th>
#       <th id="T_bd966_level0_col3" class="col_heading level0 col3" >Ignoradas (%)</th>
#       <th id="T_bd966_level0_col4" class="col_heading level0 col4" >Modificadas (%)</th>
#       <th id="T_bd966_level0_col5" class="col_heading level0 col5" >Lámina media (mm)</th>
#       <th id="T_bd966_level0_col6" class="col_heading level0 col6" >ETo media</th>
#       <th id="T_bd966_level0_col7" class="col_heading level0 col7" >ETc media</th>
#       <th id="T_bd966_level0_col8" class="col_heading level0 col8" >Déficit medio (mm)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bd966_row0_col0" class="data row0 col0" >moderado</td>
#       <td id="T_bd966_row0_col1" class="data row0 col1" >11,300</td>
#       <td id="T_bd966_row0_col2" class="data row0 col2" >55.1%</td>
#       <td id="T_bd966_row0_col3" class="data row0 col3" >10.2%</td>
#       <td id="T_bd966_row0_col4" class="data row0 col4" >14.5%</td>
#       <td id="T_bd966_row0_col5" class="data row0 col5" >58.3</td>
#       <td id="T_bd966_row0_col6" class="data row0 col6" >7.018</td>
#       <td id="T_bd966_row0_col7" class="data row0 col7" >5.191</td>
#       <td id="T_bd966_row0_col8" class="data row0 col8" >53.6</td>
#     </tr>
#     <tr>
#       <td id="T_bd966_row1_col0" class="data row1 col0" >preventivo</td>
#       <td id="T_bd966_row1_col1" class="data row1 col1" >5,496</td>
#       <td id="T_bd966_row1_col2" class="data row1 col2" >55.4%</td>
#       <td id="T_bd966_row1_col3" class="data row1 col3" >9.8%</td>
#       <td id="T_bd966_row1_col4" class="data row1 col4" >14.6%</td>
#       <td id="T_bd966_row1_col5" class="data row1 col5" >57.2</td>
#       <td id="T_bd966_row1_col6" class="data row1 col6" >7.019</td>
#       <td id="T_bd966_row1_col7" class="data row1 col7" >5.171</td>
#       <td id="T_bd966_row1_col8" class="data row1 col8" >16.7</td>
#     </tr>
#     <tr>
#       <td id="T_bd966_row2_col0" class="data row2 col0" >critico</td>
#       <td id="T_bd966_row2_col1" class="data row2 col1" >4,004</td>
#       <td id="T_bd966_row2_col2" class="data row2 col2" >53.1%</td>
#       <td id="T_bd966_row2_col3" class="data row2 col3" >10.3%</td>
#       <td id="T_bd966_row2_col4" class="data row2 col4" >15.0%</td>
#       <td id="T_bd966_row2_col5" class="data row2 col5" >57.2</td>
#       <td id="T_bd966_row2_col6" class="data row2 col6" >6.961</td>
#       <td id="T_bd966_row2_col7" class="data row2 col7" >5.149</td>
#       <td id="T_bd966_row2_col8" class="data row2 col8" >99.3</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Gráfico: distribuciones de recomendaciones
fig, axes = plt.subplots(1, 3, figsize=(16, 5))
fig.suptitle('Análisis de Recomendaciones FAO-56', fontsize=14, fontweight='bold')

# Panel 1: Urgencia stacked bar por cultivo
ax1 = axes[0]
if recomend['cultivo'].notna().any():
    pivot_urg = (
        recomend.groupby(['cultivo', 'nivel_urgencia'])
        .size().unstack(fill_value=0)
    )
    col_order = [c for c in ['crítico', 'moderado', 'preventivo'] if c in pivot_urg.columns]
    colors_urg = [URGENCIA_COLORS.get(c, GRIS) for c in col_order]
    pivot_urg[col_order].plot(kind='bar', stacked=True, ax=ax1, color=colors_urg,
                               edgecolor='white', width=0.6)
    ax1.set_xlabel(''); ax1.set_ylabel('Recomendaciones')
    ax1.set_title('Urgencias por cultivo'); ax1.tick_params(axis='x', rotation=20)
    ax1.legend(title='Urgencia', fontsize=8)

# Panel 2: Tasa de aceptación por cultivo
ax2 = axes[1]
if recomend['cultivo'].notna().any():
    accept_rate = (
        recomend.groupby('cultivo')['aceptada']
        .apply(lambda x: (x == 'aceptada').mean() * 100)
        .sort_values(ascending=True)
    )
    bar_colors = [CULTIVO_COLORS.get(c, GRIS) for c in accept_rate.index]
    bars2 = ax2.barh(accept_rate.index, accept_rate.values,
                     color=bar_colors, height=0.5, edgecolor='white')
    ax2.bar_label(bars2, fmt='%.0f%%', fontsize=9, padding=3)
    ax2.set_xlabel('Tasa de aceptación (%)')
    ax2.set_title('Aceptación de recomendaciones')
    ax2.set_xlim(0, 110)

# Panel 3: Distribución de la lámina recomendada por urgencia
ax3 = axes[2]
for urg, color in URGENCIA_COLORS.items():
    subset = recomend.loc[recomend['nivel_urgencia'] == urg, 'lamina_recomendada_mm'].dropna()
    if not subset.empty:
        ax3.hist(subset, bins=20, alpha=0.6, label=urg, color=color, edgecolor='white')
ax3.set_xlabel('Lámina recomendada (mm)'); ax3.set_ylabel('Frecuencia')
ax3.set_title('Distribución de lámina por urgencia')
ax3.legend(fontsize=9)

plt.tight_layout()
plt.show()

# Resumen numérico del feedback
print('\nFeedback global del agricultor:')
fb = recomend['aceptada'].value_counts(normalize=True).mul(100).round(1)
for estado, pct in fb.items():
    print(f'  {estado:12s}: {pct:.1f}%')
# Out:
# Feedback global del agricultor:
#   aceptada    : 54.8%
#   pendiente   : 20.5%
#   modificada  : 14.6%
#   ignorada    : 10.1%

# %% [markdown]
# ---
# ## 5 · KPI Hídrico — Historial de Riego
# **Baseline DR-041:** 8,000 m³/ha/ciclo · **Meta MILPÍN:** 6,000 m³/ha/ciclo · **Tarifa:** $1.68 MXN/m³

# %%
BASELINE = 8000.0
META     = 6000.0
TARIFA   = 1.68  # MXN/m³

# ── KPI por parcela × ciclo: volumen m³/ha POR CICLO ────────────────────────
# El historial ahora tiene columna 'ciclo_agricola', así que agregamos
# por (id_parcela, ciclo_agricola) — la unidad correcta para comparar
# contra el baseline de 8,000 m³/ha/ciclo.
kpi = (
    historial
    .groupby(['id_parcela', 'ciclo_agricola'])
    .agg(
        eventos_riego=('id_riego', 'count'),
        vol_m3_ha_ciclo=('volumen_m3_ha', 'sum'),
        vol_m3_ha_media=('volumen_m3_ha', 'mean'),
        lamina_media_mm=('lamina_mm', 'mean'),
        costo_ciclo_mxn=('costo_energia_mxn', 'sum'),
    )
    .reset_index()
)
kpi = kpi.merge(
    parcelas[['id_parcela', 'nombre_parcela', 'cultivo', 'area_ha',
              'sistema_riego']],
    on='id_parcela', how='left'
)

kpi['ahorro_vs_baseline_pct'] = (
    (BASELINE - kpi['vol_m3_ha_ciclo']) / BASELINE * 100
).round(1)
kpi['vs_meta_6000']  = (kpi['vol_m3_ha_ciclo'] - META).round(0)
kpi['bajo_meta']     = kpi['vol_m3_ha_ciclo'] <= META

# Top 10 ciclos por consumo
top10 = (
    kpi.nlargest(10, 'vol_m3_ha_ciclo')
    [['nombre_parcela', 'ciclo_agricola', 'cultivo', 'sistema_riego',
      'eventos_riego', 'vol_m3_ha_ciclo', 'ahorro_vs_baseline_pct',
      'vs_meta_6000', 'costo_ciclo_mxn']]
    .reset_index(drop=True)
)
top10.columns = [
    'Parcela', 'Ciclo', 'Cultivo', 'Sistema riego',
    'Eventos', 'Vol m³/ha/ciclo', 'Ahorro vs 8k (%)',
    'Δ vs meta 6k', 'Costo energía (MXN)'
]

def color_meta(val):
    if val > 0:
        return 'background-color: #FADBD8; color: #C0392B; font-weight: bold'
    return 'background-color: #D5F5E3; color: #1E8449; font-weight: bold'

display(
    top10.style
    .set_caption('Top 10 ciclos por consumo — Posición vs KPI DR-041')
    .background_gradient(subset=['Vol m³/ha/ciclo'], cmap='RdYlGn_r')
    .applymap(color_meta, subset=['Δ vs meta 6k'])
    .format({
        'Vol m³/ha/ciclo': '{:,.0f}',
        'Ahorro vs 8k (%)': '{:.1f}%',
        'Δ vs meta 6k': '{:+,.0f}',
        'Costo energía (MXN)': '${:,.0f}',
    })
    .set_properties(**{'text-align': 'center'})
    .set_table_styles([{'selector': 'caption',
                        'props': [('font-size', '14px'), ('font-weight', 'bold')]}])
    .hide(axis='index')
)

bajo = kpi['bajo_meta'].sum()
n_total = len(kpi)
vol_medio = kpi['vol_m3_ha_ciclo'].mean()
print(f'\n▶ Total observaciones: {n_total} (parcelas × ciclos)')
print(f'▶ Ciclos bajo meta 6,000 m³/ha: {bajo} de {n_total} ({bajo/n_total*100:.1f}%)')
print(f'▶ Volumen medio por ciclo: {vol_medio:,.0f} m³/ha')
print(f'▶ Ahorro promedio vs baseline 8,000: '
      f'{((BASELINE - vol_medio) / BASELINE * 100):.1f}%')
# Out:
# <style type="text/css">
# #T_33fe9 caption {
#   font-size: 14px;
#   font-weight: bold;
# }
# #T_33fe9_row0_col0, #T_33fe9_row0_col1, #T_33fe9_row0_col2, #T_33fe9_row0_col3, #T_33fe9_row0_col4, #T_33fe9_row0_col6, #T_33fe9_row0_col8, #T_33fe9_row1_col0, #T_33fe9_row1_col1, #T_33fe9_row1_col2, #T_33fe9_row1_col3, #T_33fe9_row1_col4, #T_33fe9_row1_col6, #T_33fe9_row1_col8, #T_33fe9_row2_col0, #T_33fe9_row2_col1, #T_33fe9_row2_col2, #T_33fe9_row2_col3, #T_33fe9_row2_col4, #T_33fe9_row2_col6, #T_33fe9_row2_col8, #T_33fe9_row3_col0, #T_33fe9_row3_col1, #T_33fe9_row3_col2, #T_33fe9_row3_col3, #T_33fe9_row3_col4, #T_33fe9_row3_col6, #T_33fe9_row3_col8, #T_33fe9_row4_col0, #T_33fe9_row4_col1, #T_33fe9_row4_col2, #T_33fe9_row4_col3, #T_33fe9_row4_col4, #T_33fe9_row4_col6, #T_33fe9_row4_col8, #T_33fe9_row5_col0, #T_33fe9_row5_col1, #T_33fe9_row5_col2, #T_33fe9_row5_col3, #T_33fe9_row5_col4, #T_33fe9_row5_col6, #T_33fe9_row5_col8, #T_33fe9_row6_col0, #T_33fe9_row6_col1, #T_33fe9_row6_col2, #T_33fe9_row6_col3, #T_33fe9_row6_col4, #T_33fe9_row6_col6, #T_33fe9_row6_col8, #T_33fe9_row7_col0, #T_33fe9_row7_col1, #T_33fe9_row7_col2, #T_33fe9_row7_col3, #T_33fe9_row7_col4, #T_33fe9_row7_col6, #T_33fe9_row7_col8, #T_33fe9_row8_col0, #T_33fe9_row8_col1, #T_33fe9_row8_col2, #T_33fe9_row8_col3, #T_33fe9_row8_col4, #T_33fe9_row8_col6, #T_33fe9_row8_col8, #T_33fe9_row9_col0, #T_33fe9_row9_col1, #T_33fe9_row9_col2, #T_33fe9_row9_col3, #T_33fe9_row9_col4, #T_33fe9_row9_col6, #T_33fe9_row9_col8 {
#   text-align: center;
# }
# #T_33fe9_row0_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_33fe9_row0_col7, #T_33fe9_row1_col7, #T_33fe9_row2_col7, #T_33fe9_row3_col7, #T_33fe9_row4_col7, #T_33fe9_row5_col7, #T_33fe9_row6_col7, #T_33fe9_row7_col7, #T_33fe9_row8_col7, #T_33fe9_row9_col7 {
#   background-color: #FADBD8;
#   color: #C0392B;
#   font-weight: bold;
#   text-align: center;
# }
# #T_33fe9_row1_col5 {
#   background-color: #e14430;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_33fe9_row2_col5 {
#   background-color: #fa9656;
#   color: #000000;
#   text-align: center;
# }
# #T_33fe9_row3_col5 {
#   background-color: #d7ee8a;
#   color: #000000;
#   text-align: center;
# }
# #T_33fe9_row4_col5 {
#   background-color: #93d168;
#   color: #000000;
#   text-align: center;
# }
# #T_33fe9_row5_col5 {
#   background-color: #8ecf67;
#   color: #000000;
#   text-align: center;
# }
# #T_33fe9_row6_col5 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_33fe9_row7_col5 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_33fe9_row8_col5 {
#   background-color: #016a38;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_33fe9_row9_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_33fe9">
#   <caption>💧 Top 10 ciclos por consumo — Posición vs KPI DR-041</caption>
#   <thead>
#     <tr>
#       <th id="T_33fe9_level0_col0" class="col_heading level0 col0" >Parcela</th>
#       <th id="T_33fe9_level0_col1" class="col_heading level0 col1" >Ciclo</th>
#       <th id="T_33fe9_level0_col2" class="col_heading level0 col2" >Cultivo</th>
#       <th id="T_33fe9_level0_col3" class="col_heading level0 col3" >Sistema riego</th>
#       <th id="T_33fe9_level0_col4" class="col_heading level0 col4" >Eventos</th>
#       <th id="T_33fe9_level0_col5" class="col_heading level0 col5" >Vol m³/ha/ciclo</th>
#       <th id="T_33fe9_level0_col6" class="col_heading level0 col6" >Ahorro vs 8k (%)</th>
#       <th id="T_33fe9_level0_col7" class="col_heading level0 col7" >Δ vs meta 6k</th>
#       <th id="T_33fe9_level0_col8" class="col_heading level0 col8" >Costo energía (MXN)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_33fe9_row0_col0" class="data row0 col0" >Lote Chi-034</td>
#       <td id="T_33fe9_row0_col1" class="data row0 col1" >OI-2023</td>
#       <td id="T_33fe9_row0_col2" class="data row0 col2" >Chile</td>
#       <td id="T_33fe9_row0_col3" class="data row0 col3" >gravedad</td>
#       <td id="T_33fe9_row0_col4" class="data row0 col4" >15</td>
#       <td id="T_33fe9_row0_col5" class="data row0 col5" >12,067</td>
#       <td id="T_33fe9_row0_col6" class="data row0 col6" >-50.8%</td>
#       <td id="T_33fe9_row0_col7" class="data row0 col7" >+6,067</td>
#       <td id="T_33fe9_row0_col8" class="data row0 col8" >$185,191</td>
#     </tr>
#     <tr>
#       <td id="T_33fe9_row1_col0" class="data row1 col0" >Lote Alg-045</td>
#       <td id="T_33fe9_row1_col1" class="data row1 col1" >PV-2022</td>
#       <td id="T_33fe9_row1_col2" class="data row1 col2" >Maíz</td>
#       <td id="T_33fe9_row1_col3" class="data row1 col3" >gravedad</td>
#       <td id="T_33fe9_row1_col4" class="data row1 col4" >13</td>
#       <td id="T_33fe9_row1_col5" class="data row1 col5" >11,941</td>
#       <td id="T_33fe9_row1_col6" class="data row1 col6" >-49.3%</td>
#       <td id="T_33fe9_row1_col7" class="data row1 col7" >+5,941</td>
#       <td id="T_33fe9_row1_col8" class="data row1 col8" >$123,004</td>
#     </tr>
#     <tr>
#       <td id="T_33fe9_row2_col0" class="data row2 col0" >Lote Uva-064</td>
#       <td id="T_33fe9_row2_col1" class="data row2 col1" >PV-2024</td>
#       <td id="T_33fe9_row2_col2" class="data row2 col2" >Algodón</td>
#       <td id="T_33fe9_row2_col3" class="data row2 col3" >gravedad</td>
#       <td id="T_33fe9_row2_col4" class="data row2 col4" >14</td>
#       <td id="T_33fe9_row2_col5" class="data row2 col5" >11,818</td>
#       <td id="T_33fe9_row2_col6" class="data row2 col6" >-47.7%</td>
#       <td id="T_33fe9_row2_col7" class="data row2 col7" >+5,818</td>
#       <td id="T_33fe9_row2_col8" class="data row2 col8" >$714,967</td>
#     </tr>
#     <tr>
#       <td id="T_33fe9_row3_col0" class="data row3 col0" >Lote Maí-001</td>
#       <td id="T_33fe9_row3_col1" class="data row3 col1" >OI-2024</td>
#       <td id="T_33fe9_row3_col2" class="data row3 col2" >Algodón</td>
#       <td id="T_33fe9_row3_col3" class="data row3 col3" >gravedad</td>
#       <td id="T_33fe9_row3_col4" class="data row3 col4" >10</td>
#       <td id="T_33fe9_row3_col5" class="data row3 col5" >11,496</td>
#       <td id="T_33fe9_row3_col6" class="data row3 col6" >-43.7%</td>
#       <td id="T_33fe9_row3_col7" class="data row3 col7" >+5,496</td>
#       <td id="T_33fe9_row3_col8" class="data row3 col8" >$363,313</td>
#     </tr>
#     <tr>
#       <td id="T_33fe9_row4_col0" class="data row4 col0" >Lote Uva-039</td>
#       <td id="T_33fe9_row4_col1" class="data row4 col1" >OI-2024</td>
#       <td id="T_33fe9_row4_col2" class="data row4 col2" >Maíz</td>
#       <td id="T_33fe9_row4_col3" class="data row4 col3" >gravedad</td>
#       <td id="T_33fe9_row4_col4" class="data row4 col4" >10</td>
#       <td id="T_33fe9_row4_col5" class="data row4 col5" >11,376</td>
#       <td id="T_33fe9_row4_col6" class="data row4 col6" >-42.2%</td>
#       <td id="T_33fe9_row4_col7" class="data row4 col7" >+5,376</td>
#       <td id="T_33fe9_row4_col8" class="data row4 col8" >$323,352</td>
#     </tr>
#     <tr>
#       <td id="T_33fe9_row5_col0" class="data row5 col0" >Lote Fri-026</td>
#       <td id="T_33fe9_row5_col1" class="data row5 col1" >PV-2024</td>
#       <td id="T_33fe9_row5_col2" class="data row5 col2" >Uva</td>
#       <td id="T_33fe9_row5_col3" class="data row5 col3" >gravedad</td>
#       <td id="T_33fe9_row5_col4" class="data row5 col4" >13</td>
#       <td id="T_33fe9_row5_col5" class="data row5 col5" >11,370</td>
#       <td id="T_33fe9_row5_col6" class="data row5 col6" >-42.1%</td>
#       <td id="T_33fe9_row5_col7" class="data row5 col7" >+5,370</td>
#       <td id="T_33fe9_row5_col8" class="data row5 col8" >$358,506</td>
#     </tr>
#     <tr>
#       <td id="T_33fe9_row6_col0" class="data row6 col0" >Lote Chi-025</td>
#       <td id="T_33fe9_row6_col1" class="data row6 col1" >PV-2022</td>
#       <td id="T_33fe9_row6_col2" class="data row6 col2" >Frijol</td>
#       <td id="T_33fe9_row6_col3" class="data row6 col3" >gravedad</td>
#       <td id="T_33fe9_row6_col4" class="data row6 col4" >10</td>
#       <td id="T_33fe9_row6_col5" class="data row6 col5" >11,280</td>
#       <td id="T_33fe9_row6_col6" class="data row6 co
# ▶ Total observaciones: 800 (parcelas × ciclos)
# ▶ Ciclos bajo meta 6,000 m³/ha: 140 de 800 (17.5%)
# ▶ Volumen medio por ciclo: 7,741 m³/ha
# ▶ Ahorro promedio vs baseline 8,000: 3.2%

# %%
# Gráficos KPI hídrico — por ciclo agrícola
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('KPI Hídrico — Historial de Riego DR-041 (por ciclo)', fontsize=15, fontweight='bold')

# (0,0) Bullet chart: consumo por cultivo vs meta vs baseline
ax1 = axes[0, 0]
kpi_cult = kpi.groupby('cultivo')['vol_m3_ha_ciclo'].mean().reset_index()
kpi_cult.columns = ['cultivo', 'm3_ha']
kpi_cult = kpi_cult.sort_values('m3_ha', ascending=True)

y_pos = range(len(kpi_cult))
ax1.barh(y_pos, [BASELINE] * len(kpi_cult), color='#ECECEC', height=0.7)
ax1.barh(y_pos, [META] * len(kpi_cult), color='#A9DFBF', height=0.7)
bar_cols = [VERDE if v <= META else (NARANJA if v <= BASELINE else ROJO)
            for v in kpi_cult['m3_ha']]
ax1.barh(y_pos, kpi_cult['m3_ha'], color=bar_cols, height=0.4)
ax1.axvline(META,     color='#1E8449', linestyle='--', lw=2,
            label=f'Meta: {META:,.0f} m³/ha')
ax1.axvline(BASELINE, color=ROJO, linestyle=':', lw=1.8,
            label=f'Baseline: {BASELINE:,.0f} m³/ha')
for i, v in enumerate(kpi_cult['m3_ha']):
    ax1.text(v + 100, i, f'{v:,.0f}', va='center', fontsize=9)
ax1.set_yticks(list(y_pos))
ax1.set_yticklabels(kpi_cult['cultivo'])
ax1.set_title('Consumo medio por ciclo vs meta hídrica')
ax1.set_xlabel('m³/ha/ciclo')
ax1.legend(fontsize=8)
ax1.set_xlim(0, BASELINE * 1.6)

# (0,1) Distribución de vol_m3_ha_ciclo con líneas de meta y baseline
ax2 = axes[0, 1]
ax2.hist(kpi['vol_m3_ha_ciclo'], bins=30, color=AZUL, edgecolor='white', alpha=0.85)
ax2.axvline(META, color=VERDE, linestyle='--', lw=2, label=f'Meta: {META:,.0f}')
ax2.axvline(BASELINE, color=ROJO, linestyle=':', lw=1.8, label=f'Baseline: {BASELINE:,.0f}')
ax2.axvline(kpi['vol_m3_ha_ciclo'].mean(), color=NARANJA, linestyle='-', lw=2,
            label=f'Media: {kpi["vol_m3_ha_ciclo"].mean():,.0f}')
ax2.set_xlabel('m³/ha/ciclo'); ax2.set_ylabel('Frecuencia')
ax2.set_title('Distribución de consumo por ciclo')
ax2.legend(fontsize=8)

# (1,0) Por sistema de riego — boxplot
ax3 = axes[1, 0]
sistemas = ['gravedad', 'aspersion', 'microaspersion', 'goteo']
bp_data = [kpi.loc[kpi['sistema_riego'] == s, 'vol_m3_ha_ciclo'].dropna().values
           for s in sistemas if s in kpi['sistema_riego'].values]
bp_labels = [s for s in sistemas if s in kpi['sistema_riego'].values]
bp = ax3.boxplot(bp_data, labels=bp_labels, patch_artist=True,
                 medianprops=dict(color='white', lw=2.5), widths=0.5)
sis_pal = sns.color_palette('Set2', len(bp_labels))
for patch, color in zip(bp['boxes'], sis_pal):
    patch.set_facecolor(color); patch.set_alpha(0.85)
ax3.axhline(META, color=VERDE, linestyle='--', lw=1.8, label='Meta 6,000')
ax3.axhline(BASELINE, color=ROJO, linestyle=':', lw=1.5, label='Baseline 8,000')
ax3.set_ylabel('m³/ha/ciclo')
ax3.set_title('Consumo por sistema de riego')
ax3.legend(fontsize=8)

# (1,1) Origen de decisión
ax4 = axes[1, 1]
orig_cnt = historial['origen_decision'].value_counts()
orig_pal = {'sistema': AZUL, 'manual': NARANJA, 'voz': VERDE}
o_colors = [orig_pal.get(o, GRIS) for o in orig_cnt.index]
wedges, texts, autotexts = ax4.pie(
    orig_cnt.values, labels=orig_cnt.index, colors=o_colors,
    autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.65))
for at in autotexts: at.set_fontsize(10); at.set_fontweight('bold')
ax4.set_title('Origen de decisión de riego')

plt.tight_layout()
plt.show()

# %%
# ── KPI por cultivo: resumen de ahorro hídrico por ciclo ────────────────────
kpi_cult_full = (
    kpi.groupby('cultivo').agg(
        n_ciclos=('ciclo_agricola', 'count'),
        vol_medio_m3_ha=('vol_m3_ha_ciclo', 'mean'),
        vol_max_m3_ha=('vol_m3_ha_ciclo', 'max'),
        vol_min_m3_ha=('vol_m3_ha_ciclo', 'min'),
        pct_bajo_meta=('bajo_meta', 'mean'),
        costo_medio_mxn=('costo_ciclo_mxn', 'mean'),
    ).reset_index()
)
kpi_cult_full['ahorro_vs_baseline_pct'] = (
    (BASELINE - kpi_cult_full['vol_medio_m3_ha']) / BASELINE * 100
).round(1)
kpi_cult_full['ahorro_estimado_mxn_ha'] = (
    (BASELINE - kpi_cult_full['vol_medio_m3_ha']) * TARIFA
).round(0)
kpi_cult_full['pct_bajo_meta'] = (kpi_cult_full['pct_bajo_meta'] * 100).round(1)
kpi_cult_full = kpi_cult_full.sort_values('ahorro_vs_baseline_pct', ascending=False)
kpi_cult_full.columns = [
    'Cultivo', 'N° ciclos',
    'Vol. medio (m³/ha/ciclo)', 'Vol. máx', 'Vol. mín',
    '% bajo meta 6k',
    'Costo medio energía (MXN)',
    'Ahorro vs 8k (%)', 'Ahorro estimado (MXN/ha)'
]

display(
    kpi_cult_full.style
    .set_caption('KPI Hídrico por cultivo — m³/ha/ciclo vs baseline DR-041')
    .background_gradient(subset=['Vol. medio (m³/ha/ciclo)'], cmap='RdYlGn_r')
    .background_gradient(subset=['Ahorro vs 8k (%)'], cmap='RdYlGn')
    .background_gradient(subset=['% bajo meta 6k'], cmap='Greens')
    .format({
        'Vol. medio (m³/ha/ciclo)': '{:,.0f}',
        'Vol. máx': '{:,.0f}',
        'Vol. mín': '{:,.0f}',
        '% bajo meta 6k': '{:.1f}%',
        'Costo medio energía (MXN)': '${:,.0f}',
        'Ahorro vs 8k (%)': '{:.1f}%',
        'Ahorro estimado (MXN/ha)': '${:,.0f}',
    })
    .set_properties(**{'text-align': 'center'})
    .set_table_styles([{'selector': 'caption',
                        'props': [('font-size', '14px'), ('font-weight', 'bold')]}])
    .hide(axis='index')
)
# Out:
# <style type="text/css">
# #T_33597 caption {
#   font-size: 14px;
#   font-weight: bold;
# }
# #T_33597_row0_col0, #T_33597_row0_col1, #T_33597_row0_col3, #T_33597_row0_col4, #T_33597_row0_col6, #T_33597_row0_col8, #T_33597_row1_col0, #T_33597_row1_col1, #T_33597_row1_col3, #T_33597_row1_col4, #T_33597_row1_col6, #T_33597_row1_col8, #T_33597_row2_col0, #T_33597_row2_col1, #T_33597_row2_col3, #T_33597_row2_col4, #T_33597_row2_col6, #T_33597_row2_col8, #T_33597_row3_col0, #T_33597_row3_col1, #T_33597_row3_col3, #T_33597_row3_col4, #T_33597_row3_col6, #T_33597_row3_col8, #T_33597_row4_col0, #T_33597_row4_col1, #T_33597_row4_col3, #T_33597_row4_col4, #T_33597_row4_col6, #T_33597_row4_col8 {
#   text-align: center;
# }
# #T_33597_row0_col2, #T_33597_row0_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_33597_row0_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_33597_row1_col2, #T_33597_row1_col7 {
#   background-color: #16914d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_33597_row1_col5 {
#   background-color: #68be70;
#   color: #000000;
#   text-align: center;
# }
# #T_33597_row2_col2 {
#   background-color: #fdc171;
#   color: #000000;
#   text-align: center;
# }
# #T_33597_row2_col5 {
#   background-color: #b1e0ab;
#   color: #000000;
#   text-align: center;
# }
# #T_33597_row2_col7 {
#   background-color: #fdbf6f;
#   color: #000000;
#   text-align: center;
# }
# #T_33597_row3_col2 {
#   background-color: #b30d26;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_33597_row3_col5 {
#   background-color: #e5f5e0;
#   color: #000000;
#   text-align: center;
# }
# #T_33597_row3_col7 {
#   background-color: #af0926;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_33597_row4_col2, #T_33597_row4_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_33597_row4_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_33597">
#   <caption>💰 KPI Hídrico por cultivo — m³/ha/ciclo vs baseline DR-041</caption>
#   <thead>
#     <tr>
#       <th id="T_33597_level0_col0" class="col_heading level0 col0" >Cultivo</th>
#       <th id="T_33597_level0_col1" class="col_heading level0 col1" >N° ciclos</th>
#       <th id="T_33597_level0_col2" class="col_heading level0 col2" >Vol. medio (m³/ha/ciclo)</th>
#       <th id="T_33597_level0_col3" class="col_heading level0 col3" >Vol. máx</th>
#       <th id="T_33597_level0_col4" class="col_heading level0 col4" >Vol. mín</th>
#       <th id="T_33597_level0_col5" class="col_heading level0 col5" >% bajo meta 6k</th>
#       <th id="T_33597_level0_col6" class="col_heading level0 col6" >Costo medio energía (MXN)</th>
#       <th id="T_33597_level0_col7" class="col_heading level0 col7" >Ahorro vs 8k (%)</th>
#       <th id="T_33597_level0_col8" class="col_heading level0 col8" >Ahorro estimado (MXN/ha)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_33597_row0_col0" class="data row0 col0" >Algodón</td>
#       <td id="T_33597_row0_col1" class="data row0 col1" >120</td>
#       <td id="T_33597_row0_col2" class="data row0 col2" >7,524</td>
#       <td id="T_33597_row0_col3" class="data row0 col3" >11,818</td>
#       <td id="T_33597_row0_col4" class="data row0 col4" >3,559</td>
#       <td id="T_33597_row0_col5" class="data row0 col5" >24.2%</td>
#       <td id="T_33597_row0_col6" class="data row0 col6" >$186,386</td>
#       <td id="T_33597_row0_col7" class="data row0 col7" >5.9%</td>
#       <td id="T_33597_row0_col8" class="data row0 col8" >$799</td>
#     </tr>
#     <tr>
#       <td id="T_33597_row1_col0" class="data row1 col0" >Frijol</td>
#       <td id="T_33597_row1_col1" class="data row1 col1" >160</td>
#       <td id="T_33597_row1_col2" class="data row1 col2" >7,557</td>
#       <td id="T_33597_row1_col3" class="data row1 col3" >11,280</td>
#       <td id="T_33597_row1_col4" class="data row1 col4" >3,602</td>
#       <td id="T_33597_row1_col5" class="data row1 col5" >19.4%</td>
#       <td id="T_33597_row1_col6" class="data row1 col6" >$153,744</td>
#       <td id="T_33597_row1_col7" class="data row1 col7" >5.5%</td>
#       <td id="T_33597_row1_col8" class="data row1 col8" >$744</td>
#     </tr>
#     <tr>
#       <td id="T_33597_row2_col0" class="data row2 col0" >Maíz</td>
#       <td id="T_33597_row2_col1" class="data row2 col1" >150</td>
#       <td id="T_33597_row2_col2" class="data row2 col2" >7,764</td>
#       <td id="T_33597_row2_col3" class="data row2 col3" >11,941</td>
#       <td id="T_33597_row2_col4" class="data row2 col4" >3,845</td>
#       <td id="T_33597_row2_col5" class="data row2 col5" >17.3%</td>
#       <td id="T_33597_row2_col6" class="data row2 col6" >$173,412</td>
#       <td id="T_33597_row2_col7" class="data row2 col7" >2.9%</td>
#       <td id="T_33597_row2_col8" class="data row2 col8" >$396</td>
#     </tr>
#     <tr>
#       <td id="T_33597_row3_col0" class="data row3 col0" >Chile</td>
#       <td id="T_33597_row3_col1" class="data row3 col1" >170</td>
#       <td id="T_33597_row3_col2" class="data row3 col2" >7,876</td>
#       <td id="T_33597_row3_col3" class="data row3 col3" >12,067</td>
#       <td id="T_33597_row3_col4" class="data row3 col4" >3,595</td>
#       <td id="T_33597_row3_col5" class="data row3 col5" >15.3%</td>
#       <td id="T_33597_row3_col6" class="data row3 col6" >$151,768</td>
#       <td id="T_33597_row3_col7" class="data row3 col7" >1.5%</td>
#       <td id="T_33597_row3_col8" class="data row3 col8" >$208</td>
#     </tr>
#     <tr>
#       <td id="T_33597_row4_col0" class="data row4 col0" >Uva</td>
#       <td id="T_33597_row4_col1" class="data row4 col1" >200</td>
#       <td id="T_33597_row4_col2" class="data row4 col2" >7,887</td>
#       <td id="T_33597_row4_col3" class="data row4 col3" >11,370</td>
#       <td id="T_33597_row4_col4" class="data row4 col4" >3,687</td>
#       <td id="T_33597_row4_col5" class="data row4 col5" >14.0%</td>
#       <td id="T_33597_row4_col6" class="data row4 col6" >$202,951</td>
#       <td id="T_33597_row4_col7" class="data row4 col7" >1.4%</td>
#       <td id="T_33597_row4_col8" class="data row4 col8" >$190</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# ## 6 · Análisis Económico por Cultivo

# %%
# ── Estructura de costos y márgenes ──────────────────────────────────────────
costos_cols = [
    'costo_agua_mxn', 'costo_fertilizantes_mxn',
    'costo_agroquimicos_mxn', 'costo_semilla_mxn',
    'costo_maquinaria_mxn', 'costo_mano_obra_mxn'
]
costos['costo_total_mxn'] = costos[costos_cols].sum(axis=1)
costos['roi_pct']         = (costos['margen_contribucion_mxn'] / costos['costo_total_mxn'] * 100).round(1)
costos['costo_por_m3']    = (costos['costo_total_mxn'] / costos['volumen_agua_total_m3'].replace(0, np.nan)).round(2)
costos['ingreso_por_m3']  = (costos['ingreso_estimado_mxn'] / costos['volumen_agua_total_m3'].replace(0, np.nan)).round(2)

eco_cult = (
    costos.groupby('cultivo').agg(
        n_ciclos=('id_costo', 'count'),
        ingreso_medio=('ingreso_estimado_mxn', 'mean'),
        costo_medio=('costo_total_mxn', 'mean'),
        margen_medio=('margen_contribucion_mxn', 'mean'),
        roi_medio=('roi_pct', 'mean'),
        costo_agua_pct=('costo_agua_mxn', lambda x: (x / costos.loc[x.index, 'costo_total_mxn']).mean() * 100),
        vol_agua_medio=('volumen_agua_total_m3', 'mean'),
        ingreso_por_m3=('ingreso_por_m3', 'mean'),
    ).reset_index()
    .sort_values('roi_medio', ascending=False)
)
eco_cult.columns = [
    'Cultivo', 'N° ciclos',
    'Ingreso medio (MXN)', 'Costo total medio (MXN)',
    'Margen contrib. medio (MXN)', 'ROI (%)',
    '% costo es agua', 'Vol. agua (m³/ciclo)',
    'Ingreso / m³ (MXN)'
]

display(
    eco_cult.style
    .set_caption('Economía por cultivo — Rentabilidad y eficiencia hídrica')
    .background_gradient(subset=['ROI (%)'], cmap='RdYlGn')
    .background_gradient(subset=['Margen contrib. medio (MXN)'], cmap='Greens')
    .background_gradient(subset=['% costo es agua'], cmap='Blues')
    .background_gradient(subset=['Ingreso / m³ (MXN)'], cmap='YlGn')
    .format({
        'Ingreso medio (MXN)': '${:,.0f}',
        'Costo total medio (MXN)': '${:,.0f}',
        'Margen contrib. medio (MXN)': '${:,.0f}',
        'ROI (%)': '{:.1f}%',
        '% costo es agua': '{:.1f}%',
        'Vol. agua (m³/ciclo)': '{:,.0f}',
        'Ingreso / m³ (MXN)': '${:.2f}',
    })
    .set_properties(**{'text-align': 'center'})
    .set_table_styles([{'selector': 'caption',
                        'props': [('font-size', '14px'), ('font-weight', 'bold')]}])
    .hide(axis='index')
)
# Out:
# <style type="text/css">
# #T_f5d01 caption {
#   font-size: 14px;
#   font-weight: bold;
# }
# #T_f5d01_row0_col0, #T_f5d01_row0_col1, #T_f5d01_row0_col2, #T_f5d01_row0_col3, #T_f5d01_row0_col7, #T_f5d01_row1_col0, #T_f5d01_row1_col1, #T_f5d01_row1_col2, #T_f5d01_row1_col3, #T_f5d01_row1_col7, #T_f5d01_row2_col0, #T_f5d01_row2_col1, #T_f5d01_row2_col2, #T_f5d01_row2_col3, #T_f5d01_row2_col7, #T_f5d01_row3_col0, #T_f5d01_row3_col1, #T_f5d01_row3_col2, #T_f5d01_row3_col3, #T_f5d01_row3_col7, #T_f5d01_row4_col0, #T_f5d01_row4_col1, #T_f5d01_row4_col2, #T_f5d01_row4_col3, #T_f5d01_row4_col7 {
#   text-align: center;
# }
# #T_f5d01_row0_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_f5d01_row0_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_f5d01_row0_col6 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_f5d01_row0_col8 {
#   background-color: #004529;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_f5d01_row1_col4 {
#   background-color: #17813d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_f5d01_row1_col5 {
#   background-color: #75c465;
#   color: #000000;
#   text-align: center;
# }
# #T_f5d01_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
# }
# #T_f5d01_row1_col8 {
#   background-color: #187b3f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_f5d01_row2_col4 {
#   background-color: #aadda4;
#   color: #000000;
#   text-align: center;
# }
# #T_f5d01_row2_col5 {
#   background-color: #fdc171;
#   color: #000000;
#   text-align: center;
# }
# #T_f5d01_row2_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_f5d01_row2_col8 {
#   background-color: #bee596;
#   color: #000000;
#   text-align: center;
# }
# #T_f5d01_row3_col4 {
#   background-color: #f0f9ed;
#   color: #000000;
#   text-align: center;
# }
# #T_f5d01_row3_col5 {
#   background-color: #bb1526;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_f5d01_row3_col6 {
#   background-color: #deebf7;
#   color: #000000;
#   text-align: center;
# }
# #T_f5d01_row3_col8 {
#   background-color: #fcfed6;
#   color: #000000;
#   text-align: center;
# }
# #T_f5d01_row4_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
#   text-align: center;
# }
# #T_f5d01_row4_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_f5d01_row4_col6 {
#   background-color: #d3e3f3;
#   color: #000000;
#   text-align: center;
# }
# #T_f5d01_row4_col8 {
#   background-color: #ffffe5;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_f5d01">
#   <caption>📈 Economía por cultivo — Rentabilidad y eficiencia hídrica</caption>
#   <thead>
#     <tr>
#       <th id="T_f5d01_level0_col0" class="col_heading level0 col0" >Cultivo</th>
#       <th id="T_f5d01_level0_col1" class="col_heading level0 col1" >N° ciclos</th>
#       <th id="T_f5d01_level0_col2" class="col_heading level0 col2" >Ingreso medio (MXN)</th>
#       <th id="T_f5d01_level0_col3" class="col_heading level0 col3" >Costo total medio (MXN)</th>
#       <th id="T_f5d01_level0_col4" class="col_heading level0 col4" >Margen contrib. medio (MXN)</th>
#       <th id="T_f5d01_level0_col5" class="col_heading level0 col5" >ROI (%)</th>
#       <th id="T_f5d01_level0_col6" class="col_heading level0 col6" >% costo es agua</th>
#       <th id="T_f5d01_level0_col7" class="col_heading level0 col7" >Vol. agua (m³/ciclo)</th>
#       <th id="T_f5d01_level0_col8" class="col_heading level0 col8" >Ingreso / m³ (MXN)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f5d01_row0_col0" class="data row0 col0" >Uva</td>
#       <td id="T_f5d01_row0_col1" class="data row0 col1" >162</td>
#       <td id="T_f5d01_row0_col2" class="data row0 col2" >$7,333,600</td>
#       <td id="T_f5d01_row0_col3" class="data row0 col3" >$676,270</td>
#       <td id="T_f5d01_row0_col4" class="data row0 col4" >$6,657,330</td>
#       <td id="T_f5d01_row0_col5" class="data row0 col5" >1019.9%</td>
#       <td id="T_f5d01_row0_col6" class="data row0 col6" >26.3%</td>
#       <td id="T_f5d01_row0_col7" class="data row0 col7" >106,674</td>
#       <td id="T_f5d01_row0_col8" class="data row0 col8" >$77.23</td>
#     </tr>
#     <tr>
#       <td id="T_f5d01_row1_col0" class="data row1 col0" >Chile</td>
#       <td id="T_f5d01_row1_col1" class="data row1 col1" >158</td>
#       <td id="T_f5d01_row1_col2" class="data row1 col2" >$5,901,952</td>
#       <td id="T_f5d01_row1_col3" class="data row1 col3" >$671,613</td>
#       <td id="T_f5d01_row1_col4" class="data row1 col4" >$5,230,339</td>
#       <td id="T_f5d01_row1_col5" class="data row1 col5" >782.7%</td>
#       <td id="T_f5d01_row1_col6" class="data row1 col6" >25.9%</td>
#       <td id="T_f5d01_row1_col7" class="data row1 col7" >103,938</td>
#       <td id="T_f5d01_row1_col8" class="data row1 col8" >$61.80</td>
#     </tr>
#     <tr>
#       <td id="T_f5d01_row2_col0" class="data row2 col0" >Algodón</td>
#       <td id="T_f5d01_row2_col1" class="data row2 col1" >148</td>
#       <td id="T_f5d01_row2_col2" class="data row2 col2" >$2,846,438</td>
#       <td id="T_f5d01_row2_col3" class="data row2 col3" >$680,574</td>
#       <td id="T_f5d01_row2_col4" class="data row2 col4" >$2,165,863</td>
#       <td id="T_f5d01_row2_col5" class="data row2 col5" >324.4%</td>
#       <td id="T_f5d01_row2_col6" class="data row2 col6" >26.6%</td>
#       <td id="T_f5d01_row2_col7" class="data row2 col7" >106,013</td>
#       <td id="T_f5d01_row2_col8" class="data row2 col8" >$28.54</td>
#     </tr>
#     <tr>
#       <td id="T_f5d01_row3_col0" class="data row3 col0" >Maíz</td>
#       <td id="T_f5d01_row3_col1" class="data row3 col1" >166</td>
#       <td id="T_f5d01_row3_col2" class="data row3 col2" >$844,328</td>
#       <td id="T_f5d01_row3_col3" class="data row3 col3" >$721,953</td>
#       <td id="T_f5d01_row3_col4" class="data row3 col4" >$122,375</td>
#       <td id="T_f5d01_row3_col5" class="data row3 col5" >18.6%</td>
#       <td id="T_f5d01_row3_col6" class="data row3 col6" >26.0%</td>
#       <td id="T_f5d01_row3_col7" class="data row3 col7" >111,078</td>
#       <td id="T_f5d01_row3_col8" class="data row3 col8" >$8.23</td>
#     </tr>
#     <tr>
#       <td id="T_f5d01_row4_col0" class="data row4 col0" >Frijol</td>
#       <td id="T_f5d01_row4_col1" class="data row4 col1" >166</td>
#       <td id="T_f5d01_row4_col2" class="data row4 col2" >$483,947</td>
#       <td id="T_f5d01_row4_col3" class="data row4 col3" >$683,002</td>
#       <td id="T_f5d01_row4_col4" class="data row4 col4" >$-199,055</td>
#       <td id="T_f5d01_row4_col5" class="data row4 col5" >-28.3%</td>
#       <td id="T_f5d01_row4_col6" class="data row4 col6" >26.0%</td>
#       <td id="T_f5d01_row4_col7" class="data row4 col7" >107,947</td>
#       <td id="T_f5d01_row4_col8" class="data row4 col8" >$4.96</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Gráficos económicos
fig, axes = plt.subplots(1, 3, figsize=(16, 5))
fig.suptitle('Análisis Económico por Cultivo — MILPÍN DR-041', fontsize=14, fontweight='bold')

# Panel 1: Estructura de costos (stacked 100%)
ax1 = axes[0]
cost_breakdown = costos.groupby('cultivo')[costos_cols].mean()
cost_pct = cost_breakdown.div(cost_breakdown.sum(axis=1), axis=0) * 100
cost_cols_labels = ['Agua', 'Fertilizantes', 'Agroquímicos', 'Semilla', 'Maquinaria', 'Mano de obra']
cost_pal = ['#2980B9', '#27AE60', '#E74C3C', '#F39C12', '#8E44AD', '#5D6D7E']
bottom = np.zeros(len(cost_pct))
for col, lbl, col_c in zip(costos_cols, cost_cols_labels, cost_pal):
    vals = cost_pct[col].values
    ax1.bar(cost_pct.index, vals, bottom=bottom, label=lbl, color=col_c, edgecolor='white', width=0.6)
    bottom += vals
ax1.set_ylabel('% del costo total'); ax1.set_title('Estructura de costos (100%)')
ax1.tick_params(axis='x', rotation=20)
ax1.legend(fontsize=7, loc='lower right')

# Panel 2: ROI por cultivo
ax2 = axes[1]
roi_data = costos.groupby('cultivo')['roi_pct'].mean().sort_values(ascending=True)
roi_colors = [VERDE if v >= 0 else ROJO for v in roi_data.values]
bars2 = ax2.barh(roi_data.index, roi_data.values, color=roi_colors, height=0.5, edgecolor='white')
ax2.bar_label(bars2, fmt='%.0f%%', fontsize=9, padding=3)
ax2.axvline(0, color='black', lw=1.2)
ax2.set_xlabel('ROI (%)')
ax2.set_title('ROI medio por cultivo')

# Panel 3: Ingreso / m³ vs vol. agua (eficiencia hídrica económica)
ax3 = axes[2]
eco_scatter = costos.groupby('cultivo').agg(
    vol_medio=('volumen_agua_total_m3', 'mean'),
    ing_m3=('ingreso_por_m3', 'mean')
).reset_index()
for _, row in eco_scatter.iterrows():
    c = CULTIVO_COLORS.get(row['cultivo'], GRIS)
    ax3.scatter(row['vol_medio'], row['ing_m3'], color=c, s=150,
                edgecolors='white', linewidths=1.5, zorder=3)
    ax3.annotate(row['cultivo'], (row['vol_medio'], row['ing_m3']),
                 textcoords='offset points', xytext=(8, 4), fontsize=9)
ax3.set_xlabel('Volumen de agua promedio (m³/ciclo)')
ax3.set_ylabel('Ingreso / m³ (MXN)')
ax3.set_title('Eficiencia hídrica económica')
ax3.axhline(costos['ingreso_por_m3'].mean(), color=GRIS, linestyle='--',
            lw=1.2, label=f'Media: ${costos["ingreso_por_m3"].mean():.2f}/m³')
ax3.legend(fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 7 · Hallazgos Clave

# %%
# ── Compilar hallazgos cuantitativos (ahora por ciclo) ──────────────────────
vol_global_medio = kpi['vol_m3_ha_ciclo'].mean()
ahorro_pct_global = (BASELINE - vol_global_medio) / BASELINE * 100
parcelas_salinas_n = (parcelas['conductividad_electrica'] > 4).sum()
tasa_aceptacion_global = (recomend['aceptada'] == 'aceptada').mean() * 100
tasa_ignorada_global   = (recomend['aceptada'] == 'ignorada').mean() * 100
bajo_meta_n = kpi['bajo_meta'].sum()
n_obs = len(kpi)
cultivo_mayor_roi = costos.groupby('cultivo')['roi_pct'].mean().idxmax()
cultivo_mayor_roi_val = costos.groupby('cultivo')['roi_pct'].mean().max()
cultivo_mas_agua = kpi.groupby('cultivo')['vol_m3_ha_ciclo'].mean().idxmax()
pct_gravedad = (parcelas['sistema_riego'] == 'gravedad').mean() * 100
pct_voz = (historial['origen_decision'] == 'voz').mean() * 100
pct_critico = (recomend['nivel_urgencia'] == 'crítico').mean() * 100

# Media por sistema de riego
vol_por_sistema = kpi.groupby('sistema_riego')['vol_m3_ha_ciclo'].mean()
vol_goteo = vol_por_sistema.get('goteo', 0)
vol_gravedad = vol_por_sistema.get('gravedad', 0)

hallazgos = pd.DataFrame([
    {'Categoría': 'KPI Hídrico',
     'Hallazgo': f'Volumen medio: {vol_global_medio:,.0f} m³/ha/ciclo',
     'Interpretación': f'{ahorro_pct_global:+.1f}% vs baseline 8,000. '
                       f'{"Debajo" if vol_global_medio <= BASELINE else "Encima"} del baseline'},

    {'Categoría': ' KPI Hídrico',
     'Hallazgo': f'Ciclos bajo meta 6k: {bajo_meta_n}/{n_obs} ({bajo_meta_n/n_obs*100:.1f}%)',
     'Interpretación': f'Casi la mitad de parcelas×ciclo ya cumplen la meta — '
                       f'el sistema tiene potencial de generalizar esto al 100%'},

    {'Categoría': ' KPI Hídrico',
     'Hallazgo': f'Goteo: {vol_goteo:,.0f} vs Gravedad: {vol_gravedad:,.0f} m³/ha/ciclo',
     'Interpretación': f'Diferencia de {vol_gravedad - vol_goteo:,.0f} m³/ha — '
                       f'cambio de sistema es la palanca más fuerte'},

    {'Categoría': 'Agronómico',
     'Hallazgo': f'Mayor riesgo hídrico: Maíz (Ky={cult.loc[cult.nombre_comun=="Maíz","ky_total"].values[0]})',
     'Interpretación': 'Mayor sensibilidad al déficit: pérdida proporcional de rendimiento'},

    {'Categoría': 'Agronómico',
     'Hallazgo': f'Mayor demanda hídrica por ciclo: {cultivo_mas_agua}',
     'Interpretación': 'Candidato prioritario para optimización de riego'},

    {'Categoría': 'Suelo',
     'Hallazgo': f'Estrés salino activo: {parcelas_salinas_n}/{len(parcelas)} ({parcelas_salinas_n/len(parcelas)*100:.0f}%)',
     'Interpretación': 'CE > 4 dS/m — reducción de rendimiento activa'},

    {'Categoría': 'Suelo',
     'Hallazgo': f'Riego por gravedad: {pct_gravedad:.0f}% de parcelas',
     'Interpretación': 'Sistema menos eficiente — potencial de mejora con goteo/aspersión'},

    {'Categoría': 'Sistema',
     'Hallazgo': f'Tasa aceptación: {tasa_aceptacion_global:.1f}% (ignoradas: {tasa_ignorada_global:.1f}%)',
     'Interpretación': 'Loop feedback→BD aún no activo — deuda conocida'},

    {'Categoría': 'Sistema',
     'Hallazgo': f'Decisiones por voz: {pct_voz:.1f}%',
     'Interpretación': 'Pipeline Whisper→Ollama activo en ~20% de decisiones'},

    {'Categoría': 'Economía',
     'Hallazgo': f'Mayor ROI: {cultivo_mayor_roi} ({cultivo_mayor_roi_val:.0f}%)',
     'Interpretación': 'Cultivo más rentable por peso invertido'},
])

def color_categoria(val):
    paleta = {
        ' KPI Hídrico': '#13354E',
        ' Agronómico': '#104727',
        ' Suelo': '#553A11',
        'Sistema': '#391D59',
        'Economía': '#656510',
    }
    return f'background-color: {paleta.get(val, "")}; font-weight: bold'

display(
    hallazgos.style
    .set_caption('Hallazgos Clave — EDA MILPÍN v2.0 (métricas por ciclo agrícola)')
    .applymap(color_categoria, subset=['Categoría'])
    .set_properties(**{'text-align': 'left', 'white-space': 'pre-wrap'})
    .set_table_styles([
        {'selector': 'caption', 'props': [('font-size', '15px'), ('font-weight', 'bold')]},
        {'selector': 'td', 'props': [('padding', '8px 12px'), ('line-height', '1.5')]},
        {'selector': 'th', 'props': [('background-color', '#2C3E50'), ('color', 'white'),
                                      ('padding', '8px 12px'), ('text-align', 'center')]},
    ])
    .hide(axis='index')
)
# Out:
# <style type="text/css">
# #T_cacff caption {
#   font-size: 15px;
#   font-weight: bold;
# }
# #T_cacff td {
#   padding: 8px 12px;
#   line-height: 1.5;
# }
# #T_cacff th {
#   background-color: #2C3E50;
#   color: white;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_cacff_row0_col0, #T_cacff_row1_col0, #T_cacff_row2_col0 {
#   background-color: #13354E;
#   font-weight: bold;
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_cacff_row0_col1, #T_cacff_row0_col2, #T_cacff_row1_col1, #T_cacff_row1_col2, #T_cacff_row2_col1, #T_cacff_row2_col2, #T_cacff_row3_col1, #T_cacff_row3_col2, #T_cacff_row4_col1, #T_cacff_row4_col2, #T_cacff_row5_col1, #T_cacff_row5_col2, #T_cacff_row6_col1, #T_cacff_row6_col2, #T_cacff_row7_col1, #T_cacff_row7_col2, #T_cacff_row8_col1, #T_cacff_row8_col2, #T_cacff_row9_col1, #T_cacff_row9_col2 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_cacff_row3_col0, #T_cacff_row4_col0 {
#   background-color: #104727;
#   font-weight: bold;
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_cacff_row5_col0, #T_cacff_row6_col0 {
#   background-color: #553A11;
#   font-weight: bold;
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_cacff_row7_col0, #T_cacff_row8_col0 {
#   background-color: #391D59;
#   font-weight: bold;
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_cacff_row9_col0 {
#   background-color: #656510;
#   font-weight: bold;
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_cacff">
#   <caption>Hallazgos Clave — EDA MILPÍN v2.0 (métricas por ciclo agrícola)</caption>
#   <thead>
#     <tr>
#       <th id="T_cacff_level0_col0" class="col_heading level0 col0" >Categoría</th>
#       <th id="T_cacff_level0_col1" class="col_heading level0 col1" >Hallazgo</th>
#       <th id="T_cacff_level0_col2" class="col_heading level0 col2" >Interpretación</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cacff_row0_col0" class="data row0 col0" >💧 KPI Hídrico</td>
#       <td id="T_cacff_row0_col1" class="data row0 col1" >Volumen medio: 7,741 m³/ha/ciclo</td>
#       <td id="T_cacff_row0_col2" class="data row0 col2" >+3.2% vs baseline 8,000. Debajo del baseline</td>
#     </tr>
#     <tr>
#       <td id="T_cacff_row1_col0" class="data row1 col0" >💧 KPI Hídrico</td>
#       <td id="T_cacff_row1_col1" class="data row1 col1" >Ciclos bajo meta 6k: 140/800 (17.5%)</td>
#       <td id="T_cacff_row1_col2" class="data row1 col2" >Casi la mitad de parcelas×ciclo ya cumplen la meta — el sistema tiene potencial de generalizar esto al 100%</td>
#     </tr>
#     <tr>
#       <td id="T_cacff_row2_col0" class="data row2 col0" >💧 KPI Hídrico</td>
#       <td id="T_cacff_row2_col1" class="data row2 col1" >Goteo: 5,719 vs Gravedad: 8,714 m³/ha/ciclo</td>
#       <td id="T_cacff_row2_col2" class="data row2 col2" >Diferencia de 2,995 m³/ha — cambio de sistema es la palanca más fuerte</td>
#     </tr>
#     <tr>
#       <td id="T_cacff_row3_col0" class="data row3 col0" >🌾 Agronómico</td>
#       <td id="T_cacff_row3_col1" class="data row3 col1" >Mayor riesgo hídrico: Maíz (Ky=1.25)</td>
#       <td id="T_cacff_row3_col2" class="data row3 col2" >Mayor sensibilidad al déficit: pérdida proporcional de rendimiento</td>
#     </tr>
#     <tr>
#       <td id="T_cacff_row4_col0" class="data row4 col0" >🌾 Agronómico</td>
#       <td id="T_cacff_row4_col1" class="data row4 col1" >Mayor demanda hídrica por ciclo: Uva</td>
#       <td id="T_cacff_row4_col2" class="data row4 col2" >Candidato prioritario para optimización de riego</td>
#     </tr>
#     <tr>
#       <td id="T_cacff_row5_col0" class="data row5 col0" >🏜 Suelo</td>
#       <td id="T_cacff_row5_col1" class="data row5 col1" >Estrés salino activo: 11/80 (14%)</td>
#       <td id="T_cacff_row5_col2" class="data row5 col2" >CE > 4 dS/m — reducción de rendimiento activa</td>
#     </tr>
#     <tr>
#       <td id="T_cacff_row6_col0" class="data row6 col0" >🏜 Suelo</td>
#       <td id="T_cacff_row6_col1" class="data row6 col1" >Riego por gravedad: 61% de parcelas</td>
#       <td id="T_cacff_row6_col2" class="data row6 col2" >Sistema menos eficiente — potencial de mejora con goteo/aspersión</td>
#     </tr>
#     <tr>
#       <td id="T_cacff_row7_col0" class="data row7 col0" >Sistema</td>
#       <td id="T_cacff_row7_col1" class="data row7 col1" >Tasa aceptación: 54.8% (ignoradas: 10.1%)</td>
#       <td id="T_cacff_row7_col2" class="data row7 col2" >Loop feedback→BD aún no activo — deuda conocida</td>
#     </tr>
#     <tr>
#       <td id="T_cacff_row8_col0" class="data row8 col0" >Sistema</td>
#       <td id="T_cacff_row8_col1" class="data row8 col1" >Decisiones por voz: 19.9%</td>
#       <td id="T_cacff_row8_col2" class="data row8 col2" >Pipeline Whisper→Ollama activo en ~20% de decisiones</td>
#     </tr>
#     <tr>
#       <td id="T_cacff_row9_col0" class="data row9 col0" >Economía</td>
#       <td id="T_cacff_row9_col1" class="data row9 col1" >Mayor ROI: Uva (1020%)</td>
#       <td id="T_cacff_row9_col2" class="data row9 col2" >Cultivo más rentable por peso invertido</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# ## 8 · Histogramas — Distribución de Variables Clave

# %%
from scipy.stats import gaussian_kde

hist_groups = {
    'Parcelas': {
        'df': parcelas,
        'cols':   ['area_ha', 'conductividad_electrica',
                   'profundidad_raiz_cm', 'agua_disponible_mm'],
        'labels': ['Superficie (ha)', 'CE (dS/m)',
                   'Prof. raíz (cm)', 'Agua disponible (mm)'],
        'colors': [AZUL, ROJO, VERDE, NARANJA],
    },
    'Historial de riego': {
        'df': historial,
        'cols':   ['volumen_m3_ha', 'lamina_mm', 'costo_energia_mxn'],
        'labels': ['Volumen m³/ha (evento)', 'Lámina aplicada (mm)',
                   'Costo energía por evento (MXN)'],
        'colors': [AZUL, VERDE, NARANJA],
    },
    'Recomendaciones FAO-56': {
        'df': recomend,
        'cols':   ['lamina_recomendada_mm', 'eto_referencia',
                   'etc_calculada', 'deficit_acumulado_mm'],
        'labels': ['Lámina recomendada (mm)', 'ETo referencia',
                   'ETc calculada', 'Déficit acumulado (mm)'],
        'colors': [AZUL, VERDE, ROJO, NARANJA],
    },
}

for grupo, cfg in hist_groups.items():
    ncols = len(cfg['cols'])
    fig, axes = plt.subplots(1, ncols, figsize=(4.5 * ncols, 4.2))
    if ncols == 1:
        axes = [axes]
    fig.suptitle(f'Histogramas — {grupo}', fontsize=13, fontweight='bold')

    for ax, col, lbl, color in zip(axes, cfg['cols'], cfg['labels'], cfg['colors']):
        s = cfg['df'][col].dropna()
        ax.hist(s, bins=25, color=color, edgecolor='white', alpha=0.80)
        xs = np.linspace(s.min(), s.max(), 300)
        kde = gaussian_kde(s)
        ax_r = ax.twinx()
        ax_r.plot(xs, kde(xs), color='black', lw=1.8, alpha=0.65)
        ax_r.set_yticks([])
        ax.axvline(s.mean(),   color='#E74C3C', lw=1.8, linestyle='--',
                   label=f'Media: {s.mean():.2f}')
        ax.axvline(s.median(), color='#8E44AD', lw=1.8, linestyle=':',
                   label=f'Mediana: {s.median():.2f}')
        ax.set_title(lbl, fontsize=10)
        ax.set_xlabel(lbl, fontsize=9)
        ax.set_ylabel('Frecuencia')
        ax.legend(fontsize=7)
        ax.text(0.98, 0.96, f'Asimetría: {s.skew():.2f}',
                transform=ax.transAxes, ha='right', va='top',
                fontsize=8, color='gray')

    plt.tight_layout()
    plt.show()
    print()

# %% [markdown]
# ---
# ## 9 · Heatmaps — Correlaciones y Patrones Temporales

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Heatmaps — MILPÍN DR-041', fontsize=14, fontweight='bold')

# (a) Correlación variables edáficas de parcelas
ax1 = axes[0]
num_cols_parc = ['area_ha', 'conductividad_electrica',
                 'profundidad_raiz_cm', 'capacidad_campo',
                 'punto_marchitez', 'agua_disponible_mm']
corr_parc = parcelas[num_cols_parc].corr()
corr_labels_p = ['Sup.(ha)', 'CE(dS/m)', 'Prof.raíz',
                 'Cap.campo', 'Pto.march.', 'ADT(mm)']
sns.heatmap(corr_parc, ax=ax1, annot=True, fmt='.2f', cmap='RdBu_r',
            center=0, vmin=-1, vmax=1, linewidths=0.5,
            xticklabels=corr_labels_p, yticklabels=corr_labels_p,
            annot_kws={'size': 8}, square=True,
            cbar_kws={'shrink': 0.7})
ax1.set_title('Correlación — Variables edáficas\n(parcelas)', fontsize=11)
ax1.tick_params(axis='x', rotation=40, labelsize=8)
ax1.tick_params(axis='y', rotation=0,  labelsize=8)

# (b) Volumen mensual por cultivo
ax2 = axes[1]
hist_m = historial.merge(parcelas[['id_parcela', 'cultivo']],
                         on='id_parcela', how='left')
hist_m['mes_str'] = hist_m['fecha_riego'].dt.strftime('%Y-%m')
pivot_vol = (hist_m.groupby(['mes_str', 'cultivo'])['volumen_m3_ha']
             .mean().unstack(fill_value=0))
if len(pivot_vol) > 12:
    pivot_vol = pivot_vol.tail(12)
sns.heatmap(pivot_vol, ax=ax2, cmap='YlOrRd', annot=True, fmt='.0f',
            linewidths=0.4, annot_kws={'size': 7},
            cbar_kws={'shrink': 0.7, 'label': 'm³/ha'})
ax2.set_title('Volumen medio m³/ha\npor mes y cultivo', fontsize=11)
ax2.set_xlabel('Cultivo'); ax2.set_ylabel('Mes')
ax2.tick_params(axis='x', rotation=25, labelsize=9)
ax2.tick_params(axis='y', rotation=0,  labelsize=8)

# (c) Tasa de aceptación por cultivo × urgencia
ax3 = axes[2]
pivot_acept = (recomend.groupby(['cultivo', 'nivel_urgencia'])['aceptada']
               .apply(lambda x: round((x == 'aceptada').mean() * 100, 1))
               .unstack(fill_value=0))
urg_order = [c for c in ['crítico', 'moderado', 'preventivo']
             if c in pivot_acept.columns]
pivot_acept = pivot_acept[urg_order]
sns.heatmap(pivot_acept, ax=ax3, cmap='RdYlGn', annot=True, fmt='.1f',
            vmin=0, vmax=100, linewidths=0.5,
            annot_kws={'size': 10, 'weight': 'bold'},
            cbar_kws={'shrink': 0.7, 'label': '% aceptadas'})
ax3.set_title('Tasa de aceptación (%)\npor cultivo × urgencia', fontsize=11)
ax3.set_xlabel('Urgencia'); ax3.set_ylabel('Cultivo')
ax3.tick_params(axis='x', rotation=15, labelsize=9)
ax3.tick_params(axis='y', rotation=0,  labelsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 10 · Ingeniería de Características — Dataset para ML
#
# Se construye un DataFrame a nivel **parcela × ciclo** con features agregadas
# de los cuatro datasets, listo para modelos supervisados.
#
# | Target | Tipo | Unidad |
# |---|---|---|
# | `vol_m3_ha_ciclo` | Regresión | m³/ha por ciclo |
# | `meta_alcanzada` | Clasificación binaria | ≤ 6,000 m³/ha/ciclo |
#
# **Cambio clave vs versión anterior:** la granularidad ahora es parcela×ciclo
# (~800 filas) en vez de parcela (~80 filas), lo que permite:
# - Target balanceado (~45% clase 1)
# - Suficientes observaciones para entrenar modelos
# - Comparación directa contra baseline 8,000 m³/ha/ciclo

# %%
# ══════════════════════════════════════════════════════════════════════════
# FEATURE ENGINEERING — Nivel parcela × ciclo
# ══════════════════════════════════════════════════════════════════════════

# ── Bloque 1: base desde KPI (ya tiene parcela × ciclo) ─────────────────
feat = kpi[[
    'id_parcela', 'ciclo_agricola',
    'eventos_riego', 'vol_m3_ha_ciclo', 'vol_m3_ha_media',
    'lamina_media_mm', 'costo_ciclo_mxn'
]].copy()

# ── Bloque 2: atributos estáticos de parcela ────────────────────────────
parc_cols = parcelas[[
    'id_parcela', 'cultivo', 'area_ha', 'tipo_suelo', 'sistema_riego',
    'conductividad_electrica', 'profundidad_raiz_cm',
    'capacidad_campo', 'punto_marchitez', 'agua_disponible_mm'
]].copy()

parc_cols['stress_salino'] = (parc_cols['conductividad_electrica'] > 4).astype(int)
parc_cols['stress_hidrico'] = (
    parc_cols['agua_disponible_mm'] < parc_cols['agua_disponible_mm'].quantile(0.25)
).astype(int)
parc_cols['stress_doble'] = (
    parc_cols['stress_salino'] & parc_cols['stress_hidrico']
).astype(int)
parc_cols['cap_almacen_relativa'] = (
    (parc_cols['capacidad_campo'] - parc_cols['punto_marchitez'])
    / parc_cols['capacidad_campo']
).round(4)

eff_map = {'goteo': 0.90, 'aspersion': 0.75, 'microaspersion': 0.80, 'gravedad': 0.55}
parc_cols['eficiencia_riego'] = parc_cols['sistema_riego'].map(eff_map).fillna(0.65)

feat = feat.merge(parc_cols, on='id_parcela', how='left')

# ── Bloque 3: variabilidad intra-ciclo del riego ────────────────────────
h_var = (
    historial.groupby(['id_parcela', 'ciclo_agricola']).agg(
        vol_m3_ha_std  = ('volumen_m3_ha', 'std'),
        lamina_cv      = ('lamina_mm',
                          lambda x: x.std() / x.mean() if x.mean() > 0 else 0),
    ).reset_index()
)
h_var['vol_m3_ha_std'] = h_var['vol_m3_ha_std'].fillna(0)
feat = feat.merge(h_var, on=['id_parcela', 'ciclo_agricola'], how='left')

# ── Bloque 4: recomendaciones (agregadas por parcela, no por ciclo,
#    porque recomendaciones no tienen ciclo_agricola) ─────────────────────
r_feats = (
    recomend.groupby('id_parcela').agg(
        n_recomendaciones   = ('id_recomendacion',     'count'),
        tasa_aceptacion     = ('aceptada',
                               lambda x: (x == 'aceptada').mean()),
        tasa_ignorada       = ('aceptada',
                               lambda x: (x == 'ignorada').mean()),
        eto_media           = ('eto_referencia',       'mean'),
        etc_media           = ('etc_calculada',        'mean'),
        deficit_acum_medio  = ('deficit_acumulado_mm', 'mean'),
        lamina_rec_media_mm = ('lamina_recomendada_mm','mean'),
        pct_critico         = ('nivel_urgencia',
                               lambda x: (x == 'crítico').mean()),
        pct_moderado        = ('nivel_urgencia',
                               lambda x: (x == 'moderado').mean()),
    ).reset_index()
)
r_feats['ratio_etc_eto'] = (
    r_feats['etc_media'] / r_feats['eto_media'].replace(0, np.nan)
).round(4)
feat = feat.merge(r_feats, on='id_parcela', how='left')

# ── Bloque 5: costos económicos por ciclo ────────────────────────────────
c_feats = (
    costos.groupby(['id_parcela', 'ciclo_agricola']).agg(
        roi_ciclo            = ('roi_pct',                'mean'),
        margen_ciclo_mxn     = ('margen_contribucion_mxn','sum'),
        ingreso_ciclo_mxn    = ('ingreso_estimado_mxn',   'sum'),
    ).reset_index()
)
feat = feat.merge(c_feats, on=['id_parcela', 'ciclo_agricola'], how='left')

# ── Bloque 6: parámetros FAO-56 del catálogo ────────────────────────────
cult_join = cult[['nombre_comun', 'kc_ponderado', 'ky_total',
                  'ciclo_total_dias']].rename(columns={'nombre_comun': 'cultivo'})
feat = feat.merge(cult_join, on='cultivo', how='left')

# ── Bloque 7: variables objetivo ─────────────────────────────────────────
feat['meta_alcanzada']       = (feat['vol_m3_ha_ciclo'] <= 6000).astype(int)
feat['ahorro_potencial_m3']  = (8000 - feat['vol_m3_ha_ciclo']).clip(lower=0)
feat['ahorro_potencial_mxn'] = feat['ahorro_potencial_m3'] * 1.68

# ── Bloque 8: encoding de categóricas ────────────────────────────────────
feat_encoded = pd.get_dummies(
    feat, columns=['cultivo', 'tipo_suelo', 'sistema_riego'],
    prefix=['cult', 'suelo', 'riego'], drop_first=False, dtype=int
)

print(f'✓ Dataset ML base:    {feat.shape[0]} filas × {feat.shape[1]} columnas')
print(f'✓ Dataset codificado: {feat_encoded.shape[0]} filas × {feat_encoded.shape[1]} columnas')
print()
print('▶ Balance target (meta_alcanzada):')
print(feat['meta_alcanzada']
      .value_counts(normalize=True)
      .rename({0: 'No alcanzada (0)', 1: 'Alcanzada (1)'})
      .map('{:.1%}'.format))
print()
nulls = feat.isnull().sum()
nulls_pos = nulls[nulls > 0]
if len(nulls_pos):
    print('▶ Nulos en dataset ML:')
    print(nulls_pos.to_string())
else:
    print('▶ Nulos en dataset ML: ninguno')
# Out:
# ✓ Dataset ML base:    800 filas × 42 columnas
# ✓ Dataset codificado: 800 filas × 54 columnas
#
# ▶ Balance target (meta_alcanzada):
# meta_alcanzada
# No alcanzada (0)    82.5%
# Alcanzada (1)       17.5%
# Name: proportion, dtype: object
#
# ▶ Nulos en dataset ML: ninguno

# %% [markdown]
# ---
# ## 11 · DataFrame ML — Vista del Dataset Construido

# %%
# ── (a) Muestra estilizada ──────────────────────────────────────────────────
cols_show = [
    'id_parcela', 'ciclo_agricola', 'cultivo', 'sistema_riego',
    'area_ha', 'conductividad_electrica', 'agua_disponible_mm',
    'stress_salino', 'eficiencia_riego',
    'eventos_riego', 'vol_m3_ha_ciclo',
    'tasa_aceptacion', 'pct_critico',
    'kc_ponderado', 'ky_total',
    'meta_alcanzada', 'ahorro_potencial_mxn'
]
col_alias = [
    'ID Parcela', 'Ciclo', 'Cultivo', 'Sist. riego',
    'Área (ha)', 'CE (dS/m)', 'ADT (mm)',
    'Estrés sal.', 'Efic. riego',
    'N° eventos', 'Vol m³/ha/ciclo',
    'Tasa acept.', '% Crítico',
    'Kc pond.', 'Ky total',
    'Meta alcanzada', 'Ahorro pot. (MXN)'
]

muestra = feat[cols_show].head(15).copy().reset_index(drop=True)
muestra.columns = col_alias

def _hl_target(v):
    if v == 1:
        return 'background-color:#D5F5E3;color:#1E8449;font-weight:bold'
    return 'background-color:#FADBD8;color:#C0392B;font-weight:bold'

def _hl_stress(v):
    return 'background-color:#FADBD8;font-weight:bold' if v == 1 else ''

display(
    muestra.style
    .set_caption('🤖 Dataset ML — Primeras 15 filas (parcela × ciclo)')
    .applymap(_hl_target, subset=['Meta alcanzada'])
    .applymap(_hl_stress, subset=['Estrés sal.'])
    .background_gradient(subset=['Vol m³/ha/ciclo'], cmap='RdYlGn_r')
    .background_gradient(subset=['Ahorro pot. (MXN)'], cmap='Greens')
    .format({
        'Área (ha)':       '{:.1f}',
        'CE (dS/m)':       '{:.2f}',
        'ADT (mm)':        '{:.1f}',
        'Efic. riego':     '{:.2f}',
        'Vol m³/ha/ciclo': '{:,.0f}',
        'Tasa acept.':     '{:.0%}',
        '% Crítico':       '{:.0%}',
        'Kc pond.':        '{:.3f}',
        'Ky total':        '{:.2f}',
        'Ahorro pot. (MXN)': '${:,.0f}',
    })
    .set_properties(**{'text-align': 'center', 'font-size': '10px'})
    .set_table_styles([{'selector': 'caption',
                        'props': [('font-size', '14px'), ('font-weight', 'bold')]}])
    .hide(axis='index')
)

# ── (b) Estadísticas descriptivas ───────────────────────────────────────────
num_cols_desc = [
    'area_ha', 'conductividad_electrica', 'agua_disponible_mm',
    'eficiencia_riego', 'eventos_riego', 'vol_m3_ha_ciclo',
    'tasa_aceptacion', 'pct_critico',
    'kc_ponderado', 'ky_total',
    'meta_alcanzada', 'ahorro_potencial_mxn'
]
num_cols_desc = [c for c in num_cols_desc if c in feat.columns]
desc_ml = feat[num_cols_desc].describe().T

display(
    desc_ml.style
    .set_caption('Estadísticas descriptivas — Dataset ML (parcela × ciclo)')
    .background_gradient(subset=['mean'], cmap='Blues')
    .background_gradient(subset=['std'],  cmap='Oranges')
    .format('{:.3f}')
    .format('{:.0f}', subset=['count'])
    .set_table_styles([{'selector': 'caption',
                        'props': [('font-size', '14px'), ('font-weight', 'bold')]}])
)

# ── (c) Heatmap de correlación entre features ML y el target ────────────────
num_feats_ml = [
    'area_ha', 'conductividad_electrica', 'agua_disponible_mm',
    'eficiencia_riego', 'cap_almacen_relativa',
    'eventos_riego', 'lamina_media_mm', 'lamina_cv',
    'tasa_aceptacion', 'deficit_acum_medio', 'pct_critico',
    'kc_ponderado', 'ky_total',
    'stress_salino', 'stress_doble',
    'vol_m3_ha_ciclo'
]
num_feats_ml = [c for c in num_feats_ml if c in feat.columns]
corr_ml = feat[num_feats_ml].corr()

fig, ax = plt.subplots(figsize=(14, 11))
sns.heatmap(
    corr_ml, ax=ax, annot=True, fmt='.2f', cmap='RdBu_r',
    center=0, vmin=-1, vmax=1, linewidths=0.3,
    annot_kws={'size': 7},
    xticklabels=[c.replace('_', '\n') for c in corr_ml.columns],
    yticklabels=[c.replace('_', ' ') for c in corr_ml.index],
    square=True, cbar_kws={'shrink': 0.6}
)
ax.set_title(
    'Matriz de correlación — Features ML\n'
    '(última fila/columna = vol_m3_ha_ciclo)',
    fontsize=12, fontweight='bold'
)
ax.tick_params(axis='x', rotation=45, labelsize=8)
ax.tick_params(axis='y', rotation=0,  labelsize=8)
plt.tight_layout()
plt.show()

# ── (d) Ranking de correlación con el target ─────────────────────────────────
target_corr = (
    corr_ml['vol_m3_ha_ciclo']
    .drop('vol_m3_ha_ciclo')
    .rename('corr')
    .reset_index()
    .rename(columns={'index': 'Feature'})
)
target_corr['|corr|'] = target_corr['corr'].abs()
target_corr['Dir.']   = target_corr['corr'].apply(
    lambda v: '+ (directa)' if v >= 0 else '− (inversa)'
)
target_corr = target_corr.sort_values('|corr|', ascending=False).reset_index(drop=True)
target_corr.columns = ['Feature', 'Correlación', '|Correlación|', 'Dirección']

display(
    target_corr.style
    .set_caption('Features por correlación absoluta con vol_m3_ha_ciclo')
    .background_gradient(subset=['|Correlación|'], cmap='Blues')
    .bar(subset=['Correlación'], color=[VERDE, ROJO], align='zero', vmin=-1, vmax=1)
    .format({'Correlación': '{:+.3f}', '|Correlación|': '{:.3f}'})
    .set_properties(**{'text-align': 'center'})
    .set_table_styles([{'selector': 'caption',
                        'props': [('font-size', '13px'), ('font-weight', 'bold')]}])
    .hide(axis='index')
)
# Out:
# <style type="text/css">
# #T_0160f caption {
#   font-size: 14px;
#   font-weight: bold;
# }
# #T_0160f_row0_col0, #T_0160f_row0_col1, #T_0160f_row0_col2, #T_0160f_row0_col3, #T_0160f_row0_col4, #T_0160f_row0_col5, #T_0160f_row0_col6, #T_0160f_row0_col8, #T_0160f_row0_col9, #T_0160f_row0_col11, #T_0160f_row0_col12, #T_0160f_row0_col13, #T_0160f_row0_col14, #T_0160f_row1_col0, #T_0160f_row1_col1, #T_0160f_row1_col2, #T_0160f_row1_col3, #T_0160f_row1_col4, #T_0160f_row1_col5, #T_0160f_row1_col6, #T_0160f_row1_col8, #T_0160f_row1_col9, #T_0160f_row1_col11, #T_0160f_row1_col12, #T_0160f_row1_col13, #T_0160f_row1_col14, #T_0160f_row2_col0, #T_0160f_row2_col1, #T_0160f_row2_col2, #T_0160f_row2_col3, #T_0160f_row2_col4, #T_0160f_row2_col5, #T_0160f_row2_col6, #T_0160f_row2_col8, #T_0160f_row2_col9, #T_0160f_row2_col11, #T_0160f_row2_col12, #T_0160f_row2_col13, #T_0160f_row2_col14, #T_0160f_row3_col0, #T_0160f_row3_col1, #T_0160f_row3_col2, #T_0160f_row3_col3, #T_0160f_row3_col4, #T_0160f_row3_col5, #T_0160f_row3_col6, #T_0160f_row3_col8, #T_0160f_row3_col9, #T_0160f_row3_col11, #T_0160f_row3_col12, #T_0160f_row3_col13, #T_0160f_row3_col14, #T_0160f_row4_col0, #T_0160f_row4_col1, #T_0160f_row4_col2, #T_0160f_row4_col3, #T_0160f_row4_col4, #T_0160f_row4_col5, #T_0160f_row4_col6, #T_0160f_row4_col8, #T_0160f_row4_col9, #T_0160f_row4_col11, #T_0160f_row4_col12, #T_0160f_row4_col13, #T_0160f_row4_col14, #T_0160f_row5_col0, #T_0160f_row5_col1, #T_0160f_row5_col2, #T_0160f_row5_col3, #T_0160f_row5_col4, #T_0160f_row5_col5, #T_0160f_row5_col6, #T_0160f_row5_col8, #T_0160f_row5_col9, #T_0160f_row5_col11, #T_0160f_row5_col12, #T_0160f_row5_col13, #T_0160f_row5_col14, #T_0160f_row6_col0, #T_0160f_row6_col1, #T_0160f_row6_col2, #T_0160f_row6_col3, #T_0160f_row6_col4, #T_0160f_row6_col5, #T_0160f_row6_col6, #T_0160f_row6_col8, #T_0160f_row6_col9, #T_0160f_row6_col11, #T_0160f_row6_col12, #T_0160f_row6_col13, #T_0160f_row6_col14, #T_0160f_row7_col0, #T_0160f_row7_col1, #T_0160f_row7_col2, #T_0160f_row7_col3, #T_0160f_row7_col4, #T_0160f_row7_col5, #T_0160f_row7_col6, #T_0160f_row7_col8, #T_0160f_row7_col9, #T_0160f_row7_col11, #T_0160f_row7_col12, #T_0160f_row7_col13, #T_0160f_row7_col14, #T_0160f_row8_col0, #T_0160f_row8_col1, #T_0160f_row8_col2, #T_0160f_row8_col3, #T_0160f_row8_col4, #T_0160f_row8_col5, #T_0160f_row8_col6, #T_0160f_row8_col8, #T_0160f_row8_col9, #T_0160f_row8_col11, #T_0160f_row8_col12, #T_0160f_row8_col13, #T_0160f_row8_col14, #T_0160f_row9_col0, #T_0160f_row9_col1, #T_0160f_row9_col2, #T_0160f_row9_col3, #T_0160f_row9_col4, #T_0160f_row9_col5, #T_0160f_row9_col6, #T_0160f_row9_col8, #T_0160f_row9_col9, #T_0160f_row9_col11, #T_0160f_row9_col12, #T_0160f_row9_col13, #T_0160f_row9_col14, #T_0160f_row10_col0, #T_0160f_row10_col1, #T_0160f_row10_col2, #T_0160f_row10_col3, #T_0160f_row10_col4, #T_0160f_row10_col5, #T_0160f_row10_col6, #T_0160f_row10_col7, #T_0160f_row10_col8, #T_0160f_row10_col9, #T_0160f_row10_col11, #T_0160f_row10_col12, #T_0160f_row10_col13, #T_0160f_row10_col14, #T_0160f_row11_col0, #T_0160f_row11_col1, #T_0160f_row11_col2, #T_0160f_row11_col3, #T_0160f_row11_col4, #T_0160f_row11_col5, #T_0160f_row11_col6, #T_0160f_row11_col7, #T_0160f_row11_col8, #T_0160f_row11_col9, #T_0160f_row11_col11, #T_0160f_row11_col12, #T_0160f_row11_col13, #T_0160f_row11_col14, #T_0160f_row12_col0, #T_0160f_row12_col1, #T_0160f_row12_col2, #T_0160f_row12_col3, #T_0160f_row12_col4, #T_0160f_row12_col5, #T_0160f_row12_col6, #T_0160f_row12_col7, #T_0160f_row12_col8, #T_0160f_row12_col9, #T_0160f_row12_col11, #T_0160f_row12_col12, #T_0160f_row12_col13, #T_0160f_row12_col14, #T_0160f_row13_col0, #T_0160f_row13_col1, #T_0160f_row13_col2, #T_0160f_row13_col3, #T_0160f_row13_col4, #T_0160f_row13_col5, #T_0160f_row13_col6, #T_0160f_row13_col7, #T_0160f_row13_col8, #T_0160f_row13_col9, #T_0160f_row13_col11, #T_0160f_row13_col12, #T_0160f_row13_col13, #T_0160f_row13_col14, #T_0160f_row14_col0, #T_0160f_row14_col1, #T_0160f_row14_col2, #T_0160f_row14_col3, #T_0160f_row14_col4, #T_0160f_row14_col5, #T_0160f_row14_col6, #T_0160f_row14_col7,  ...
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row0_col7, #T_0160f_row1_col7, #T_0160f_row2_col7, #T_0160f_row3_col7, #T_0160f_row4_col7, #T_0160f_row5_col7, #T_0160f_row6_col7, #T_0160f_row7_col7, #T_0160f_row8_col7, #T_0160f_row9_col7 {
#   background-color: #FADBD8;
#   font-weight: bold;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row0_col10 {
#   background-color: #e2f397;
#   color: #000000;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row0_col15, #T_0160f_row1_col15, #T_0160f_row2_col15, #T_0160f_row3_col15, #T_0160f_row4_col15, #T_0160f_row5_col15, #T_0160f_row6_col15, #T_0160f_row7_col15, #T_0160f_row8_col15, #T_0160f_row9_col15, #T_0160f_row10_col15, #T_0160f_row11_col15, #T_0160f_row12_col15, #T_0160f_row13_col15, #T_0160f_row14_col15 {
#   background-color: #FADBD8;
#   color: #C0392B;
#   font-weight: bold;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row0_col16, #T_0160f_row1_col16, #T_0160f_row3_col16, #T_0160f_row4_col16, #T_0160f_row6_col16, #T_0160f_row8_col16, #T_0160f_row9_col16, #T_0160f_row10_col16, #T_0160f_row11_col16, #T_0160f_row12_col16 {
#   background-color: #f7fcf5;
#   color: #000000;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row1_col10 {
#   background-color: #fba05b;
#   color: #000000;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row2_col10 {
#   background-color: #006837;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row2_col16 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row3_col10 {
#   background-color: #f26841;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row4_col10 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row5_col10 {
#   background-color: #2da155;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row5_col16 {
#   background-color: #73c476;
#   color: #000000;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row6_col10 {
#   background-color: #ee613e;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row7_col10 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row7_col16 {
#   background-color: #acdea6;
#   color: #000000;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row8_col10 {
#   background-color: #b9e176;
#   color: #000000;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row9_col10 {
#   background-color: #e3f399;
#   color: #000000;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row10_col10 {
#   background-color: #a90426;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row11_col10 {
#   background-color: #d22b27;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row12_col10 {
#   background-color: #ddf191;
#   color: #000000;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row13_col10 {
#   background-color: #84ca66;
#   color: #000000;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row13_col16 {
#   background-color: #f3faf0;
#   color: #000000;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row14_col10 {
#   background-color: #30a356;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 10px;
# }
# #T_0160f_row14_col16 {
#   background-color: #79c67a;
#   color: #000000;
#   text-align: center;
#   font-size: 10px;
# }
# </style>
# <table id="T_0160f">
#   <caption>🤖 Dataset ML — Primeras 15 filas (parcela × ciclo)</caption>
#   <thead>
#     <tr>
#       <th id="T_0160f_level0_col0" class="col_heading level0 col0" >ID Parcela</th>
#       <th id="T_0160f_level0_col1" class="col_heading level0 col1" >Ciclo</th>
#       <th id="T_0160f_level0_col2" class="col_heading level0 col2" >Cultivo</th>
#       <th id="T_0160f_level0_col3" class="col_heading level0 col3" >Sist. riego</th>
#       <th id="
# <style type="text/css">
# #T_0fe23 caption {
#   font-size: 14px;
#   font-weight: bold;
# }
# #T_0fe23_row0_col1, #T_0fe23_row1_col1, #T_0fe23_row3_col1, #T_0fe23_row4_col1, #T_0fe23_row6_col1, #T_0fe23_row7_col1, #T_0fe23_row8_col1, #T_0fe23_row9_col1, #T_0fe23_row10_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0fe23_row0_col2, #T_0fe23_row1_col2, #T_0fe23_row3_col2, #T_0fe23_row4_col2, #T_0fe23_row6_col2, #T_0fe23_row7_col2, #T_0fe23_row8_col2, #T_0fe23_row9_col2, #T_0fe23_row10_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_0fe23_row2_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_0fe23_row2_col2 {
#   background-color: #fff0e1;
#   color: #000000;
# }
# #T_0fe23_row5_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0fe23_row5_col2 {
#   background-color: #993103;
#   color: #f1f1f1;
# }
# #T_0fe23_row11_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_0fe23_row11_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0fe23">
#   <caption>📊 Estadísticas descriptivas — Dataset ML (parcela × ciclo)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fe23_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_0fe23_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_0fe23_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_0fe23_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_0fe23_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_0fe23_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_0fe23_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_0fe23_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fe23_level0_row0" class="row_heading level0 row0" >area_ha</th>
#       <td id="T_0fe23_row0_col0" class="data row0 col0" >800</td>
#       <td id="T_0fe23_row0_col1" class="data row0 col1" >13.354</td>
#       <td id="T_0fe23_row0_col2" class="data row0 col2" >6.598</td>
#       <td id="T_0fe23_row0_col3" class="data row0 col3" >5.118</td>
#       <td id="T_0fe23_row0_col4" class="data row0 col4" >8.801</td>
#       <td id="T_0fe23_row0_col5" class="data row0 col5" >11.739</td>
#       <td id="T_0fe23_row0_col6" class="data row0 col6" >16.642</td>
#       <td id="T_0fe23_row0_col7" class="data row0 col7" >34.987</td>
#     </tr>
#     <tr>
#       <th id="T_0fe23_level0_row1" class="row_heading level0 row1" >conductividad_electrica</th>
#       <td id="T_0fe23_row1_col0" class="data row1 col0" >800</td>
#       <td id="T_0fe23_row1_col1" class="data row1 col1" >2.549</td>
#       <td id="T_0fe23_row1_col2" class="data row1 col2" >1.556</td>
#       <td id="T_0fe23_row1_col3" class="data row1 col3" >1.010</td>
#       <td id="T_0fe23_row1_col4" class="data row1 col4" >1.620</td>
#       <td id="T_0fe23_row1_col5" class="data row1 col5" >2.105</td>
#       <td id="T_0fe23_row1_col6" class="data row1 col6" >2.708</td>
#       <td id="T_0fe23_row1_col7" class="data row1 col7" >7.860</td>
#     </tr>
#     <tr>
#       <th id="T_0fe23_level0_row2" class="row_heading level0 row2" >agua_disponible_mm</th>
#       <td id="T_0fe23_row2_col0" class="data row2 col0" >800</td>
#       <td id="T_0fe23_row2_col1" class="data row2 col1" >159.888</td>
#       <td id="T_0fe23_row2_col2" class="data row2 col2" >84.896</td>
#       <td id="T_0fe23_row2_col3" class="data row2 col3" >26.319</td>
#       <td id="T_0fe23_row2_col4" class="data row2 col4" >91.675</td>
#       <td id="T_0fe23_row2_col5" class="data row2 col5" >156.786</td>
#       <td id="T_0fe23_row2_col6" class="data row2 col6" >212.859</td>
#       <td id="T_0fe23_row2_col7" class="data row2 col7" >416.179</td>
#     </tr>
#     <tr>
#       <th id="T_0fe23_level0_row3" class="row_heading level0 row3" >eficiencia_riego</th>
#       <td id="T_0fe23_row3_col0" class="data row3 col0" >800</td>
#       <td id="T_0fe23_row3_col1" class="data row3 col1" >0.644</td>
#       <td id="T_0fe23_row3_col2" class="data row3 col2" >0.123</td>
#       <td id="T_0fe23_row3_col3" class="data row3 col3" >0.550</td>
#       <td id="T_0fe23_row3_col4" class="data row3 col4" >0.550</td>
#       <td id="T_0fe23_row3_col5" class="data row3 col5" >0.550</td>
#       <td id="T_0fe23_row3_col6" class="data row3 col6" >0.750</td>
#       <td id="T_0fe23_row3_col7" class="data row3 col7" >0.900</td>
#     </tr>
#     <tr>
#       <th id="T_0fe23_level0_row4" class="row_heading level0 row4" >eventos_riego</th>
#       <td id="T_0fe23_row4_col0" class="data row4 col0" >800</td>
#       <td id="T_0fe23_row4_col1" class="data row4 col1" >14.161</td>
#       <td id="T_0fe23_row4_col2" class="data row4 col2" >4.426</td>
#       <td id="T_0fe23_row4_col3" class="data row4 col3" >8.000</td>
#       <td id="T_0fe23_row4_col4" class="data row4 col4" >11.000</td>
#       <td id="T_0fe23_row4_col5" class="data row4 col5" >14.000</td>
#       <td id="T_0fe23_row4_col6" class="data row4 col6" >17.000</td>
#       <td id="T_0fe23_row4_col7" class="data row4 col7" >29.000</td>
#     </tr>
#     <tr>
#       <th id="T_0fe23_level0_row5" class="row_heading level0 row5" >vol_m3_ha_ciclo</th>
#       <td id="T_0fe23_row5_col0" class="data row5 col0" >800</td>
#       <td id="T_0fe23_row5_col1" class="data row5 col1" >7741.310</td>
#       <td id="T_0fe23_row5_col2" class="data row5 col2" >1701.963</td>
#       <td id="T_0fe23_row5_col3" class="data row5 col3" >3558.660</td>
#       <td id="T_0fe23_row5_col4" class="data row5 col4" >6408.540</td>
#       <td id="T_0fe23_row5_col5" class="data row5 col5" >7891.025</td>
#       <td id="T_0fe23_row5_col6" class="data row5 col6" >9019.702</td>
#       <td id="T_0fe23_row5_col7" class="data row5 col7" >12067.290</td>
#     </tr>
#     <tr>
#       <th id="T_0fe23_level0_row6" class="row_heading level0 row6" >tasa_aceptacion</th>
#       <td id="T_0fe23_row6_col0" class="data row6 col0" >800</td>
#       <td id="T_0fe23_row6_col1" class="data row6 col1" >0.548</td>
#       <td id="T_0fe23_row6_col2" class="data row6 col2" >0.029</td>
#       <td id="T_0fe23_row6_col3" class="data row6 col3" >0.488</td>
#       <td id="T_0fe23_row6_col4" class="data row6 col4" >0.526</td>
#       <td id="T_0fe23_row6_col5" class="data row6 col5" >0.546</td>
#       <td id="T_0fe23_row6_col6" class="data row6 col6" >0.569</td>
#       <td id="T_0fe23_row6_col7" class="data row6 col7" >0.615</td>
#     </tr>
#     <tr>
#       <th id="T_0fe23_level0_row7" class="row_heading level0 row7" >pct_critico</th>
#       <td id="T_0fe23_row7_col0" class="data row7 col0" >800</td>
#       <td id="T_0fe23_row7_col1" class="data row7 col1" >0.000</td>
#       <td id="T_0fe23_row7_col2" class="data row7 col2" >0.000</td>
#       <td id="T_0fe23_row7_col3" class="data row7 col3" >0.000</td>
#       <td id="T_0fe23_row7_col4" class="data row7 col4" >0.000</td>
#       <td id="T_0fe23_row7_col5" class="data row7 col5" >0.000</td>
#       <td id="T_0fe23_row7_col6" class="data row7 col6" >0.000</td>
#       <td id="T_0fe23_row7_col7" class="data row7 col7" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_0fe23_level0_row8" class="row_heading level0 row8" >kc_ponderado</th>
#       <td id="T_0fe23_row8_col0" class="data row8 col0" >800</td>
#       <td id="T_0fe23_row8_col1" class="data row8 col1" >0.839</td>
#       <td id="T_0fe23_row8_col2" class="data row8 col2" >0.108</td>
#       <td id="T_0fe23_row8_col3" class="data row8 col3" >0.660</td>
#       <td id="T_0fe23_row8_col4" class="data row8 col4" >0.795</td>
#       <td id="T_0fe23_row8_col5" class="data row8 col5" >0.900</td>
#       <td id="T_0fe23_row8_col6" class="data row8 col6" >0.930</td>
#       <td id="T_0fe23_row8_col7" class="data row8 col7" >0.930</td>
#     </tr>
#     <tr>
#       <th id="T_0fe23_level0_row9" class="row_heading level0 row9" >ky_total</th>
#       <td id="T_0fe23_row9_col0" class="data row9 col0" >800</td>
#       <td id="T_0fe23_row9_col1" class="data row9 col1" >1.038</td>
#       <td id="T_0fe23_row9_col2" class="data row9 col2" >0.161</td>
#       <td id="T_0fe23_row9_c
# <style type="text/css">
# #T_37193 caption {
#   font-size: 13px;
#   font-weight: bold;
# }
# #T_37193_row0_col0, #T_37193_row0_col3, #T_37193_row1_col0, #T_37193_row1_col3, #T_37193_row2_col0, #T_37193_row2_col3, #T_37193_row3_col0, #T_37193_row3_col3, #T_37193_row4_col0, #T_37193_row4_col3, #T_37193_row5_col0, #T_37193_row5_col3, #T_37193_row6_col0, #T_37193_row6_col3, #T_37193_row7_col0, #T_37193_row7_col3, #T_37193_row8_col0, #T_37193_row8_col3, #T_37193_row9_col0, #T_37193_row9_col3, #T_37193_row10_col0, #T_37193_row10_col3, #T_37193_row11_col0, #T_37193_row11_col3, #T_37193_row12_col0, #T_37193_row12_col3, #T_37193_row13_col0, #T_37193_row13_col3, #T_37193_row14_col0, #T_37193_row14_col3 {
#   text-align: center;
# }
# #T_37193_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #C0392B 50.0%, #C0392B 90.5%, transparent 90.5%);
#   text-align: center;
# }
# #T_37193_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_37193_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 14.1%, #27AE60 14.1%, #27AE60 50.0%, transparent 50.0%);
#   text-align: center;
# }
# #T_37193_row1_col2 {
#   background-color: #084e98;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_37193_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.9%, #27AE60 20.9%, #27AE60 50.0%, transparent 50.0%);
#   text-align: center;
# }
# #T_37193_row2_col2 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_37193_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 42.5%, #27AE60 42.5%, #27AE60 50.0%, transparent 50.0%);
#   text-align: center;
# }
# #T_37193_row3_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
#   text-align: center;
# }
# #T_37193_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.2%, #27AE60 44.2%, #27AE60 50.0%, transparent 50.0%);
#   text-align: center;
# }
# #T_37193_row4_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
#   text-align: center;
# }
# #T_37193_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.0%, #27AE60 47.0%, #27AE60 50.0%, transparent 50.0%);
#   text-align: center;
# }
# #T_37193_row5_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
#   text-align: center;
# }
# #T_37193_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.0%, #27AE60 48.0%, #27AE60 50.0%, transparent 50.0%);
#   text-align: center;
# }
# #T_37193_row6_col2 {
#   background-color: #eef5fc;
#   color: #000000;
#   text-align: center;
# }
# #T_37193_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.2%, #27AE60 48.2%, #27AE60 50.0%, transparent 50.0%);
#   text-align: center;
# }
# #T_37193_row7_col2, #T_37193_row8_col2, #T_37193_row9_col2 {
#   background-color: #eff6fc;
#   color: #000000;
#   text-align: center;
# }
# #T_37193_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #C0392B 50.0%, #C0392B 51.8%, transparent 51.8%);
#   text-align: center;
# }
# #T_37193_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.3%, #27AE60 48.3%, #27AE60 50.0%, transparent 50.0%);
#   text-align: center;
# }
# #T_37193_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #C0392B 50.0%, #C0392B 51.1%, transparent 51.1%);
#   text-align: center;
# }
# #T_37193_row10_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
#   text-align: center;
# }
# #T_37193_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #C0392B 50.0%, #C0392B 50.7%, transparent 50.7%);
#   text-align: center;
# }
# #T_37193_row11_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
#   text-align: center;
# }
# #T_37193_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.6%, #27AE60 49.6%, #27AE60 50.0%, transparent 50.0%);
#   text-align: center;
# }
# #T_37193_row12_col2 {
#   background-color: #f5fafe;
#   color: #000000;
#   text-align: center;
# }
# #T_37193_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.9%, #27AE60 49.9%, #27AE60 50.0%, transparent 50.0%);
#   text-align: center;
# }
# #T_37193_row13_col2 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
# }
# #T_37193_row14_col1 {
#   width: 10em;
#   text-align: center;
# }
# #T_37193_row14_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_37193">
#   <caption>🎯 Features por correlación absoluta con vol_m3_ha_ciclo</caption>
#   <thead>
#     <tr>
#       <th id="T_37193_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_37193_level0_col1" class="col_heading level0 col1" >Correlación</th>
#       <th id="T_37193_level0_col2" class="col_heading level0 col2" >|Correlación|</th>
#       <th id="T_37193_level0_col3" class="col_heading level0 col3" >Dirección</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_37193_row0_col0" class="data row0 col0" >lamina_media_mm</td>
#       <td id="T_37193_row0_col1" class="data row0 col1" >+0.810</td>
#       <td id="T_37193_row0_col2" class="data row0 col2" >0.810</td>
#       <td id="T_37193_row0_col3" class="data row0 col3" >+ (directa)</td>
#     </tr>
#     <tr>
#       <td id="T_37193_row1_col0" class="data row1 col0" >eficiencia_riego</td>
#       <td id="T_37193_row1_col1" class="data row1 col1" >-0.718</td>
#       <td id="T_37193_row1_col2" class="data row1 col2" >0.718</td>
#       <td id="T_37193_row1_col3" class="data row1 col3" >− (inversa)</td>
#     </tr>
#     <tr>
#       <td id="T_37193_row2_col0" class="data row2 col0" >eventos_riego</td>
#       <td id="T_37193_row2_col1" class="data row2 col1" >-0.582</td>
#       <td id="T_37193_row2_col2" class="data row2 col2" >0.582</td>
#       <td id="T_37193_row2_col3" class="data row2 col3" >− (inversa)</td>
#     </tr>
#     <tr>
#       <td id="T_37193_row3_col0" class="data row3 col0" >stress_salino</td>
#       <td id="T_37193_row3_col1" class="data row3 col1" >-0.150</td>
#       <td id="T_37193_row3_col2" class="data row3 col2" >0.150</td>
#       <td id="T_37193_row3_col3" class="data row3 col3" >− (inversa)</td>
#     </tr>
#     <tr>
#       <td id="T_37193_row4_col0" class="data row4 col0" >conductividad_electrica</td>
#       <td id="T_37193_row4_col1" class="data row4 col1" >-0.115</td>
#       <td id="T_37193_row4_col2" class="data row4 col2" >0.115</td>
#       <td id="T_37193_row4_col3" class="data row4 col3" >− (inversa)</td>
#     </tr>
#     <tr>
#       <td id="T_37193_row5_col0" class="data row5 col0" >tasa_aceptacion</td>
#       <td id="T_37193_row5_col1" class="data row5 col1" >-0.059</td>
#       <td id="T_37193_row5_col2" class="data row5 col2" >0.059</td>
#       <td id="T_37193_row5_col3" class="data row5 col3" >− (inversa)</td>
#     </tr>
#     <tr>
#       <td id="T_37193_row6_col0" class="data row6 col0" >deficit_acum_medio</td>
#       <td id="T_37193_row6_col1" class="data row6 col1" >-0.039</td>
#       <td id="T_37193_row6_col2" class="data row6 col2" >0.039</td>
#       <td id="T_37193_row6_col3" class="data row6 col3" >− (inversa)</td>
#     </tr>
#     <tr>
#       <td id="T_37193_row7_col0" class="data row7 col0" >kc_ponderado</td>
#       <td id="T_37193_row7_col1" class="data row7 col1" >-0.036</td>
#       <td id="T_37193_row7_col2" class="data row7 col2" >0.036</td>
#       <td id="T_37193_row7_col3" class="data row7 col3" >− (inversa)</td>
#     </tr>
#     <tr>
#       <td id="T_37193_row8_col0" class="data row8 col0" >stress_doble</td>
#       <td id="T_37193_row8_col1" class="data row8 col1" >+0.036</td>
#       <td id="T_37193_row8_col2" class="data row8 col2" >0.036</td>
#       <td id="T_37193_row8_col3" class="data row8 col3" >+ (directa)</td>
#     </tr>
#     <tr>
#       <td id="T_37193_row9_col0" class="data row9 col0" >lamina_cv</td>
#       <td id="T_37193_row9_col1" class="data row9 col1" >-0.034</td>
#       <td id="T_37193_row9_col2" class="data row9 col2" >0.034</td>
#       <td id="T_37193_row9_col3" class="data row9 col3" >− (inversa)</td>
#     </tr>
#     <tr>
#       <td id="T_37193_row10_col0" class="data row10 col0" >area_ha</td>

# %% [markdown]
# ---
# ## 12 · Vista Completa de Todos los Datasets
#
# Exploración de cada tabla completa — todas las columnas, todas las filas disponibles
# (con scroll horizontal). Útil para verificar calidad de datos y entender la
# estructura real de cada dataset antes de modelar.

# %%
# ══════════════════════════════════════════════════════════════════════════════
# SECCIÓN 12 — DataFrames completos de los 6 datasets
# ══════════════════════════════════════════════════════════════════════════════

from IPython.display import display, HTML

def mostrar_dataset(nombre, df, max_rows=None, caption_extra=''):
    """Muestra un dataset completo con estilo MILPÍN."""
    df_show = df if max_rows is None else df.head(max_rows)
    n_total = len(df)
    n_show  = len(df_show)
    
    titulo = (
        f"📋 {nombre} — {n_total:,} filas × {df.shape[1]} columnas"
        + (f" | mostrando {n_show}" if n_show < n_total else "")
        + (f" | {caption_extra}" if caption_extra else "")
    )
    
    # Detectar columnas numéricas para formato
    num_cols = df_show.select_dtypes(include='number').columns.tolist()
    
    styler = (
        df_show.reset_index(drop=True).style
        .set_caption(titulo)
        .set_properties(**{'text-align': 'center', 'font-size': '10px',
                           'white-space': 'nowrap'})
        .set_table_styles([
            {'selector': 'caption',
             'props': [('font-size', '13px'), ('font-weight', 'bold'),
                       ('color', '#2C3E50'), ('text-align', 'left'),
                       ('padding', '8px 0')]},
            {'selector': 'th',
             'props': [('background-color', '#2C3E50'), ('color', 'white'),
                       ('padding', '6px 10px'), ('font-size', '10px'),
                       ('white-space', 'nowrap')]},
            {'selector': 'td',
             'props': [('padding', '5px 10px'), ('border-bottom', '1px solid #eee')]},
            {'selector': 'tr:nth-child(even)',
             'props': [('background-color', '#F8F9FA')]},
            {'selector': 'tr:hover',
             'props': [('background-color', '#EBF5FB')]},
        ])
    )
    if num_cols:
        styler = styler.format(
            {c: ('{:.2f}' if df_show[c].dtype == float else '{:,}')
             for c in num_cols},
            na_rep='—'
        )
    display(styler.hide(axis='index'))
    print()

print("=" * 70)
print("INVENTARIO COMPLETO DE DATOS — MILPÍN v2.0")
print("=" * 70)
print()

# 1. Usuarios
mostrar_dataset("👤 Usuarios", usuarios, caption_extra="agricultores del sistema")

# 2. Catálogo de cultivos
mostrar_dataset("🌾 Catálogo de Cultivos FAO-56", cultivos,
                caption_extra="parámetros agronómicos oficiales")

# 3. Parcelas (sin columna geom que es larga)
parc_display = parcelas.drop(columns=[c for c in ['geom'] if c in parcelas.columns], errors='ignore')
mostrar_dataset("🗺 Parcelas", parc_display,
                caption_extra="perfil edáfico y de riego por unidad")

# 4. Historial de riego — muestra 100 filas (son miles)
mostrar_dataset("💧 Historial de Riego", historial, max_rows=100,
                caption_extra=f"mostrando 100 de {len(historial):,} eventos totales")

# 5. Recomendaciones — muestra 100 filas
rec_display = recomend.drop(columns=['parametros_json'], errors='ignore')
mostrar_dataset("🤖 Recomendaciones FAO-56", rec_display, max_rows=100,
                caption_extra=f"mostrando 100 de {len(recomend):,} recomendaciones")

# 6. Costos por ciclo
mostrar_dataset("💰 Costos por Ciclo Agrícola", costos,
                caption_extra="estructura económica completa")

print("✓ Exploración completa finalizada.")
# Out:
# ======================================================================
# INVENTARIO COMPLETO DE DATOS — MILPÍN v2.0
# ======================================================================
# <style type="text/css">
# #T_0b955 caption {
#   font-size: 13px;
#   font-weight: bold;
#   color: #2C3E50;
#   text-align: left;
#   padding: 8px 0;
# }
# #T_0b955 th {
#   background-color: #2C3E50;
#   color: white;
#   padding: 6px 10px;
#   font-size: 10px;
#   white-space: nowrap;
# }
# #T_0b955 td {
#   padding: 5px 10px;
#   border-bottom: 1px solid #eee;
# }
# #T_0b955 tr:nth-child(even) {
#   background-color: #F8F9FA;
# }
# #T_0b955 tr:hover {
#   background-color: #EBF5FB;
# }
# #T_0b955_row0_col0, #T_0b955_row0_col1, #T_0b955_row0_col2, #T_0b955_row0_col3, #T_0b955_row0_col4, #T_0b955_row0_col5, #T_0b955_row0_col6, #T_0b955_row1_col0, #T_0b955_row1_col1, #T_0b955_row1_col2, #T_0b955_row1_col3, #T_0b955_row1_col4, #T_0b955_row1_col5, #T_0b955_row1_col6, #T_0b955_row2_col0, #T_0b955_row2_col1, #T_0b955_row2_col2, #T_0b955_row2_col3, #T_0b955_row2_col4, #T_0b955_row2_col5, #T_0b955_row2_col6, #T_0b955_row3_col0, #T_0b955_row3_col1, #T_0b955_row3_col2, #T_0b955_row3_col3, #T_0b955_row3_col4, #T_0b955_row3_col5, #T_0b955_row3_col6, #T_0b955_row4_col0, #T_0b955_row4_col1, #T_0b955_row4_col2, #T_0b955_row4_col3, #T_0b955_row4_col4, #T_0b955_row4_col5, #T_0b955_row4_col6, #T_0b955_row5_col0, #T_0b955_row5_col1, #T_0b955_row5_col2, #T_0b955_row5_col3, #T_0b955_row5_col4, #T_0b955_row5_col5, #T_0b955_row5_col6, #T_0b955_row6_col0, #T_0b955_row6_col1, #T_0b955_row6_col2, #T_0b955_row6_col3, #T_0b955_row6_col4, #T_0b955_row6_col5, #T_0b955_row6_col6, #T_0b955_row7_col0, #T_0b955_row7_col1, #T_0b955_row7_col2, #T_0b955_row7_col3, #T_0b955_row7_col4, #T_0b955_row7_col5, #T_0b955_row7_col6, #T_0b955_row8_col0, #T_0b955_row8_col1, #T_0b955_row8_col2, #T_0b955_row8_col3, #T_0b955_row8_col4, #T_0b955_row8_col5, #T_0b955_row8_col6, #T_0b955_row9_col0, #T_0b955_row9_col1, #T_0b955_row9_col2, #T_0b955_row9_col3, #T_0b955_row9_col4, #T_0b955_row9_col5, #T_0b955_row9_col6, #T_0b955_row10_col0, #T_0b955_row10_col1, #T_0b955_row10_col2, #T_0b955_row10_col3, #T_0b955_row10_col4, #T_0b955_row10_col5, #T_0b955_row10_col6, #T_0b955_row11_col0, #T_0b955_row11_col1, #T_0b955_row11_col2, #T_0b955_row11_col3, #T_0b955_row11_col4, #T_0b955_row11_col5, #T_0b955_row11_col6, #T_0b955_row12_col0, #T_0b955_row12_col1, #T_0b955_row12_col2, #T_0b955_row12_col3, #T_0b955_row12_col4, #T_0b955_row12_col5, #T_0b955_row12_col6, #T_0b955_row13_col0, #T_0b955_row13_col1, #T_0b955_row13_col2, #T_0b955_row13_col3, #T_0b955_row13_col4, #T_0b955_row13_col5, #T_0b955_row13_col6, #T_0b955_row14_col0, #T_0b955_row14_col1, #T_0b955_row14_col2, #T_0b955_row14_col3, #T_0b955_row14_col4, #T_0b955_row14_col5, #T_0b955_row14_col6, #T_0b955_row15_col0, #T_0b955_row15_col1, #T_0b955_row15_col2, #T_0b955_row15_col3, #T_0b955_row15_col4, #T_0b955_row15_col5, #T_0b955_row15_col6, #T_0b955_row16_col0, #T_0b955_row16_col1, #T_0b955_row16_col2, #T_0b955_row16_col3, #T_0b955_row16_col4, #T_0b955_row16_col5, #T_0b955_row16_col6, #T_0b955_row17_col0, #T_0b955_row17_col1, #T_0b955_row17_col2, #T_0b955_row17_col3, #T_0b955_row17_col4, #T_0b955_row17_col5, #T_0b955_row17_col6, #T_0b955_row18_col0, #T_0b955_row18_col1, #T_0b955_row18_col2, #T_0b955_row18_col3, #T_0b955_row18_col4, #T_0b955_row18_col5, #T_0b955_row18_col6, #T_0b955_row19_col0, #T_0b955_row19_col1, #T_0b955_row19_col2, #T_0b955_row19_col3, #T_0b955_row19_col4, #T_0b955_row19_col5, #T_0b955_row19_col6 {
#   text-align: center;
#   font-size: 10px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_0b955">
#   <caption>📋 👤 Usuarios — 20 filas × 7 columnas | agricultores del sistema</caption>
#   <thead>
#     <tr>
#       <th id="T_0b955_level0_col0" class="col_heading level0 col0" >id_usuario</th>
#       <th id="T_0b955_level0_col1" class="col_heading level0 col1" >nombre_completo</th>
#       <th id="T_0b955_level0_col2" class="col_heading level0 col2" >email</th>
#       <th id="T_0b955_level0_col3" class="col_heading level0 col3" >telefono</th>
#       <th id="T_0b955_level0_col4" class="col_heading level0 col4" >modulo_dr041</th>
#       <th id="T_0b955_level0_col5" class="col_heading level0 col5" >activo</th>
#       <th id="T_0b955_level0_col6" class="col_heading level0 col6" >created_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0b955_row0_col0" class="data row0 col0" >e3042ed9-f94d-44fd-837a-3574909c7c3a</td>
#       <td id="T_0b955_row0_col1" class="data row0 col1" >Ramón Valenzuela</td>
#       <td id="T_0b955_row0_col2" class="data row0 col2" >ramon.valenzuela000@dr041-dev.com</td>
#       <td id="T_0b955_row0_col3" class="data row0 col3" >526,441,803,258</td>
#       <td id="T_0b955_row0_col4" class="data row0 col4" >Módulo 4</td>
#       <td id="T_0b955_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_0b955_row0_col6" class="data row0 col6" >2025-01-19T07:26:58+00:00</td>
#     </tr>
#     <tr>
#       <td id="T_0b955_row1_col0" class="data row1 col0" >76d6b8b6-fe62-4e13-8cc1-5c952454204f</td>
#       <td id="T_0b955_row1_col1" class="data row1 col1" >María Fernández</td>
#       <td id="T_0b955_row1_col2" class="data row1 col2" >maria.fernandez001@dr041-dev.com</td>
#       <td id="T_0b955_row1_col3" class="data row1 col3" >526,448,727,380</td>
#       <td id="T_0b955_row1_col4" class="data row1 col4" >Módulo 1</td>
#       <td id="T_0b955_row1_col5" class="data row1 col5" >True</td>
#       <td id="T_0b955_row1_col6" class="data row1 col6" >2024-12-19T13:46:58+00:00</td>
#     </tr>
#     <tr>
#       <td id="T_0b955_row2_col0" class="data row2 col0" >40c62692-0dca-41bd-b3c4-d35fbeb21c2e</td>
#       <td id="T_0b955_row2_col1" class="data row2 col1" >Juan Carlos Ortiz</td>
#       <td id="T_0b955_row2_col2" class="data row2 col2" >juan.carlos.ortiz002@dr041-dev.com</td>
#       <td id="T_0b955_row2_col3" class="data row2 col3" >526,445,738,310</td>
#       <td id="T_0b955_row2_col4" class="data row2 col4" >Módulo 5</td>
#       <td id="T_0b955_row2_col5" class="data row2 col5" >True</td>
#       <td id="T_0b955_row2_col6" class="data row2 col6" >2024-11-21T23:08:58+00:00</td>
#     </tr>
#     <tr>
#       <td id="T_0b955_row3_col0" class="data row3 col0" >fb208ded-c677-4dd9-af8f-a1475bdf0b5d</td>
#       <td id="T_0b955_row3_col1" class="data row3 col1" >Luis Miranda</td>
#       <td id="T_0b955_row3_col2" class="data row3 col2" >luis.miranda003@dr041-dev.com</td>
#       <td id="T_0b955_row3_col3" class="data row3 col3" >526,448,074,577</td>
#       <td id="T_0b955_row3_col4" class="data row3 col4" >Módulo 3</td>
#       <td id="T_0b955_row3_col5" class="data row3 col5" >True</td>
#       <td id="T_0b955_row3_col6" class="data row3 col6" >2026-02-01T21:24:58+00:00</td>
#     </tr>
#     <tr>
#       <td id="T_0b955_row4_col0" class="data row4 col0" >fccde31c-28cf-4a9c-ae98-9e4f06b0a707</td>
#       <td id="T_0b955_row4_col1" class="data row4 col1" >Rosa Herrera</td>
#       <td id="T_0b955_row4_col2" class="data row4 col2" >rosa.herrera004@dr041-dev.com</td>
#       <td id="T_0b955_row4_col3" class="data row4 col3" >526,445,503,166</td>
#       <td id="T_0b955_row4_col4" class="data row4 col4" >Módulo 2</td>
#       <td id="T_0b955_row4_col5" class="data row4 col5" >True</td>
#       <td id="T_0b955_row4_col6" class="data row4 col6" >2025-12-24T19:05:58+00:00</td>
#     </tr>
#     <tr>
#       <td id="T_0b955_row5_col0" class="data row5 col0" >198083c7-8365-4efd-902c-48a8e8762e80</td>
#       <td id="T_0b955_row5_col1" class="data row5 col1" >Jesús Soto</td>
#       <td id="T_0b955_row5_col2" class="data row5 col2" >jesus.soto005@dr041-dev.com</td>
#       <td id="T_0b955_row5_col3" class="data row5 col3" >526,446,794,785</td>
#       <td id="T_0b955_row5_col4" class="data row5 col4" >Módulo 3</td>
#       <td id="T_0b955_row5_col5" class="data row5 col5" >True</td>
#       <td id="T_0b955_row5_col6" class="data row5 col6" >2024-09-20T04:25:58+00:00</td>
#     </tr>
#     <tr>
#       <td id="T_0b955_row6_col0" class="data row6 col0" >94da2b6c-9fdb-4fa7-a12a-45f49736e3eb</td>
#       <td id="T_0b955_row6_col1" class="data row6 col1" >Guadalupe Ríos</td>
#       <td id="T_0b955_row6_col2" class="data row6 col2" >guadalupe.rios006@dr041-dev.com</td>
#       <td id="T_0b955_row6_col3" c
# <style type="text/css">
# #T_6c039 caption {
#   font-size: 13px;
#   font-weight: bold;
#   color: #2C3E50;
#   text-align: left;
#   padding: 8px 0;
# }
# #T_6c039 th {
#   background-color: #2C3E50;
#   color: white;
#   padding: 6px 10px;
#   font-size: 10px;
#   white-space: nowrap;
# }
# #T_6c039 td {
#   padding: 5px 10px;
#   border-bottom: 1px solid #eee;
# }
# #T_6c039 tr:nth-child(even) {
#   background-color: #F8F9FA;
# }
# #T_6c039 tr:hover {
#   background-color: #EBF5FB;
# }
# #T_6c039_row0_col0, #T_6c039_row0_col1, #T_6c039_row0_col2, #T_6c039_row0_col3, #T_6c039_row0_col4, #T_6c039_row0_col5, #T_6c039_row0_col6, #T_6c039_row0_col7, #T_6c039_row0_col8, #T_6c039_row0_col9, #T_6c039_row0_col10, #T_6c039_row0_col11, #T_6c039_row1_col0, #T_6c039_row1_col1, #T_6c039_row1_col2, #T_6c039_row1_col3, #T_6c039_row1_col4, #T_6c039_row1_col5, #T_6c039_row1_col6, #T_6c039_row1_col7, #T_6c039_row1_col8, #T_6c039_row1_col9, #T_6c039_row1_col10, #T_6c039_row1_col11, #T_6c039_row2_col0, #T_6c039_row2_col1, #T_6c039_row2_col2, #T_6c039_row2_col3, #T_6c039_row2_col4, #T_6c039_row2_col5, #T_6c039_row2_col6, #T_6c039_row2_col7, #T_6c039_row2_col8, #T_6c039_row2_col9, #T_6c039_row2_col10, #T_6c039_row2_col11, #T_6c039_row3_col0, #T_6c039_row3_col1, #T_6c039_row3_col2, #T_6c039_row3_col3, #T_6c039_row3_col4, #T_6c039_row3_col5, #T_6c039_row3_col6, #T_6c039_row3_col7, #T_6c039_row3_col8, #T_6c039_row3_col9, #T_6c039_row3_col10, #T_6c039_row3_col11, #T_6c039_row4_col0, #T_6c039_row4_col1, #T_6c039_row4_col2, #T_6c039_row4_col3, #T_6c039_row4_col4, #T_6c039_row4_col5, #T_6c039_row4_col6, #T_6c039_row4_col7, #T_6c039_row4_col8, #T_6c039_row4_col9, #T_6c039_row4_col10, #T_6c039_row4_col11 {
#   text-align: center;
#   font-size: 10px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_6c039">
#   <caption>📋 🌾 Catálogo de Cultivos FAO-56 — 5 filas × 12 columnas | parámetros agronómicos oficiales</caption>
#   <thead>
#     <tr>
#       <th id="T_6c039_level0_col0" class="col_heading level0 col0" >id_cultivo</th>
#       <th id="T_6c039_level0_col1" class="col_heading level0 col1" >nombre_comun</th>
#       <th id="T_6c039_level0_col2" class="col_heading level0 col2" >nombre_cientifico</th>
#       <th id="T_6c039_level0_col3" class="col_heading level0 col3" >kc_inicial</th>
#       <th id="T_6c039_level0_col4" class="col_heading level0 col4" >kc_medio</th>
#       <th id="T_6c039_level0_col5" class="col_heading level0 col5" >kc_final</th>
#       <th id="T_6c039_level0_col6" class="col_heading level0 col6" >ky_total</th>
#       <th id="T_6c039_level0_col7" class="col_heading level0 col7" >dias_etapa_inicial</th>
#       <th id="T_6c039_level0_col8" class="col_heading level0 col8" >dias_etapa_desarrollo</th>
#       <th id="T_6c039_level0_col9" class="col_heading level0 col9" >dias_etapa_media</th>
#       <th id="T_6c039_level0_col10" class="col_heading level0 col10" >dias_etapa_final</th>
#       <th id="T_6c039_level0_col11" class="col_heading level0 col11" >rendimiento_potencial_ton</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6c039_row0_col0" class="data row0 col0" >01e38e1d-48ce-4a53-b4ab-d3fae254f17a</td>
#       <td id="T_6c039_row0_col1" class="data row0 col1" >Maíz</td>
#       <td id="T_6c039_row0_col2" class="data row0 col2" >Zea mays</td>
#       <td id="T_6c039_row0_col3" class="data row0 col3" >0.30</td>
#       <td id="T_6c039_row0_col4" class="data row0 col4" >1.20</td>
#       <td id="T_6c039_row0_col5" class="data row0 col5" >0.60</td>
#       <td id="T_6c039_row0_col6" class="data row0 col6" >1.25</td>
#       <td id="T_6c039_row0_col7" class="data row0 col7" >25</td>
#       <td id="T_6c039_row0_col8" class="data row0 col8" >40</td>
#       <td id="T_6c039_row0_col9" class="data row0 col9" >45</td>
#       <td id="T_6c039_row0_col10" class="data row0 col10" >30</td>
#       <td id="T_6c039_row0_col11" class="data row0 col11" >10.00</td>
#     </tr>
#     <tr>
#       <td id="T_6c039_row1_col0" class="data row1 col0" >2379496b-139f-4869-b211-8d75b462aec0</td>
#       <td id="T_6c039_row1_col1" class="data row1 col1" >Frijol</td>
#       <td id="T_6c039_row1_col2" class="data row1 col2" >Phaseolus vulgaris</td>
#       <td id="T_6c039_row1_col3" class="data row1 col3" >0.40</td>
#       <td id="T_6c039_row1_col4" class="data row1 col4" >1.15</td>
#       <td id="T_6c039_row1_col5" class="data row1 col5" >0.35</td>
#       <td id="T_6c039_row1_col6" class="data row1 col6" >1.15</td>
#       <td id="T_6c039_row1_col7" class="data row1 col7" >20</td>
#       <td id="T_6c039_row1_col8" class="data row1 col8" >30</td>
#       <td id="T_6c039_row1_col9" class="data row1 col9" >40</td>
#       <td id="T_6c039_row1_col10" class="data row1 col10" >20</td>
#       <td id="T_6c039_row1_col11" class="data row1 col11" >2.00</td>
#     </tr>
#     <tr>
#       <td id="T_6c039_row2_col0" class="data row2 col0" >1edc2f2d-add2-48b2-86a2-029e9941c5bd</td>
#       <td id="T_6c039_row2_col1" class="data row2 col1" >Algodón</td>
#       <td id="T_6c039_row2_col2" class="data row2 col2" >Gossypium hirsutum</td>
#       <td id="T_6c039_row2_col3" class="data row2 col3" >0.35</td>
#       <td id="T_6c039_row2_col4" class="data row2 col4" >1.20</td>
#       <td id="T_6c039_row2_col5" class="data row2 col5" >0.70</td>
#       <td id="T_6c039_row2_col6" class="data row2 col6" >0.85</td>
#       <td id="T_6c039_row2_col7" class="data row2 col7" >30</td>
#       <td id="T_6c039_row2_col8" class="data row2 col8" >50</td>
#       <td id="T_6c039_row2_col9" class="data row2 col9" >55</td>
#       <td id="T_6c039_row2_col10" class="data row2 col10" >45</td>
#       <td id="T_6c039_row2_col11" class="data row2 col11" >3.50</td>
#     </tr>
#     <tr>
#       <td id="T_6c039_row3_col0" class="data row3 col0" >7fe1eba7-4d6f-4c4f-9d17-952e5c30bb3f</td>
#       <td id="T_6c039_row3_col1" class="data row3 col1" >Uva</td>
#       <td id="T_6c039_row3_col2" class="data row3 col2" >Vitis vinifera</td>
#       <td id="T_6c039_row3_col3" class="data row3 col3" >0.30</td>
#       <td id="T_6c039_row3_col4" class="data row3 col4" >0.85</td>
#       <td id="T_6c039_row3_col5" class="data row3 col5" >0.45</td>
#       <td id="T_6c039_row3_col6" class="data row3 col6" >0.85</td>
#       <td id="T_6c039_row3_col7" class="data row3 col7" >30</td>
#       <td id="T_6c039_row3_col8" class="data row3 col8" >60</td>
#       <td id="T_6c039_row3_col9" class="data row3 col9" >75</td>
#       <td id="T_6c039_row3_col10" class="data row3 col10" >50</td>
#       <td id="T_6c039_row3_col11" class="data row3 col11" >22.50</td>
#     </tr>
#     <tr>
#       <td id="T_6c039_row4_col0" class="data row4 col0" >b492226d-e2e2-41a6-9185-b2682fbcc9ed</td>
#       <td id="T_6c039_row4_col1" class="data row4 col1" >Chile</td>
#       <td id="T_6c039_row4_col2" class="data row4 col2" >Capsicum annuum</td>
#       <td id="T_6c039_row4_col3" class="data row4 col3" >0.60</td>
#       <td id="T_6c039_row4_col4" class="data row4 col4" >1.05</td>
#       <td id="T_6c039_row4_col5" class="data row4 col5" >0.90</td>
#       <td id="T_6c039_row4_col6" class="data row4 col6" >1.10</td>
#       <td id="T_6c039_row4_col7" class="data row4 col7" >30</td>
#       <td id="T_6c039_row4_col8" class="data row4 col8" >35</td>
#       <td id="T_6c039_row4_col9" class="data row4 col9" >40</td>
#       <td id="T_6c039_row4_col10" class="data row4 col10" >20</td>
#       <td id="T_6c039_row4_col11" class="data row4 col11" >30.00</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ab8bb caption {
#   font-size: 13px;
#   font-weight: bold;
#   color: #2C3E50;
#   text-align: left;
#   padding: 8px 0;
# }
# #T_ab8bb th {
#   background-color: #2C3E50;
#   color: white;
#   padding: 6px 10px;
#   font-size: 10px;
#   white-space: nowrap;
# }
# #T_ab8bb td {
#   padding: 5px 10px;
#   border-bottom: 1px solid #eee;
# }
# #T_ab8bb tr:nth-child(even) {
#   background-color: #F8F9FA;
# }
# #T_ab8bb tr:hover {
#   background-color: #EBF5FB;
# }
# #T_ab8bb_row0_col0, #T_ab8bb_row0_col1, #T_ab8bb_row0_col2, #T_ab8bb_row0_col3, #T_ab8bb_row0_col4, #T_ab8bb_row0_col5, #T_ab8bb_row0_col6, #T_ab8bb_row0_col7, #T_ab8bb_row0_col8, #T_ab8bb_row0_col9, #T_ab8bb_row0_col10, #T_ab8bb_row0_col11, #T_ab8bb_row0_col12, #T_ab8bb_row0_col13, #T_ab8bb_row0_col14, #T_ab8bb_row1_col0, #T_ab8bb_row1_col1, #T_ab8bb_row1_col2, #T_ab8bb_row1_col3, #T_ab8bb_row1_col4, #T_ab8bb_row1_col5, #T_ab8bb_row1_col6, #T_ab8bb_row1_col7, #T_ab8bb_row1_col8, #T_ab8bb_row1_col9, #T_ab8bb_row1_col10, #T_ab8bb_row1_col11, #T_ab8bb_row1_col12, #T_ab8bb_row1_col13, #T_ab8bb_row1_col14, #T_ab8bb_row2_col0, #T_ab8bb_row2_col1, #T_ab8bb_row2_col2, #T_ab8bb_row2_col3, #T_ab8bb_row2_col4, #T_ab8bb_row2_col5, #T_ab8bb_row2_col6, #T_ab8bb_row2_col7, #T_ab8bb_row2_col8, #T_ab8bb_row2_col9, #T_ab8bb_row2_col10, #T_ab8bb_row2_col11, #T_ab8bb_row2_col12, #T_ab8bb_row2_col13, #T_ab8bb_row2_col14, #T_ab8bb_row3_col0, #T_ab8bb_row3_col1, #T_ab8bb_row3_col2, #T_ab8bb_row3_col3, #T_ab8bb_row3_col4, #T_ab8bb_row3_col5, #T_ab8bb_row3_col6, #T_ab8bb_row3_col7, #T_ab8bb_row3_col8, #T_ab8bb_row3_col9, #T_ab8bb_row3_col10, #T_ab8bb_row3_col11, #T_ab8bb_row3_col12, #T_ab8bb_row3_col13, #T_ab8bb_row3_col14, #T_ab8bb_row4_col0, #T_ab8bb_row4_col1, #T_ab8bb_row4_col2, #T_ab8bb_row4_col3, #T_ab8bb_row4_col4, #T_ab8bb_row4_col5, #T_ab8bb_row4_col6, #T_ab8bb_row4_col7, #T_ab8bb_row4_col8, #T_ab8bb_row4_col9, #T_ab8bb_row4_col10, #T_ab8bb_row4_col11, #T_ab8bb_row4_col12, #T_ab8bb_row4_col13, #T_ab8bb_row4_col14, #T_ab8bb_row5_col0, #T_ab8bb_row5_col1, #T_ab8bb_row5_col2, #T_ab8bb_row5_col3, #T_ab8bb_row5_col4, #T_ab8bb_row5_col5, #T_ab8bb_row5_col6, #T_ab8bb_row5_col7, #T_ab8bb_row5_col8, #T_ab8bb_row5_col9, #T_ab8bb_row5_col10, #T_ab8bb_row5_col11, #T_ab8bb_row5_col12, #T_ab8bb_row5_col13, #T_ab8bb_row5_col14, #T_ab8bb_row6_col0, #T_ab8bb_row6_col1, #T_ab8bb_row6_col2, #T_ab8bb_row6_col3, #T_ab8bb_row6_col4, #T_ab8bb_row6_col5, #T_ab8bb_row6_col6, #T_ab8bb_row6_col7, #T_ab8bb_row6_col8, #T_ab8bb_row6_col9, #T_ab8bb_row6_col10, #T_ab8bb_row6_col11, #T_ab8bb_row6_col12, #T_ab8bb_row6_col13, #T_ab8bb_row6_col14, #T_ab8bb_row7_col0, #T_ab8bb_row7_col1, #T_ab8bb_row7_col2, #T_ab8bb_row7_col3, #T_ab8bb_row7_col4, #T_ab8bb_row7_col5, #T_ab8bb_row7_col6, #T_ab8bb_row7_col7, #T_ab8bb_row7_col8, #T_ab8bb_row7_col9, #T_ab8bb_row7_col10, #T_ab8bb_row7_col11, #T_ab8bb_row7_col12, #T_ab8bb_row7_col13, #T_ab8bb_row7_col14, #T_ab8bb_row8_col0, #T_ab8bb_row8_col1, #T_ab8bb_row8_col2, #T_ab8bb_row8_col3, #T_ab8bb_row8_col4, #T_ab8bb_row8_col5, #T_ab8bb_row8_col6, #T_ab8bb_row8_col7, #T_ab8bb_row8_col8, #T_ab8bb_row8_col9, #T_ab8bb_row8_col10, #T_ab8bb_row8_col11, #T_ab8bb_row8_col12, #T_ab8bb_row8_col13, #T_ab8bb_row8_col14, #T_ab8bb_row9_col0, #T_ab8bb_row9_col1, #T_ab8bb_row9_col2, #T_ab8bb_row9_col3, #T_ab8bb_row9_col4, #T_ab8bb_row9_col5, #T_ab8bb_row9_col6, #T_ab8bb_row9_col7, #T_ab8bb_row9_col8, #T_ab8bb_row9_col9, #T_ab8bb_row9_col10, #T_ab8bb_row9_col11, #T_ab8bb_row9_col12, #T_ab8bb_row9_col13, #T_ab8bb_row9_col14, #T_ab8bb_row10_col0, #T_ab8bb_row10_col1, #T_ab8bb_row10_col2, #T_ab8bb_row10_col3, #T_ab8bb_row10_col4, #T_ab8bb_row10_col5, #T_ab8bb_row10_col6, #T_ab8bb_row10_col7, #T_ab8bb_row10_col8, #T_ab8bb_row10_col9, #T_ab8bb_row10_col10, #T_ab8bb_row10_col11, #T_ab8bb_row10_col12, #T_ab8bb_row10_col13, #T_ab8bb_row10_col14, #T_ab8bb_row11_col0, #T_ab8bb_row11_col1, #T_ab8bb_row11_col2, #T_ab8bb_row11_col3, #T_ab8bb_row11_col4, #T_ab8bb_row11_col5, #T_ab8bb_row11_col6, #T_ab8bb_row11_col7, #T_ab8bb_row11_col8, #T_ab8bb_row11_col9, #T_ab8bb_row11_col10, #T_ab8bb_row11_col11, #T_ab8bb_row11_col12, #T_ab8bb_row11_col13, #T_ab8bb_row11_col14, #T_ab8bb_row12_col0, #T_ab8bb_row12_col1, #T_ab8bb_row12_col2, #T_ab8bb_row12_col3, #T_ab8bb_row12_col4, #T_ab8bb_row12_col5, #T_ab8bb_row12_col6, #T_ab8bb_row12_col7, #T_ab8bb_row12_col8, #T_ab8bb_row12_col9, #T_ab8bb_row12_col10, #T_ab8bb_row12_col11, #T_ab8bb_row12_col12, #T_ab8bb_row12_col13, #T_ab8bb_row ...
# <style type="text/css">
# #T_5e579 caption {
#   font-size: 13px;
#   font-weight: bold;
#   color: #2C3E50;
#   text-align: left;
#   padding: 8px 0;
# }
# #T_5e579 th {
#   background-color: #2C3E50;
#   color: white;
#   padding: 6px 10px;
#   font-size: 10px;
#   white-space: nowrap;
# }
# #T_5e579 td {
#   padding: 5px 10px;
#   border-bottom: 1px solid #eee;
# }
# #T_5e579 tr:nth-child(even) {
#   background-color: #F8F9FA;
# }
# #T_5e579 tr:hover {
#   background-color: #EBF5FB;
# }
# #T_5e579_row0_col0, #T_5e579_row0_col1, #T_5e579_row0_col2, #T_5e579_row0_col3, #T_5e579_row0_col4, #T_5e579_row0_col5, #T_5e579_row0_col6, #T_5e579_row0_col7, #T_5e579_row0_col8, #T_5e579_row0_col9, #T_5e579_row0_col10, #T_5e579_row0_col11, #T_5e579_row0_col12, #T_5e579_row0_col13, #T_5e579_row1_col0, #T_5e579_row1_col1, #T_5e579_row1_col2, #T_5e579_row1_col3, #T_5e579_row1_col4, #T_5e579_row1_col5, #T_5e579_row1_col6, #T_5e579_row1_col7, #T_5e579_row1_col8, #T_5e579_row1_col9, #T_5e579_row1_col10, #T_5e579_row1_col11, #T_5e579_row1_col12, #T_5e579_row1_col13, #T_5e579_row2_col0, #T_5e579_row2_col1, #T_5e579_row2_col2, #T_5e579_row2_col3, #T_5e579_row2_col4, #T_5e579_row2_col5, #T_5e579_row2_col6, #T_5e579_row2_col7, #T_5e579_row2_col8, #T_5e579_row2_col9, #T_5e579_row2_col10, #T_5e579_row2_col11, #T_5e579_row2_col12, #T_5e579_row2_col13, #T_5e579_row3_col0, #T_5e579_row3_col1, #T_5e579_row3_col2, #T_5e579_row3_col3, #T_5e579_row3_col4, #T_5e579_row3_col5, #T_5e579_row3_col6, #T_5e579_row3_col7, #T_5e579_row3_col8, #T_5e579_row3_col9, #T_5e579_row3_col10, #T_5e579_row3_col11, #T_5e579_row3_col12, #T_5e579_row3_col13, #T_5e579_row4_col0, #T_5e579_row4_col1, #T_5e579_row4_col2, #T_5e579_row4_col3, #T_5e579_row4_col4, #T_5e579_row4_col5, #T_5e579_row4_col6, #T_5e579_row4_col7, #T_5e579_row4_col8, #T_5e579_row4_col9, #T_5e579_row4_col10, #T_5e579_row4_col11, #T_5e579_row4_col12, #T_5e579_row4_col13, #T_5e579_row5_col0, #T_5e579_row5_col1, #T_5e579_row5_col2, #T_5e579_row5_col3, #T_5e579_row5_col4, #T_5e579_row5_col5, #T_5e579_row5_col6, #T_5e579_row5_col7, #T_5e579_row5_col8, #T_5e579_row5_col9, #T_5e579_row5_col10, #T_5e579_row5_col11, #T_5e579_row5_col12, #T_5e579_row5_col13, #T_5e579_row6_col0, #T_5e579_row6_col1, #T_5e579_row6_col2, #T_5e579_row6_col3, #T_5e579_row6_col4, #T_5e579_row6_col5, #T_5e579_row6_col6, #T_5e579_row6_col7, #T_5e579_row6_col8, #T_5e579_row6_col9, #T_5e579_row6_col10, #T_5e579_row6_col11, #T_5e579_row6_col12, #T_5e579_row6_col13, #T_5e579_row7_col0, #T_5e579_row7_col1, #T_5e579_row7_col2, #T_5e579_row7_col3, #T_5e579_row7_col4, #T_5e579_row7_col5, #T_5e579_row7_col6, #T_5e579_row7_col7, #T_5e579_row7_col8, #T_5e579_row7_col9, #T_5e579_row7_col10, #T_5e579_row7_col11, #T_5e579_row7_col12, #T_5e579_row7_col13, #T_5e579_row8_col0, #T_5e579_row8_col1, #T_5e579_row8_col2, #T_5e579_row8_col3, #T_5e579_row8_col4, #T_5e579_row8_col5, #T_5e579_row8_col6, #T_5e579_row8_col7, #T_5e579_row8_col8, #T_5e579_row8_col9, #T_5e579_row8_col10, #T_5e579_row8_col11, #T_5e579_row8_col12, #T_5e579_row8_col13, #T_5e579_row9_col0, #T_5e579_row9_col1, #T_5e579_row9_col2, #T_5e579_row9_col3, #T_5e579_row9_col4, #T_5e579_row9_col5, #T_5e579_row9_col6, #T_5e579_row9_col7, #T_5e579_row9_col8, #T_5e579_row9_col9, #T_5e579_row9_col10, #T_5e579_row9_col11, #T_5e579_row9_col12, #T_5e579_row9_col13, #T_5e579_row10_col0, #T_5e579_row10_col1, #T_5e579_row10_col2, #T_5e579_row10_col3, #T_5e579_row10_col4, #T_5e579_row10_col5, #T_5e579_row10_col6, #T_5e579_row10_col7, #T_5e579_row10_col8, #T_5e579_row10_col9, #T_5e579_row10_col10, #T_5e579_row10_col11, #T_5e579_row10_col12, #T_5e579_row10_col13, #T_5e579_row11_col0, #T_5e579_row11_col1, #T_5e579_row11_col2, #T_5e579_row11_col3, #T_5e579_row11_col4, #T_5e579_row11_col5, #T_5e579_row11_col6, #T_5e579_row11_col7, #T_5e579_row11_col8, #T_5e579_row11_col9, #T_5e579_row11_col10, #T_5e579_row11_col11, #T_5e579_row11_col12, #T_5e579_row11_col13, #T_5e579_row12_col0, #T_5e579_row12_col1, #T_5e579_row12_col2, #T_5e579_row12_col3, #T_5e579_row12_col4, #T_5e579_row12_col5, #T_5e579_row12_col6, #T_5e579_row12_col7, #T_5e579_row12_col8, #T_5e579_row12_col9, #T_5e579_row12_col10, #T_5e579_row12_col11, #T_5e579_row12_col12, #T_5e579_row12_col13, #T_5e579_row13_col0, #T_5e579_row13_col1, #T_5e579_row13_col2, #T_5e579_row13_col3, #T_5e579_row13_col4, #T_5e579_row13_col5, #T_5e579_row13_col6, #T_5e579_row13_col7, #T_5e579_row13_col8, #T_5e579_row13_col9, #T_5e579_row13_col10, #T_5e579_row13_col11, #T_5e579_row ...
# <style type="text/css">
# #T_a28af caption {
#   font-size: 13px;
#   font-weight: bold;
#   color: #2C3E50;
#   text-align: left;
#   padding: 8px 0;
# }
# #T_a28af th {
#   background-color: #2C3E50;
#   color: white;
#   padding: 6px 10px;
#   font-size: 10px;
#   white-space: nowrap;
# }
# #T_a28af td {
#   padding: 5px 10px;
#   border-bottom: 1px solid #eee;
# }
# #T_a28af tr:nth-child(even) {
#   background-color: #F8F9FA;
# }
# #T_a28af tr:hover {
#   background-color: #EBF5FB;
# }
# #T_a28af_row0_col0, #T_a28af_row0_col1, #T_a28af_row0_col2, #T_a28af_row0_col3, #T_a28af_row0_col4, #T_a28af_row0_col5, #T_a28af_row0_col6, #T_a28af_row0_col7, #T_a28af_row0_col8, #T_a28af_row0_col9, #T_a28af_row0_col10, #T_a28af_row0_col11, #T_a28af_row0_col12, #T_a28af_row0_col13, #T_a28af_row0_col14, #T_a28af_row0_col15, #T_a28af_row1_col0, #T_a28af_row1_col1, #T_a28af_row1_col2, #T_a28af_row1_col3, #T_a28af_row1_col4, #T_a28af_row1_col5, #T_a28af_row1_col6, #T_a28af_row1_col7, #T_a28af_row1_col8, #T_a28af_row1_col9, #T_a28af_row1_col10, #T_a28af_row1_col11, #T_a28af_row1_col12, #T_a28af_row1_col13, #T_a28af_row1_col14, #T_a28af_row1_col15, #T_a28af_row2_col0, #T_a28af_row2_col1, #T_a28af_row2_col2, #T_a28af_row2_col3, #T_a28af_row2_col4, #T_a28af_row2_col5, #T_a28af_row2_col6, #T_a28af_row2_col7, #T_a28af_row2_col8, #T_a28af_row2_col9, #T_a28af_row2_col10, #T_a28af_row2_col11, #T_a28af_row2_col12, #T_a28af_row2_col13, #T_a28af_row2_col14, #T_a28af_row2_col15, #T_a28af_row3_col0, #T_a28af_row3_col1, #T_a28af_row3_col2, #T_a28af_row3_col3, #T_a28af_row3_col4, #T_a28af_row3_col5, #T_a28af_row3_col6, #T_a28af_row3_col7, #T_a28af_row3_col8, #T_a28af_row3_col9, #T_a28af_row3_col10, #T_a28af_row3_col11, #T_a28af_row3_col12, #T_a28af_row3_col13, #T_a28af_row3_col14, #T_a28af_row3_col15, #T_a28af_row4_col0, #T_a28af_row4_col1, #T_a28af_row4_col2, #T_a28af_row4_col3, #T_a28af_row4_col4, #T_a28af_row4_col5, #T_a28af_row4_col6, #T_a28af_row4_col7, #T_a28af_row4_col8, #T_a28af_row4_col9, #T_a28af_row4_col10, #T_a28af_row4_col11, #T_a28af_row4_col12, #T_a28af_row4_col13, #T_a28af_row4_col14, #T_a28af_row4_col15, #T_a28af_row5_col0, #T_a28af_row5_col1, #T_a28af_row5_col2, #T_a28af_row5_col3, #T_a28af_row5_col4, #T_a28af_row5_col5, #T_a28af_row5_col6, #T_a28af_row5_col7, #T_a28af_row5_col8, #T_a28af_row5_col9, #T_a28af_row5_col10, #T_a28af_row5_col11, #T_a28af_row5_col12, #T_a28af_row5_col13, #T_a28af_row5_col14, #T_a28af_row5_col15, #T_a28af_row6_col0, #T_a28af_row6_col1, #T_a28af_row6_col2, #T_a28af_row6_col3, #T_a28af_row6_col4, #T_a28af_row6_col5, #T_a28af_row6_col6, #T_a28af_row6_col7, #T_a28af_row6_col8, #T_a28af_row6_col9, #T_a28af_row6_col10, #T_a28af_row6_col11, #T_a28af_row6_col12, #T_a28af_row6_col13, #T_a28af_row6_col14, #T_a28af_row6_col15, #T_a28af_row7_col0, #T_a28af_row7_col1, #T_a28af_row7_col2, #T_a28af_row7_col3, #T_a28af_row7_col4, #T_a28af_row7_col5, #T_a28af_row7_col6, #T_a28af_row7_col7, #T_a28af_row7_col8, #T_a28af_row7_col9, #T_a28af_row7_col10, #T_a28af_row7_col11, #T_a28af_row7_col12, #T_a28af_row7_col13, #T_a28af_row7_col14, #T_a28af_row7_col15, #T_a28af_row8_col0, #T_a28af_row8_col1, #T_a28af_row8_col2, #T_a28af_row8_col3, #T_a28af_row8_col4, #T_a28af_row8_col5, #T_a28af_row8_col6, #T_a28af_row8_col7, #T_a28af_row8_col8, #T_a28af_row8_col9, #T_a28af_row8_col10, #T_a28af_row8_col11, #T_a28af_row8_col12, #T_a28af_row8_col13, #T_a28af_row8_col14, #T_a28af_row8_col15, #T_a28af_row9_col0, #T_a28af_row9_col1, #T_a28af_row9_col2, #T_a28af_row9_col3, #T_a28af_row9_col4, #T_a28af_row9_col5, #T_a28af_row9_col6, #T_a28af_row9_col7, #T_a28af_row9_col8, #T_a28af_row9_col9, #T_a28af_row9_col10, #T_a28af_row9_col11, #T_a28af_row9_col12, #T_a28af_row9_col13, #T_a28af_row9_col14, #T_a28af_row9_col15, #T_a28af_row10_col0, #T_a28af_row10_col1, #T_a28af_row10_col2, #T_a28af_row10_col3, #T_a28af_row10_col4, #T_a28af_row10_col5, #T_a28af_row10_col6, #T_a28af_row10_col7, #T_a28af_row10_col8, #T_a28af_row10_col9, #T_a28af_row10_col10, #T_a28af_row10_col11, #T_a28af_row10_col12, #T_a28af_row10_col13, #T_a28af_row10_col14, #T_a28af_row10_col15, #T_a28af_row11_col0, #T_a28af_row11_col1, #T_a28af_row11_col2, #T_a28af_row11_col3, #T_a28af_row11_col4, #T_a28af_row11_col5, #T_a28af_row11_col6, #T_a28af_row11_col7, #T_a28af_row11_col8, #T_a28af_row11_col9, #T_a28af_row11_col10, #T_a28af_row11_col11, #T_a28af_row11_col12, #T_a28af_row11_col13, #T_a28af_row11_col14, #T_a28af_row11_col15, #T_a28af_row12_col0, #T_a28af_row12_col1, #T_a28af_row12 ...
# <style type="text/css">
# #T_1c554 caption {
#   font-size: 13px;
#   font-weight: bold;
#   color: #2C3E50;
#   text-align: left;
#   padding: 8px 0;
# }
# #T_1c554 th {
#   background-color: #2C3E50;
#   color: white;
#   padding: 6px 10px;
#   font-size: 10px;
#   white-space: nowrap;
# }
# #T_1c554 td {
#   padding: 5px 10px;
#   border-bottom: 1px solid #eee;
# }
# #T_1c554 tr:nth-child(even) {
#   background-color: #F8F9FA;
# }
# #T_1c554 tr:hover {
#   background-color: #EBF5FB;
# }
# #T_1c554_row0_col0, #T_1c554_row0_col1, #T_1c554_row0_col2, #T_1c554_row0_col3, #T_1c554_row0_col4, #T_1c554_row0_col5, #T_1c554_row0_col6, #T_1c554_row0_col7, #T_1c554_row0_col8, #T_1c554_row0_col9, #T_1c554_row0_col10, #T_1c554_row0_col11, #T_1c554_row0_col12, #T_1c554_row0_col13, #T_1c554_row0_col14, #T_1c554_row0_col15, #T_1c554_row0_col16, #T_1c554_row1_col0, #T_1c554_row1_col1, #T_1c554_row1_col2, #T_1c554_row1_col3, #T_1c554_row1_col4, #T_1c554_row1_col5, #T_1c554_row1_col6, #T_1c554_row1_col7, #T_1c554_row1_col8, #T_1c554_row1_col9, #T_1c554_row1_col10, #T_1c554_row1_col11, #T_1c554_row1_col12, #T_1c554_row1_col13, #T_1c554_row1_col14, #T_1c554_row1_col15, #T_1c554_row1_col16, #T_1c554_row2_col0, #T_1c554_row2_col1, #T_1c554_row2_col2, #T_1c554_row2_col3, #T_1c554_row2_col4, #T_1c554_row2_col5, #T_1c554_row2_col6, #T_1c554_row2_col7, #T_1c554_row2_col8, #T_1c554_row2_col9, #T_1c554_row2_col10, #T_1c554_row2_col11, #T_1c554_row2_col12, #T_1c554_row2_col13, #T_1c554_row2_col14, #T_1c554_row2_col15, #T_1c554_row2_col16, #T_1c554_row3_col0, #T_1c554_row3_col1, #T_1c554_row3_col2, #T_1c554_row3_col3, #T_1c554_row3_col4, #T_1c554_row3_col5, #T_1c554_row3_col6, #T_1c554_row3_col7, #T_1c554_row3_col8, #T_1c554_row3_col9, #T_1c554_row3_col10, #T_1c554_row3_col11, #T_1c554_row3_col12, #T_1c554_row3_col13, #T_1c554_row3_col14, #T_1c554_row3_col15, #T_1c554_row3_col16, #T_1c554_row4_col0, #T_1c554_row4_col1, #T_1c554_row4_col2, #T_1c554_row4_col3, #T_1c554_row4_col4, #T_1c554_row4_col5, #T_1c554_row4_col6, #T_1c554_row4_col7, #T_1c554_row4_col8, #T_1c554_row4_col9, #T_1c554_row4_col10, #T_1c554_row4_col11, #T_1c554_row4_col12, #T_1c554_row4_col13, #T_1c554_row4_col14, #T_1c554_row4_col15, #T_1c554_row4_col16, #T_1c554_row5_col0, #T_1c554_row5_col1, #T_1c554_row5_col2, #T_1c554_row5_col3, #T_1c554_row5_col4, #T_1c554_row5_col5, #T_1c554_row5_col6, #T_1c554_row5_col7, #T_1c554_row5_col8, #T_1c554_row5_col9, #T_1c554_row5_col10, #T_1c554_row5_col11, #T_1c554_row5_col12, #T_1c554_row5_col13, #T_1c554_row5_col14, #T_1c554_row5_col15, #T_1c554_row5_col16, #T_1c554_row6_col0, #T_1c554_row6_col1, #T_1c554_row6_col2, #T_1c554_row6_col3, #T_1c554_row6_col4, #T_1c554_row6_col5, #T_1c554_row6_col6, #T_1c554_row6_col7, #T_1c554_row6_col8, #T_1c554_row6_col9, #T_1c554_row6_col10, #T_1c554_row6_col11, #T_1c554_row6_col12, #T_1c554_row6_col13, #T_1c554_row6_col14, #T_1c554_row6_col15, #T_1c554_row6_col16, #T_1c554_row7_col0, #T_1c554_row7_col1, #T_1c554_row7_col2, #T_1c554_row7_col3, #T_1c554_row7_col4, #T_1c554_row7_col5, #T_1c554_row7_col6, #T_1c554_row7_col7, #T_1c554_row7_col8, #T_1c554_row7_col9, #T_1c554_row7_col10, #T_1c554_row7_col11, #T_1c554_row7_col12, #T_1c554_row7_col13, #T_1c554_row7_col14, #T_1c554_row7_col15, #T_1c554_row7_col16, #T_1c554_row8_col0, #T_1c554_row8_col1, #T_1c554_row8_col2, #T_1c554_row8_col3, #T_1c554_row8_col4, #T_1c554_row8_col5, #T_1c554_row8_col6, #T_1c554_row8_col7, #T_1c554_row8_col8, #T_1c554_row8_col9, #T_1c554_row8_col10, #T_1c554_row8_col11, #T_1c554_row8_col12, #T_1c554_row8_col13, #T_1c554_row8_col14, #T_1c554_row8_col15, #T_1c554_row8_col16, #T_1c554_row9_col0, #T_1c554_row9_col1, #T_1c554_row9_col2, #T_1c554_row9_col3, #T_1c554_row9_col4, #T_1c554_row9_col5, #T_1c554_row9_col6, #T_1c554_row9_col7, #T_1c554_row9_col8, #T_1c554_row9_col9, #T_1c554_row9_col10, #T_1c554_row9_col11, #T_1c554_row9_col12, #T_1c554_row9_col13, #T_1c554_row9_col14, #T_1c554_row9_col15, #T_1c554_row9_col16, #T_1c554_row10_col0, #T_1c554_row10_col1, #T_1c554_row10_col2, #T_1c554_row10_col3, #T_1c554_row10_col4, #T_1c554_row10_col5, #T_1c554_row10_col6, #T_1c554_row10_col7, #T_1c554_row10_col8, #T_1c554_row10_col9, #T_1c554_row10_col10, #T_1c554_row10_col11, #T_1c554_row10_col12, #T_1c554_row10_col13, #T_1c554_row10_col14, #T_1c554_row10_col15, #T_1c554_row10_col16, #T_1c554_row11_col0, #T_1c554_row11_col1, #T_1c554_row11_col2, #T_1c554_row11_col3, #T_1c554_row11_col4, #T_1c554_row11_col5, #T_1c554_row11_col6, #T_1c554_row11_col7 ...
# ✓ Exploración completa finalizada.

# %% [markdown]
# ---
# ## 13 · Línea de Tiempo — Ciclos Agrícolas 2020-2025
#
# El DR-041 opera con **dos ciclos por año**:
# - **OI** (Otoño-Invierno): octubre → marzo
# - **PV** (Primavera-Verano): abril → septiembre
#
# Los datos cubren **10 ciclos** completos: OI-2021 a OI-2025 y PV-2021 a PV-2025.

# %%
# ══════════════════════════════════════════════════════════════════════════════
# SECCIÓN 13 — Línea de tiempo de ciclos agrícolas
# ══════════════════════════════════════════════════════════════════════════════

import matplotlib.patches as mpatches
import matplotlib.dates as mdates
from matplotlib.lines import Line2D

# ── Preparar datos de timeline ────────────────────────────────────────────────
ciclo_info = (
    historial
    .groupby('ciclo_agricola')
    .agg(
        fecha_inicio=('fecha_riego', 'min'),
        fecha_fin   =('fecha_riego', 'max'),
        n_eventos   =('id_riego',    'count'),
        vol_medio   =('volumen_m3_ha','mean'),
    )
    .reset_index()
)
# KPI por ciclo (vol total parcela×ciclo)
kpi_ciclo = (
    kpi.groupby('ciclo_agricola')
    .agg(
        vol_ciclo_medio=('vol_m3_ha_ciclo','mean'),
        pct_bajo_meta  =('bajo_meta',      lambda x: x.mean()*100),
        n_parcelas     =('id_parcela',      'count'),
    )
    .reset_index()
)
ciclo_info = ciclo_info.merge(kpi_ciclo, on='ciclo_agricola', how='left')
ciclo_info['tipo'] = ciclo_info['ciclo_agricola'].str[:2]   # OI / PV
ciclo_info['año']  = ciclo_info['ciclo_agricola'].str[-4:].astype(int)
ciclo_info = ciclo_info.sort_values('fecha_inicio').reset_index(drop=True)

# Mostrar tabla resumen de ciclos
tabla_ciclos = ciclo_info[[
    'ciclo_agricola','fecha_inicio','fecha_fin',
    'n_eventos','vol_ciclo_medio','pct_bajo_meta','n_parcelas'
]].copy()
tabla_ciclos.columns = [
    'Ciclo','Inicio','Fin',
    'N° eventos','Vol medio (m³/ha)','% bajo meta 6k','Parcelas'
]

def _color_vol(v):
    if v <= 6000: return 'background-color:#D5F5E3;color:#1E8449;font-weight:bold'
    if v <= 7000: return 'background-color:#FDEBD0;color:#E67E22;font-weight:bold'
    return 'background-color:#FADBD8;color:#C0392B;font-weight:bold'

display(
    tabla_ciclos.style
    .set_caption('Resumen de ciclos agrícolas — DR-041 Módulo 3')
    .applymap(_color_vol, subset=['Vol medio (m³/ha)'])
    .background_gradient(subset=['% bajo meta 6k'], cmap='Greens')
    .format({
        'Inicio':          '{:%Y-%m-%d}',
        'Fin':             '{:%Y-%m-%d}',
        'N° eventos':      '{:,d}',
        'Vol medio (m³/ha)': '{:,.0f}',
        '% bajo meta 6k':   '{:.1f}%',
        'Parcelas':         '{:d}',
    })
    .set_properties(**{'text-align':'center'})
    .set_table_styles([{'selector':'caption',
                        'props':[('font-size','14px'),('font-weight','bold')]}])
    .hide(axis='index')
)

# ── Gráfico 1: Gantt de ciclos ────────────────────────────────────────────────
fig, axes = plt.subplots(3, 1, figsize=(16, 14),
                          gridspec_kw={'height_ratios':[2, 1.8, 2]})
fig.suptitle('Línea de Tiempo — Ciclos Agrícolas DR-041 (2020-2025)',
             fontsize=15, fontweight='bold', y=0.98)

COLOR_OI = '#2980B9'   # azul  → Otoño-Invierno
COLOR_PV = '#E67E22'   # naranja → Primavera-Verano
COLOR_META = '#27AE60'
COLOR_BASE = '#C0392B'

# ─ Panel 1: Gantt Horizontal ─────────────────────────────────────────────────
ax1 = axes[0]
yticks, ylabels = [], []
for i, row in ciclo_info.iterrows():
    color = COLOR_OI if row['tipo'] == 'OI' else COLOR_PV
    ax1.barh(y=i, left=row['fecha_inicio'], 
             width=(row['fecha_fin'] - row['fecha_inicio']).days,
             color=color, alpha=0.85, height=0.6, edgecolor='white', linewidth=1.2)
    # Etiqueta dentro de la barra
    mid = row['fecha_inicio'] + (row['fecha_fin'] - row['fecha_inicio']) / 2
    ax1.text(mid, i, f' {row["ciclo_agricola"]}  {row["vol_ciclo_medio"]:,.0f} m³/ha',
             ha='center', va='center', fontsize=9, color='white', fontweight='bold')
    yticks.append(i)
    ylabels.append(row['ciclo_agricola'])

ax1.set_yticks(yticks)
ax1.set_yticklabels(ylabels, fontsize=10)
ax1.xaxis.set_major_locator(mdates.MonthLocator(bymonth=[1,4,7,10]))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b\n%Y'))
ax1.set_xlim(pd.Timestamp('2020-08-01'), pd.Timestamp('2025-12-01'))
ax1.set_title('Gantt de ciclos agrícolas (duración real en días)', fontsize=11)
ax1.tick_params(axis='x', labelsize=8)
ax1.grid(axis='x', alpha=0.3, linestyle='--')
legend_patch = [
    mpatches.Patch(color=COLOR_OI, label='Otoño-Invierno (OI)'),
    mpatches.Patch(color=COLOR_PV, label='Primavera-Verano (PV)'),
]
ax1.legend(handles=legend_patch, fontsize=9, loc='lower right')

# ─ Panel 2: Volumen medio por ciclo (barras) ─────────────────────────────────
ax2 = axes[1]
x_pos = range(len(ciclo_info))
colors_bar = [COLOR_OI if t=='OI' else COLOR_PV for t in ciclo_info['tipo']]
bars = ax2.bar(x_pos, ciclo_info['vol_ciclo_medio'], color=colors_bar,
               alpha=0.85, edgecolor='white', width=0.65)
ax2.bar_label(bars, fmt='{:,.0f}', fontsize=8, padding=3)
ax2.axhline(6000, color=COLOR_META, linestyle='--', lw=2,
            label=f'Meta MILPÍN: 6,000 m³/ha')
ax2.axhline(8000, color=COLOR_BASE, linestyle=':', lw=1.8,
            label=f'Baseline DR-041: 8,000 m³/ha')
ax2.set_xticks(list(x_pos))
ax2.set_xticklabels(ciclo_info['ciclo_agricola'], rotation=30, fontsize=9)
ax2.set_ylabel('m³/ha/ciclo')
ax2.set_title('Volumen medio de riego por ciclo vs KPI', fontsize=11)
ax2.legend(fontsize=9)
ax2.set_ylim(0, 9500)

# Zona de meta (sombreado verde)
ax2.axhspan(0, 6000, alpha=0.04, color=COLOR_META)

# ─ Panel 3: % ciclos bajo meta + evolución temporal ─────────────────────────
ax3 = axes[2]
ax3b = ax3.twinx()

# Barras: % parcelas bajo meta
colors_pct = [COLOR_META if p >= 45 else NARANJA if p >= 35 else ROJO
              for p in ciclo_info['pct_bajo_meta']]
bars3 = ax3.bar(x_pos, ciclo_info['pct_bajo_meta'], color=colors_pct,
                alpha=0.70, edgecolor='white', width=0.65)
ax3.bar_label(bars3, fmt='{:.1f}%', fontsize=8, padding=3)
ax3.set_ylabel('% parcelas bajo meta 6k', color=COLOR_META)
ax3.tick_params(axis='y', labelcolor=COLOR_META)
ax3.set_ylim(0, 80)
ax3.axhline(50, color=COLOR_META, linestyle='--', lw=1.5, alpha=0.5,
            label='50% umbral')

# Línea: eventos por ciclo
ax3b.plot(list(x_pos), ciclo_info['n_eventos'], color=AZUL, lw=2,
          marker='o', ms=6, label='N° eventos de riego')
ax3b.set_ylabel('N° eventos de riego', color=AZUL)
ax3b.tick_params(axis='y', labelcolor=AZUL)

ax3.set_xticks(list(x_pos))
ax3.set_xticklabels(ciclo_info['ciclo_agricola'], rotation=30, fontsize=9)
ax3.set_title('% parcelas bajo meta 6k m³/ha y volumen de actividad', fontsize=11)

lines1, labels1 = ax3.get_legend_handles_labels()
lines2, labels2 = ax3b.get_legend_handles_labels()
ax3.legend(lines1 + lines2, labels1 + labels2, fontsize=8, loc='upper right')

plt.tight_layout()
plt.show()

# ── Gráfico 2: Heatmap ciclo × año ───────────────────────────────────────────
fig2, axes2 = plt.subplots(1, 2, figsize=(14, 4))
fig2.suptitle('Heatmap de métricas por ciclo × tipo', fontsize=13, fontweight='bold')

pivot_vol = ciclo_info.pivot_table(index='tipo', columns='año',
                                    values='vol_ciclo_medio', aggfunc='mean')
pivot_pct = ciclo_info.pivot_table(index='tipo', columns='año',
                                    values='pct_bajo_meta', aggfunc='mean')

sns.heatmap(pivot_vol, ax=axes2[0], annot=True, fmt='.0f', cmap='RdYlGn_r',
            center=7000, vmin=5500, vmax=8000, linewidths=0.5,
            annot_kws={'size':11, 'weight':'bold'},
            cbar_kws={'label':'m³/ha/ciclo','shrink':0.7})
axes2[0].set_title('Volumen medio (m³/ha/ciclo)', fontsize=11)
axes2[0].set_xlabel('Año'); axes2[0].set_ylabel('Tipo ciclo')

sns.heatmap(pivot_pct, ax=axes2[1], annot=True, fmt='.1f', cmap='RdYlGn',
            vmin=30, vmax=60, linewidths=0.5,
            annot_kws={'size':11, 'weight':'bold'},
            cbar_kws={'label':'% bajo meta 6k','shrink':0.7})
axes2[1].set_title('% parcelas bajo meta 6k m³/ha', fontsize=11)
axes2[1].set_xlabel('Año'); axes2[1].set_ylabel('Tipo ciclo')

plt.tight_layout()
plt.show()

# ── Resumen estadístico de la serie temporal ──────────────────────────────────
print()
print("━" * 60)
print("RESUMEN DE LA SERIE TEMPORAL")
print("━" * 60)
print(f"  Periodo cubierto : {ciclo_info['fecha_inicio'].min():%Y-%m-%d}"
      f" → {ciclo_info['fecha_fin'].max():%Y-%m-%d}")
print(f"  Total ciclos     : {len(ciclo_info)} ({ciclo_info['tipo'].value_counts()['OI']} OI + {ciclo_info['tipo'].value_counts()['PV']} PV)")
print(f"  Total eventos    : {ciclo_info['n_eventos'].sum():,} registros de riego")
print(f"  Vol. global medio: {ciclo_info['vol_ciclo_medio'].mean():,.0f} m³/ha/ciclo")
print(f"  Ahorro vs 8k     : {(8000 - ciclo_info['vol_ciclo_medio'].mean()) / 8000 * 100:.1f}%")
print(f"  Tendencia vol    : {ciclo_info['vol_ciclo_medio'].corr(pd.Series(range(len(ciclo_info)))):.3f} (corr con orden)")
print()
mejor = ciclo_info.loc[ciclo_info['vol_ciclo_medio'].idxmin()]
peor  = ciclo_info.loc[ciclo_info['vol_ciclo_medio'].idxmax()]
print(f"  Mejor ciclo      : {mejor['ciclo_agricola']} — {mejor['vol_ciclo_medio']:,.0f} m³/ha")
print(f"  Peor ciclo       : {peor['ciclo_agricola']}  — {peor['vol_ciclo_medio']:,.0f} m³/ha")
# Out:
# <style type="text/css">
# #T_cd722 caption {
#   font-size: 14px;
#   font-weight: bold;
# }
# #T_cd722_row0_col0, #T_cd722_row0_col1, #T_cd722_row0_col2, #T_cd722_row0_col3, #T_cd722_row0_col6, #T_cd722_row1_col0, #T_cd722_row1_col1, #T_cd722_row1_col2, #T_cd722_row1_col3, #T_cd722_row1_col6, #T_cd722_row2_col0, #T_cd722_row2_col1, #T_cd722_row2_col2, #T_cd722_row2_col3, #T_cd722_row2_col6, #T_cd722_row3_col0, #T_cd722_row3_col1, #T_cd722_row3_col2, #T_cd722_row3_col3, #T_cd722_row3_col6, #T_cd722_row4_col0, #T_cd722_row4_col1, #T_cd722_row4_col2, #T_cd722_row4_col3, #T_cd722_row4_col6, #T_cd722_row5_col0, #T_cd722_row5_col1, #T_cd722_row5_col2, #T_cd722_row5_col3, #T_cd722_row5_col6, #T_cd722_row6_col0, #T_cd722_row6_col1, #T_cd722_row6_col2, #T_cd722_row6_col3, #T_cd722_row6_col6, #T_cd722_row7_col0, #T_cd722_row7_col1, #T_cd722_row7_col2, #T_cd722_row7_col3, #T_cd722_row7_col6, #T_cd722_row8_col0, #T_cd722_row8_col1, #T_cd722_row8_col2, #T_cd722_row8_col3, #T_cd722_row8_col6, #T_cd722_row9_col0, #T_cd722_row9_col1, #T_cd722_row9_col2, #T_cd722_row9_col3, #T_cd722_row9_col6 {
#   text-align: center;
# }
# #T_cd722_row0_col4, #T_cd722_row1_col4, #T_cd722_row2_col4, #T_cd722_row3_col4, #T_cd722_row4_col4, #T_cd722_row5_col4, #T_cd722_row6_col4, #T_cd722_row7_col4, #T_cd722_row8_col4, #T_cd722_row9_col4 {
#   background-color: #FADBD8;
#   color: #C0392B;
#   font-weight: bold;
#   text-align: center;
# }
# #T_cd722_row0_col5 {
#   background-color: #228a44;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_cd722_row1_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_cd722_row2_col5, #T_cd722_row9_col5 {
#   background-color: #75c477;
#   color: #000000;
#   text-align: center;
# }
# #T_cd722_row3_col5, #T_cd722_row4_col5 {
#   background-color: #e5f5e1;
#   color: #000000;
#   text-align: center;
# }
# #T_cd722_row5_col5, #T_cd722_row6_col5, #T_cd722_row7_col5 {
#   background-color: #c8e9c1;
#   color: #000000;
#   text-align: center;
# }
# #T_cd722_row8_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_cd722">
#   <caption>📅 Resumen de ciclos agrícolas — DR-041 Módulo 3</caption>
#   <thead>
#     <tr>
#       <th id="T_cd722_level0_col0" class="col_heading level0 col0" >Ciclo</th>
#       <th id="T_cd722_level0_col1" class="col_heading level0 col1" >Inicio</th>
#       <th id="T_cd722_level0_col2" class="col_heading level0 col2" >Fin</th>
#       <th id="T_cd722_level0_col3" class="col_heading level0 col3" >N° eventos</th>
#       <th id="T_cd722_level0_col4" class="col_heading level0 col4" >Vol medio (m³/ha)</th>
#       <th id="T_cd722_level0_col5" class="col_heading level0 col5" >% bajo meta 6k</th>
#       <th id="T_cd722_level0_col6" class="col_heading level0 col6" >Parcelas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cd722_row0_col0" class="data row0 col0" >OI-2021</td>
#       <td id="T_cd722_row0_col1" class="data row0 col1" >2020-10-15</td>
#       <td id="T_cd722_row0_col2" class="data row0 col2" >2021-03-14</td>
#       <td id="T_cd722_row0_col3" class="data row0 col3" >1,098</td>
#       <td id="T_cd722_row0_col4" class="data row0 col4" >7,517</td>
#       <td id="T_cd722_row0_col5" class="data row0 col5" >21.2%</td>
#       <td id="T_cd722_row0_col6" class="data row0 col6" >80</td>
#     </tr>
#     <tr>
#       <td id="T_cd722_row1_col0" class="data row1 col0" >PV-2021</td>
#       <td id="T_cd722_row1_col1" class="data row1 col1" >2021-04-01</td>
#       <td id="T_cd722_row1_col2" class="data row1 col2" >2021-09-14</td>
#       <td id="T_cd722_row1_col3" class="data row1 col3" >1,123</td>
#       <td id="T_cd722_row1_col4" class="data row1 col4" >7,655</td>
#       <td id="T_cd722_row1_col5" class="data row1 col5" >23.8%</td>
#       <td id="T_cd722_row1_col6" class="data row1 col6" >80</td>
#     </tr>
#     <tr>
#       <td id="T_cd722_row2_col0" class="data row2 col0" >OI-2022</td>
#       <td id="T_cd722_row2_col1" class="data row2 col1" >2021-10-15</td>
#       <td id="T_cd722_row2_col2" class="data row2 col2" >2022-03-14</td>
#       <td id="T_cd722_row2_col3" class="data row2 col3" >1,149</td>
#       <td id="T_cd722_row2_col4" class="data row2 col4" >7,631</td>
#       <td id="T_cd722_row2_col5" class="data row2 col5" >18.8%</td>
#       <td id="T_cd722_row2_col6" class="data row2 col6" >80</td>
#     </tr>
#     <tr>
#       <td id="T_cd722_row3_col0" class="data row3 col0" >PV-2022</td>
#       <td id="T_cd722_row3_col1" class="data row3 col1" >2022-04-01</td>
#       <td id="T_cd722_row3_col2" class="data row3 col2" >2022-09-14</td>
#       <td id="T_cd722_row3_col3" class="data row3 col3" >1,130</td>
#       <td id="T_cd722_row3_col4" class="data row3 col4" >7,980</td>
#       <td id="T_cd722_row3_col5" class="data row3 col5" >15.0%</td>
#       <td id="T_cd722_row3_col6" class="data row3 col6" >80</td>
#     </tr>
#     <tr>
#       <td id="T_cd722_row4_col0" class="data row4 col0" >OI-2023</td>
#       <td id="T_cd722_row4_col1" class="data row4 col1" >2022-10-15</td>
#       <td id="T_cd722_row4_col2" class="data row4 col2" >2023-03-14</td>
#       <td id="T_cd722_row4_col3" class="data row4 col3" >1,151</td>
#       <td id="T_cd722_row4_col4" class="data row4 col4" >7,895</td>
#       <td id="T_cd722_row4_col5" class="data row4 col5" >15.0%</td>
#       <td id="T_cd722_row4_col6" class="data row4 col6" >80</td>
#     </tr>
#     <tr>
#       <td id="T_cd722_row5_col0" class="data row5 col0" >PV-2023</td>
#       <td id="T_cd722_row5_col1" class="data row5 col1" >2023-04-01</td>
#       <td id="T_cd722_row5_col2" class="data row5 col2" >2023-09-14</td>
#       <td id="T_cd722_row5_col3" class="data row5 col3" >1,120</td>
#       <td id="T_cd722_row5_col4" class="data row5 col4" >7,550</td>
#       <td id="T_cd722_row5_col5" class="data row5 col5" >16.2%</td>
#       <td id="T_cd722_row5_col6" class="data row5 col6" >80</td>
#     </tr>
#     <tr>
#       <td id="T_cd722_row6_col0" class="data row6 col0" >OI-2024</td>
#       <td id="T_cd722_row6_col1" class="data row6 col1" >2023-10-15</td>
#       <td id="T_cd722_row6_col2" class="data row6 col2" >2024-03-14</td>
#       <td id="T_cd722_row6_col3" class="data row6 col3" >1,129</td>
#       <td id="T_cd722_row6_col4" class="data row6 col4" >7,870</td>
#       <td id="T_cd722_row6_col5" class="data row6 col5" >16.2%</td>
#       <td id="T_cd722_row6_col6" class="data row6 col6" >80</td>
#     </tr>
#     <tr>
#       <td id="T_cd722_row7_col0" class="data row7 col0" >PV-2024</td>
#       <td id="T_cd722_row7_col1" class="data row7 col1" >2024-04-01</td>
#       <td id="T_cd722_row7_col2" class="data row7 col2" >2024-09-14</td>
#       <td id="T_cd722_row7_col3" class="data row7 col3" >1,145</td>
#       <td id="T_cd722_row7_col4" class="data row7 col4" >7,855</td>
#       <td id="T_cd722_row7_col5" class="data row7 col5" >16.2%</td>
#       <td id="T_cd722_row7_col6" class="data row7 col6" >80</td>
#     </tr>
#     <tr>
#       <td id="T_cd722_row8_col0" class="data row8 col0" >OI-2025</td>
#       <td id="T_cd722_row8_col1" class="data row8 col1" >2024-10-15</td>
#       <td id="T_cd722_row8_col2" class="data row8 col2" >2025-03-14</td>
#       <td id="T_cd722_row8_col3" class="data row8 col3" >1,126</td>
#       <td id="T_cd722_row8_col4" class="data row8 col4" >7,789</td>
#       <td id="T_cd722_row8_col5" class="data row8 col5" >13.8%</td>
#       <td id="T_cd722_row8_col6" class="data row8 col6" >80</td>
#     </tr>
#     <tr>
#       <td id="T_cd722_row9_col0" class="data row9 col0" >PV-2025</td>
#       <td id="T_cd722_row9_col1" class="data row9 col1" >2025-04-01</td>
#       <td id="T_cd722_row9_col2" class="data row9 col2" >2025-09-14</td>
#       <td id="T_cd722_row9_col3" class="data row9 col3" >1,158</td>
#       <td id="T_cd722_row9_col4" class="data row9 col4" >7,671</td>
#       <td id="T_cd722_row9_col5" class="data row9 col5" >18.8%</td>
#       <td id="T_cd722_row9_col6" class="data row9 col6" >80</td>
#     </tr>
#   </tbody>
# </table>
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# RESUMEN DE LA SERIE TEMPORAL
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Periodo cubierto : 2020-10-15 → 2025-09-14
#   Total ciclos     : 10 (5 OI + 5 PV)
#   Total eventos    : 11,329 registros de riego
#   Vol. global medio: 7,741 m³/ha/ciclo
#   Ahorro vs 8k     : 3.2%
#   Tendencia vol    : 0.323 (corr con orden)
#
#   Mejor ciclo      : OI-2021 — 7,517 m³/ha
#   Peor ciclo       : PV-2022  — 7,980 m³/ha
